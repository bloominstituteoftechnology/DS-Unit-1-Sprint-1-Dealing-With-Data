# %% [markdown]
# <a href="https://colab.research.google.com/github/KryssyCo/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/Krista_Shepard_DS5_Assignment_4_Make_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **I am doing the assignment where in the same space Ryan used for lecture notes.**
# ## I also watched both Ryan's videos for this assignment, so there may be additional information that came from the other class.

# %% [markdown]
# ## Get LendingClub data
#
# [Source](https://www.lendingclub.com/info/download-data.action)

# %% [markdown]
# _Lambda School Data Science_
#
# # Make features
#
# Objectives
# -  understand the purpose of feature engineering
# -  work with strings in pandas
# - work with dates and times in pandas
#
# Links
# - [Feature Engineering](https://en.wikipedia.org/wiki/Feature_engineering)
# - Python Data Science Handbook
#   - [Chapter 3.10](https://jakevdp.github.io/PythonDataScienceHandbook/03.10-working-with-strings.html), Vectorized String Operations
#   - [Chapter 3.11](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html), Working with Time Series

# %%
# !wget -nc https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip ##Linux Commands
# Out:
# File ‘LoanStats_2018Q4.csv.zip’ already there; not retrieving.

# %%
# !unzip LoanStats_2018Q4.csv.zip ## Linux Commands
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv ## Linux commands includes top of list
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv  ## Linux commands includes bottom of list. Last two lines are issues.
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4680.80","4680.80","1320.92","1320.92","919.20","401.72","0.0","0.0","0.0","May-2019","190.21","Jun-2019","May-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %% [markdown]
# ## Load LendingClub data
#
# pandas documentation
# - [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# - [`options.display`](https://pandas.pydata.org/pandas-docs/stable/options.html#available-options)

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine ='python')

print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       9600         9600           9600.0   36 months
# 1 NaN        NaN       4000         4000           4000.0   36 months
# 2 NaN        NaN       2500         2500           2500.0   36 months
# 3 NaN        NaN      30000        30000          30000.0   60 months
# 4 NaN        NaN       5000         5000           5000.0   36 months
#
#   int_rate  installment grade sub_grade       emp_title emp_length  \
# 0   12.98%       323.37     B        B5             NaN        NaN
# 1   23.40%       155.68     E        E1        Security    3 years
# 2   13.56%        84.92     C        C1            Chef  10+ years
# 3   18.94%       777.23     D        D2     Postmaster   10+ years
# 4   17.97%       180.69     D        D1  Administrative    6 years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# id                                            128412
# member_id                                     128412
# url                                           128412
# desc                                          128412
# hardship_dpd                                  128411
# deferral_term                                 128411
# hardship_amount                               128411
# hardship_start_date                           128411
# hardship_end_date                             128411
# payment_plan_start_date                       128411
# hardship_length                               128411
# orig_projected_additional_accrued_interest    128411
# hardship_loan_status                          128411
# hardship_reason                               128411
# hardship_payoff_balance_amount                128411
# hardship_last_payment_amount                  128411
# hardship_type                                 128411
# hardship_status                               128411
# ...

# %% [markdown]
# ## **Drop NA Columns**

# %%
##df.columns 
## This is how you can look at the column headers

# %%
df = df.drop(['id','url','desc','member_id'], axis='columns') 
## Only run once or you will get an error!!!

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       9600         9600           9600.0   36 months   12.98%       323.37
# 1       4000         4000           4000.0   36 months   23.40%       155.68
# 2       2500         2500           2500.0   36 months   13.56%        84.92
# 3      30000        30000          30000.0   60 months   18.94%       777.23
# 4       5000         5000           5000.0   36 months   17.97%       180.69
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B5             NaN        NaN       MORTGAGE     35704.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     C        C1            Chef  10+ years           RENT     55000.0
# 3     D        D2     Postmaster   10+ years       MORTGAGE     90000.0
# 4     D        D1  Administrative    6 years       MORTGAGE     59280.0
#
# ...

# %%
df.describe(exclude='number')
# Out:
#               term int_rate   grade sub_grade emp_title emp_length  \
# count       128412   128412  128412    128412    107465     116708
# unique           2       46       7        35     43892         11
# top      36 months   13.56%       A        A4   Teacher  10+ years
# freq         88179     6975   38011      9770      2090      38826
#
#        home_ownership verification_status   issue_d loan_status pymnt_plan  \
# count          128412              128412    128412      128412     128412
# unique              4                   3         3           7          1
# top          MORTGAGE        Not Verified  Oct-2018     Current          n
# freq            63490               58350     46305      117259     128412
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# ...

# %% [markdown]
# # **Work with Strings (str)**

# %% [markdown]
# For machine learning, we usually want to replace strings with numbers.
#
# We can get info about which columns have a datatype of "object" (strings)

# %%
df.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
df.describe(exclude='number')
# Out:
#               term int_rate   grade sub_grade emp_title emp_length  \
# count       128412   128412  128412    128412    107465     116708
# unique           2       46       7        35     43892         11
# top      36 months   13.56%       A        A4   Teacher  10+ years
# freq         88179     6975   38011      9770      2090      38826
#
#        home_ownership verification_status   issue_d loan_status pymnt_plan  \
# count          128412              128412    128412      128412     128412
# unique              4                   3         3           7          1
# top          MORTGAGE        Not Verified  Oct-2018     Current          n
# freq            63490               58350     46305      117259     128412
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# ...

# %%
'13.56%'.strip('%')
# Out:
# '13.56'

# %%
type('13.56%'.strip('%'))
# Out:
# str

# %%
float('13.56%'.strip('%'))
# Out:
# 13.56

# %%
type(float('13.56%'.strip('%')))
# Out:
# float

# %% [markdown]
# ## **List Comprehension Example**

# %% [markdown]
# Define a function to remove **percent signs** from strings and convert to floats

# %%
example_list = ['13.56%', '13.57%', '13.58%']

def remove_percent(string):
  return float(string.strip('%'))

[remove_percent(item) for item in example_list]
# Out:
# [13.56, 13.57, 13.58]

# %% [markdown]
# ## Covert int_rate: (to whole column)
#
# Define a function to remove percent signs from strings and **convert to floats**

# %%
def remove_percent(string):
  return float(string.strip('%'))

# %%
## Ryan H's method
## df['int_rate'] = df['int_rate'].str.strip('%').astype(float).head()

# %%
## Ryan A's version uses . apply medthod...it shortens it.
df['int_rate'] = df['int_rate'].apply(remove_percent)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       9600         9600           9600.0   36 months     12.98       323.37
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       2500         2500           2500.0   36 months     13.56        84.92
# 3      30000        30000          30000.0   60 months     18.94       777.23
# 4       5000         5000           5000.0   36 months     17.97       180.69
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B5             NaN        NaN       MORTGAGE     35704.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     C        C1            Chef  10+ years           RENT     55000.0
# 3     D        D2     Postmaster   10+ years       MORTGAGE     90000.0
# 4     D        D1  Administrative    6 years       MORTGAGE     59280.0
#
# ...

# %%
(df['int_rate'] / 100).head() ## Turns it to percentages
# Out:
# 0    0.1298
# 1    0.2340
# 2    0.1356
# 3    0.1894
# 4    0.1797
# Name: int_rate, dtype: float64

# %%
df.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
  ## df['in_rate'] = df['int_rate'].apply(remove_percent) ##THIS IS THE MOST IMPORTANT LINE OF CODE!!! Ryan H

# %%
df.describe(exclude='number')
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       128412  128412    128412    107465     116708         128412
# unique           2       7        35     43892         11              4
# top      36 months       A        A4   Teacher  10+ years       MORTGAGE
# freq         88179   38011      9770      2090      38826          63490
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               128412    128412      128412     128412
# unique                   3         3           7          1
# top           Not Verified  Oct-2018     Current          n
# freq                 58350     46305      117259     128412
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# ...

# %% [markdown]
# ## Filter dataframe by term - Example - Ryan A

# %%
int_rate_14 = df[df['int_rate'] >= 14]
int_rate_14.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 3      30000        30000          30000.0   60 months     18.94       777.23
# 4       5000         5000           5000.0   36 months     17.97       180.69
# 6      23000        23000          23000.0   60 months     20.89       620.81
# 7       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 1     E        E1        Security    3 years           RENT     90000.0
# 3     D        D2     Postmaster   10+ years       MORTGAGE     90000.0
# 4     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 6     D        D4        Operator    5 years           RENT     68107.0
# 7     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
int_rate_14['term'].iloc[0] ##Looks by row
# Out:
# ' 36 months'

# %%
df[df['term'] == ' 36 months'].shape
# Out:
# (88179, 140)

# %%
int_rate_14['term'].loc[0] ## Goes by index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-196-e4c9ae38616d> in <module>()
# ----> 1 int_rate_14['term'].loc[0] ## Goes by index
#
# ...

# %%
int_rate_14['term'].reset_index() ## You can look at just one row.

# %%
int_rate_14.reset_index()

# %% [markdown]
# ### Clean `emp_title`
#
# Look at top 20 titles

# %%
df['emp_title'].value_counts(dropna=False).head(20)

# %% [markdown]
# How often is `emp_title` null?

# %%
df['emp_title'].isnull().sum()

# %% [markdown]
# **Clean the title and handle missing values**
#
# **- Capitalize**
#
# **- Strip spaces**
#
# **- Replace 'NaN' with 'Unknown'**

# %% [markdown]
# ### Create `emp_title_manager`
#
# pandas documentation: [`str.contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html)
#
# Look up top 20 titles

# %%
df['emp_title'].value_counts(dropna=False).head(20)

# %%
df['emp_title'].isnull().sum()

# %% [markdown]
# Clean the title and handle missing values.

# %%
type(np.NaN)
# Out:
# float

# %%
examples = ['owner', 'Supervisor ', ' Project Manager', np.nan]

def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"

[clean_title(x) for x in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %% [markdown]
# **Using .apply with a lambda function**
#
# It doesn't work. Was copied and pasted from Han.

# %%
df.apply(lambda x: x.strip().title() if isinstance(x, str)) ## Han offered it

# %% [markdown]
# ### Create `emp_title_manager`
#
# pandas documentation: [`str.contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html)

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

# %%
df['emp_title'].value_counts()

# %%
df.emp_title_manager = True # Don't do this when trying to create a column
df['emp_title_manager'] = True # Do this

# %%
df['emp_title_manager'] = df['emp_title'].str.contains("Manager")
df['emp_title_manager']

# %%
managers = df[df['emp_title_manager'] == True] 
plebians = df[df['emp_title_manager'] == False]

print(managers['int_rate'].mean())
print(plebians['int_rate'].mean())

# %%
print(managers['int_rate'].std())
print(plebians['int_rate'].std())

# %%
import seaborn as sns
sns.distplot(managers['int_rate'])

# %%
sns.distplot(plebians['int_rate'])

# %% [markdown]
# ## Work with dates

# %% [markdown]
# pandas documentation
# - [to_datetime](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)
# - [Time/Date Components](https://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components) **"You can access these properties via the `.dt` accessor"**

# %%
df['issue_d'].head().values
# Out:
# array(['Dec-2018', 'Dec-2018', 'Dec-2018', 'Dec-2018', 'Dec-2018'],
#       dtype=object)

# %%
df['issue_d'].describe()
# Out:
# count       128412
# unique           3
# top       Oct-2018
# freq         46305
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['issue_d'].describe()

# %%
df['issue_d'].dt.year

# %%
df['issue_d'].dt.month

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

# %%
df.head()

# %%
df['issue_month'].value_counts()

# %%
df.dtypes

# %%
[col for col in df if col.endswith('_d')]

# %%
df['earliest_cr_line'].head()

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], 
                                        infer_datetime_format=True)

# %%
df['issue_d'] - df['earliest_cr_line']

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df['days_from_earliest_credit_to_issue'] = (
    df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df.head()

# %%
df['days_from_earliest_credit_to_issue'].describe()

# %%
25171 / 365

# %% [markdown]
# # ASSIGNMENT
#
# Assignment 4 - Per Ryan
#
# In writing: Get the LendingClub dataset to the same state we had it in by the time of lecture (same columns cleaned up and new columns added). Then clean up the other column with percent signs and handle its missing values. Modify the emp_title column to only contain the most common 20 titles, and make any other changes that you think would be fun/interesting.
#
# Before embarking on this assignment's stretch goals, go back and review the concepts from the week's earlier assignments to prepare for the Sprint Challenge.

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2019-06-03 04:13:14--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.147.5
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.147.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  66.1MB/s    in 3.0s
#
# 2019-06-03 04:13:18 (66.1 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
### Couldn't figure out what to do here....
