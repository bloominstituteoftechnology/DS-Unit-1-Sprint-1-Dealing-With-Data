# %% [markdown]
# <a href="https://colab.research.google.com/github/iesous-kurios/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/module4-makefeatures/GJW_LS_DS_114_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %% [markdown]
# # Weather data

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/jvns/pandas-cookbook/master/data/weather_2012.csv"

# %%
df_weather = pd.read_csv(url) #, parse_dates=True, index_col='Date/Time')
df_weather.head()
# Out:
#              Date/Time  Temp (C)  ...  Stn Press (kPa)               Weather
# 0  2012-01-01 00:00:00      -1.8  ...           101.24                   Fog
# 1  2012-01-01 01:00:00      -1.8  ...           101.24                   Fog
# 2  2012-01-01 02:00:00      -1.8  ...           101.26  Freezing Drizzle,Fog
# 3  2012-01-01 03:00:00      -1.5  ...           101.27  Freezing Drizzle,Fog
# 4  2012-01-01 04:00:00      -1.5  ...           101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df_weather['Date/Time'] = pd.to_datetime(df_weather['Date/Time'])

# %%
df_weather.set_index('Date/Time')
# Out:
#                      Temp (C)  ...               Weather
# Date/Time                      ...
# 2012-01-01 00:00:00      -1.8  ...                   Fog
# 2012-01-01 01:00:00      -1.8  ...                   Fog
# 2012-01-01 02:00:00      -1.8  ...  Freezing Drizzle,Fog
# 2012-01-01 03:00:00      -1.5  ...  Freezing Drizzle,Fog
# 2012-01-01 04:00:00      -1.5  ...                   Fog
# 2012-01-01 05:00:00      -1.4  ...                   Fog
# 2012-01-01 06:00:00      -1.5  ...                   Fog
# 2012-01-01 07:00:00      -1.4  ...                   Fog
# 2012-01-01 08:00:00      -1.4  ...                   Fog
# 2012-01-01 09:00:00      -1.3  ...                   Fog
# 2012-01-01 10:00:00      -1.0  ...                   Fog
# 2012-01-01 11:00:00      -0.5  ...                   Fog
# 2012-01-01 12:00:00      -0.2  ...                   Fog
# 2012-01-01 13:00:00       0.2  ...                   Fog
# 2012-01-01 14:00:00       0.8  ...                   Fog
# 2012-01-01 15:00:00       1.8  ...                   Fog
# 2012-01-01 16:00:00       2.6  ...         Mostly Cloudy
# 2012-01-01 17:00:00       3.0  ...                Cloudy
# 2012-01-01 18:00:00       3.8  ...                  Rain
# 2012-01-01 19:00:00       3.1  ...                  Rain
# 2012-01-01 20:00:00       3.2  ...                Cloudy
# 2012-01-01 21:00:00       4.0  ...                Cloudy
# 2012-01-01 22:00:00       4.4  ...          Rain Showers
# 2012-01-01 23:00:00       5.3  ...                Cloudy
# 2012-01-02 00:00:00       5.2  ...          Rain Showers
# 2012-01-02 01:00:00       4.6  ...                Cloudy
# 2012-01-02 02:00:00       3.9  ...         Mostly Cloudy
# 2012-01-02 03:00:00       3.7  ...         Mostly Cloudy
# 2012-01-02 04:00:00       2.9  ...         Mostly Cloudy
# 2012-01-02 05:00:00       2.6  ...         Mostly Cloudy
# ...                       ...  ...                   ...
# 2012-12-30 18:00:00     -12.6  ...          Mainly Clear
# 2012-12-30 19:00:00     -13.4  ...          Mainly Clear
# 2012-12-30 20:00:00     -13.8  ...                 Clear
# 2012-12-30 21:00:00     -13.8  ...          Mainly Clear
# 2012-12-30 22:00:00     -13.7  ...          Mainly Clear
# 2012-12-30 23:00:00     -12.1  ...         Mostly Cloudy
# 2012-12-31 00:00:00     -11.1  ...                Cloudy
# 2012-12-31 01:00:00     -10.7  ...                Cloudy
# 2012-12-31 02:00:00     -10.1  ...                Cloudy
# 2012-12-31 03:00:00     -11.8  ...         Mostly Cloudy
# 2012-12-31 04:00:00     -10.5  ...                Cloudy
# 2012-12-31 05:00:00     -10.2  ...                Cloudy
# 2012-12-31 06:00:00      -9.7  ...                Cloudy
# 2012-12-31 07:00:00      -9.3  ...          Snow Showers
# 2012-12-31 08:00:00      -8.6  ...          Snow Showers
# 2012-12-31 09:00:00      -8.1  ...                  Snow
# 2012-12-31 10:00:00      -7.4  ...              Snow,Fog
# 2012-12-31 11:00:00      -6.7  ...                  Snow
# 2012-12-31 12:00:00      -5.8  ...                  Snow
# 2012-12-31 13:00:00      -4.6  ...                  Snow
# 2012-12-31 14:00:00      -3.4  ...                  Snow
# 2012-12-31 15:00:00      -2.3  ...                  Snow
# 2012-12-31 16:00:00      -1.4  ...                  Snow
# 2012-12-31 17:00:00      -1.1  ...                  Snow
# 2012-12-31 18:00:00      -1.3  ...                  Snow
# 2012-12-31 19:00:00       0.1  ...                  Snow
# 2012-12-31 20:00:00       0.2  ...                  Snow
# 2012-12-31 21:00:00      -0.5  ...                  Snow
# 2012-12-31 22:00:00      -0.2  ...                  Snow
# 2012-12-31 23:00:00       0.0  ...                  Snow
#
# [8784 rows x 7 columns]

# %%
type(df_weather['Date/Time'])
# Out:
# pandas.core.series.Series

# %%
x_list = [1,2,3]
x_arr = np.array([1,2,3])
x_series = pd.Series([1,2,3])

# %%
for i in  x_series:
  print(i)
# Out:
# 1
# 2
# 3

# %%
df_weather['Weather'].str.contains('Snow')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8754    False
# 8755    False
# 8756    False
# 8757    False
# 8758    False
# 8759    False
# 8760    False
# 8761    False
# 8762    False
# 8763    False
# 8764    False
# 8765    False
# 8766    False
# 8767     True
# 8768     True
# 8769     True
# 8770     True
# 8771     True
# 8772     True
# 8773     True
# 8774     True
# 8775     True
# 8776     True
# 8777     True
# 8778     True
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# 8783     True
# Name: Weather, Length: 8784, dtype: bool

# %%
df_weather['Weather'].str.contains('Rain')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19       True
# 20      False
# 21      False
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8754    False
# 8755    False
# 8756    False
# 8757    False
# 8758    False
# 8759    False
# 8760    False
# 8761    False
# 8762    False
# 8763    False
# 8764    False
# 8765    False
# 8766    False
# 8767    False
# 8768    False
# 8769    False
# 8770    False
# 8771    False
# 8772    False
# 8773    False
# 8774    False
# 8775    False
# 8776    False
# 8777    False
# 8778    False
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
is_percipitation = df_weather['Weather'].str.contains('Rain') | df_weather['Weather'].str.contains('Snow')
is_percipitation
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19       True
# 20      False
# 21      False
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8754    False
# 8755    False
# 8756    False
# 8757    False
# 8758    False
# 8759    False
# 8760    False
# 8761    False
# 8762    False
# 8763    False
# 8764    False
# 8765    False
# 8766    False
# 8767     True
# 8768     True
# 8769     True
# 8770     True
# 8771     True
# 8772     True
# 8773     True
# 8774     True
# 8775     True
# 8776     True
# 8777     True
# 8778     True
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# 8783     True
# Name: Weather, Length: 8784, dtype: bool

# %%
df_weather['is_percipitation'] = is_percipitation

# %%
df_weather.head()
# Out:
#             Date/Time  Temp (C)  ...               Weather  is_percipitation
# 0 2012-01-01 00:00:00      -1.8  ...                   Fog             False
# 1 2012-01-01 01:00:00      -1.8  ...                   Fog             False
# 2 2012-01-01 02:00:00      -1.8  ...  Freezing Drizzle,Fog             False
# 3 2012-01-01 03:00:00      -1.5  ...  Freezing Drizzle,Fog             False
# 4 2012-01-01 04:00:00      -1.5  ...                   Fog             False
#
# [5 rows x 9 columns]

# %%
df_weather['Visibility (mi)'] = df_weather['Visibility (km)']*0.621

# %%
df_weather.head()
# Out:
#             Date/Time  Temp (C)  ...  is_percipitation  Visibility (mi)
# 0 2012-01-01 00:00:00      -1.8  ...             False           4.9680
# 1 2012-01-01 01:00:00      -1.8  ...             False           4.9680
# 2 2012-01-01 02:00:00      -1.8  ...             False           2.4840
# 3 2012-01-01 03:00:00      -1.5  ...             False           2.4840
# 4 2012-01-01 04:00:00      -1.5  ...             False           2.9808
#
# [5 rows x 10 columns]

# %%
df_weather['Weather'].str.split(',',expand=True)
# Out:
#                      0     1     2
# 0                  Fog  None  None
# 1                  Fog  None  None
# 2     Freezing Drizzle   Fog  None
# 3     Freezing Drizzle   Fog  None
# 4                  Fog  None  None
# 5                  Fog  None  None
# 6                  Fog  None  None
# 7                  Fog  None  None
# 8                  Fog  None  None
# 9                  Fog  None  None
# 10                 Fog  None  None
# 11                 Fog  None  None
# 12                 Fog  None  None
# 13                 Fog  None  None
# 14                 Fog  None  None
# 15                 Fog  None  None
# 16       Mostly Cloudy  None  None
# 17              Cloudy  None  None
# 18                Rain  None  None
# 19                Rain  None  None
# 20              Cloudy  None  None
# 21              Cloudy  None  None
# 22        Rain Showers  None  None
# 23              Cloudy  None  None
# 24        Rain Showers  None  None
# 25              Cloudy  None  None
# 26       Mostly Cloudy  None  None
# 27       Mostly Cloudy  None  None
# 28       Mostly Cloudy  None  None
# 29       Mostly Cloudy  None  None
# ...                ...   ...   ...
# 8754      Mainly Clear  None  None
# 8755      Mainly Clear  None  None
# 8756             Clear  None  None
# 8757      Mainly Clear  None  None
# 8758      Mainly Clear  None  None
56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,123,124,125,126,127,128,129,130,131,132,133,134,135,136,138,139,140,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# id  member_id loan_amnt funded_amnt funded_amnt_inv term       int_rate installment grade sub_grade emp_title      emp_length home_ownership annual_inc verification_status issue_d  loan_status        pymnt_plan url desc purpose            title              zip_code addr_state dti   delinq_2yrs earliest_cr_line inq_last_6mths mths_since_last_delinq mths_since_last_record open_acc pub_rec revol_bal revol_util total_acc initial_list_status out_prncp out_prncp_inv total_pymnt total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt next_pymnt_d last_credit_pull_d collections_12_mths_ex_med mths_since_last_major_derog policy_code application_type annual_inc_joint dti_joint verification_status_joint acc_now_delinq tot_coll_amt tot_cur_bal open_acc_6m open_act_il open_il_12m open_il_24m mths_since_rcnt_il total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m acc_open_past_24mths avg_cur_bal bc_open_to_buy bc_util chargeoff_within_12_mths delinq_amnt mo_sin_old_il_acct mo_sin_old_rev_tl_op mo_sin_rcnt_rev_tl_op mo_sin_rcnt_tl mort_acc mths_since_recent_bc mths_since_recent_bc_dlq mths_since_recent_inq mths_since_recent_revol_delinq num_accts_ever_120_pd num_actv_bc_tl num_actv_rev_tl num_bc_sats num_bc_tl num_il_tl num_op_rev_tl num_rev_accts num_rev_tl_bal_gt_0 num_sats num_tl_120dpd_2m num_tl_30dpd num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit total_il_high_credit_limit revol_bal_joint sec_app_earliest_cr_line sec_app_inq_last_6mths sec_app_mort_acc sec_app_open_acc sec_app_revol_util sec_app_open_act_il sec_app_num_rev_accts sec_app_chargeoff_within_12_mths sec_app_collections_12_mths_ex_med sec_app_mths_since_last_major_derog hardship_flag hardship_type hardship_reason hardship_status deferral_term hardship_amount hardship_start_date hardship_end_date payment_plan_start_date hardship_length hardship_dpd hardship_loan_status orig_projected_additional_accrued_interest hardship_payoff_balance_amount hardship_last_payment_amount debt_settlement_flag debt_settlement_flag_date settlement_status settlement_date settlement_amount settlement_percentage                                    settlement_term
# NaN NaN       10000     10000       10000            36 months  10.33%  324.23      B     B1        NaN            < 1 year   MORTGAGE       280000     Not Verified        Dec-2018 Current            n          NaN NaN  debt_consolidation Debt consolidation 974xx    OR         6.15  2           Jan-1996         0              18                     NaN                    14       0       9082      38%        23        w                   8289.30   8289.30       2261.0      2261.00         1710.70         550.30        0.0                0.0        0.0                     Jul-2019     324.23          Sep-2019     Aug-2019           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              671          246828      1           3           2           3           1                  48552        62      1           3           4923       46       23900            2      7           1            7                    17631       11897          43.1    0                        0           158                275                  11                    1              1        11                   NaN                      11                    NaN                            0                     3              4               7           7         10        9             11            4                   14       0                0            0                  4                  91.3           28.6             0                    0         367828          61364             20900          54912                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#               4000      4000        4000             36 months  23.40%  155.68      E     E1        Security       3 years    RENT           90000      Source Verified     Dec-2018 Current            n          NaN NaN  debt_consolidation Debt consolidation 070xx    NJ         26.33 0           Sep-2006         4              59                     NaN                    15       0       5199      19.2%      20        w                   3423.38   3423.38       1081.96     1081.96         576.62          505.34        0.0                0.0        0.0                     Jul-2019     155.68          Sep-2019     Aug-2019           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            66926       5           4           3           4           5                  61727        86      6           11          1353       68       27100            4      0           4            15                   4462        20174          7.9     0                        0           147                118                  2                     2              0        2                    NaN                      0                     NaN                            0                     5              7               9           9         8         11            12            7                   15       0                0            0                  9                  95             0                0                    0         98655           66926             21900          71555                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#               5000      5000        5000             36 months  17.97%  180.69      D     D1        Administrative 6 years    MORTGAGE       59280      Source Verified     Dec-2018 Late (31-120 days) n          NaN NaN  debt_consolidation Debt consolidation 490xx    MI         10.51 0           Apr-2011         0              NaN                    NaN                    8        0       4599      19.1%      13        w                   4456.17   4456.17       895.96      895.96          543.83          352.13        0.0                0.0        0.0                     Jun-2019     180.69          Sep-2019     Aug-2019           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            110299      0           1           0           2           14                 7150         72      0           2           0          35       24100            1      5           0            4                    18383       13800          0       0                        0           87                 92                   15                    14             2        77                   NaN                      14                    NaN                            0                     0              3               3           3         4         6             7             3                   8        0                0            0                  0                  100            0                0                    0         136927          11749             13800          10000                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#
","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","5000","5000","5000"," 36 months"," 13.56%","169.83","C","C1","Payoff Clerk","10+ years","MORTGAGE","35360","Not Verified","Oct-2018","Current","n","","","debt_consolidation","Debt consolidation","381xx","TN","11.3","1","Jun-2006","0","21","","9","0","2597","27.3%","15","f","3807.30","3807.30","1694.53","1694.53","1192.70","501.83","0.0","0.0","0.0","Aug-2019","169.83","Sep-2019","Aug-2019","0","","1","Individual","","","","0","1413","69785","0","2","0","1","16","2379","40","3","4","1826","32","9500","0","0","1","5","8723","1174","60.9","0","0","147","85","9","9","2","10","21","9","21","0","1","3","2","2","6","6","7","3","9","0","0","0","3","92.9","50","0","0","93908","4976","3000","6028","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","10000","10000","9750"," 36 months"," 11.06%","327.68","B","B3","","n/a","RENT","44400","Source Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","980xx","WA","11.78","0","Oct-2008","2","40","","15","0","6269","13.1%","25","f","7544.75","7356.13","3261.44","3179.90","2455.25","806.19","0.0","0.0","0.0","Aug-2019","327.68","Sep-2019","Aug-2019","0","53","1","Individual","","","","0","520","16440","3","1","1","1","2","10171","100","2","5","404","28","47700","0","3","5","6","1265","20037","2.3","0","0","61","119","1","1","0","1","","1","40","1","2","4","6","8","3","14","22","4","15","0","0","0","3","92","0","0","0","57871","16440","20500","10171","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","10000","10000","10000"," 36 months"," 16.91%","356.08","C","C5","Key Accounts Manager","2 years","RENT","80000","Not Verified","Oct-2018","Current","n","","","other","Other","021xx","MA","17.72","1","Sep-2006","0","14","","17","0","1942","30.8%","31","w","7706.67","7706.67","3551.41","3551.41","2293.33","1258.08","0.0","0.0","0.0","Aug-2019","356.08","Sep-2019","Aug-2019","0","25","1","Individual","","","","0","0","59194","0","15","1","1","12","57252","85","0","0","1942","80","6300","0","5","0","1","3482","2058","48.5","0","0","144","142","40","12","0","131","30","","30","3","1","1","1","5","22","2","9","1","17","0","0","0","1","74.2","0","0","0","73669","59194","4000","67369","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
#
#
# Total amount funded in policy code 1: 2050909275
# Total amount funded in policy code 2: 820109297

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')

# %%
df.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128407 NaN        NaN  ...                    NaN              NaN
# 128408 NaN        NaN  ...                    NaN              NaN
# 128409 NaN        NaN  ...                    NaN              NaN
# 128410 NaN        NaN  ...                    NaN              NaN
# 128411 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.shape
# Out:
# (128412, 144)

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
df.isnull().sum()
# Out:
# id                                            128412
# member_id                                     128412
# loan_amnt                                          0
# funded_amnt                                        0
# funded_amnt_inv                                    0
# term                                               0
# int_rate                                           0
# installment                                        0
# grade                                              0
# sub_grade                                          0
# emp_title                                      20947
# emp_length                                     11704
# home_ownership                                     0
# annual_inc                                         0
# verification_status                                0
# issue_d                                            0
# loan_status                                        0
# pymnt_plan                                         0
# url                                           128412
# desc                                          128412
# purpose                                            0
# title                                              0
# zip_code                                           0
# addr_state                                         0
# dti                                              237
#                                                ...
# sec_app_chargeoff_within_12_mths              111630
# sec_app_collections_12_mths_ex_med            111630
# sec_app_mths_since_last_major_derog           123258
# hardship_flag                                      0
# hardship_type                                 128385
# hardship_reason                               128385
# hardship_status                               128385
# deferral_term                                 128385
# hardship_amount                               128385
# hardship_start_date                           128385
# hardship_end_date                             128385
# payment_plan_start_date                       128385
# hardship_length                               128385
# hardship_dpd                                  128385
# hardship_loan_status                          128385
# orig_projected_additional_accrued_interest    128386
# hardship_payoff_balance_amount                128385
# hardship_last_payment_amount                  128385
# debt_settlement_flag                               0
# debt_settlement_flag_date                     128301
# settlement_status                             128301
# settlement_date                               128301
# settlement_amount                             128301
# settlement_percentage                         128301
# settlement_term                               128301
# Length: 144, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# desc                                          128412
# member_id                                     128412
# url                                           128412
# orig_projected_additional_accrued_interest    128386
# hardship_type                                 128385
# hardship_last_payment_amount                  128385
# hardship_payoff_balance_amount                128385
# hardship_reason                               128385
# hardship_loan_status                          128385
# hardship_dpd                                  128385
# hardship_length                               128385
# payment_plan_start_date                       128385
# hardship_end_date                             128385
# hardship_start_date                           128385
# hardship_amount                               128385
# deferral_term                                 128385
# hardship_status                               128385
# settlement_percentage                         128301
# settlement_term                               128301
# settlement_status                             128301
# settlement_amount                             128301
# settlement_date                               128301
# debt_settlement_flag_date                     128301
# sec_app_mths_since_last_major_derog           123258
#                                                ...
# total_il_high_credit_limit                         0
# mort_acc                                           0
# mo_sin_rcnt_tl                                     0
# mo_sin_rcnt_rev_tl_op                              0
# mo_sin_old_rev_tl_op                               0
# policy_code                                        0
# application_type                                   0
# acc_now_delinq                                     0
# tot_coll_amt                                       0
# tot_cur_bal                                        0
# open_acc_6m                                        0
# open_act_il                                        0
# hardship_flag                                      0
# open_il_24m                                        0
# total_bal_il                                       0
# open_rv_12m                                        0
# open_rv_24m                                        0
# max_bal_bc                                         0
# total_rev_hi_lim                                   0
# total_cu_tl                                        0
# inq_last_12m                                       0
# acc_open_past_24mths                               0
# chargeoff_within_12_mths                           0
# delinq_amnt                                        0
# inq_fi                                             0
# Length: 144, dtype: int64

# %% [markdown]
# ## Work with strings

# %%
df.drop(columns=['id', 'member_id', 'desc', 'url'])
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           10000        10000          10000.0   36 months   10.33%
# 1            4000         4000           4000.0   36 months   23.40%
# 2            5000         5000           5000.0   36 months   17.97%
# 3           23000        23000          23000.0   60 months   20.89%
# 4            8000         8000           8000.0   36 months   23.40%
# 5           32075        32075          32075.0   60 months   11.80%
# 6            9600         9600           9600.0   36 months   12.98%
# 7           30000        30000          30000.0   60 months   18.94%
# 8            2500         2500           2500.0   36 months   13.56%
# 9           12000        12000          12000.0   60 months   13.56%
# 10          10000        10000          10000.0   60 months   19.92%
# 11          16000        16000          16000.0   60 months   17.97%
# 12          16000        16000          16000.0   60 months   26.31%
# 13          15000        15000          14975.0   60 months   14.47%
# 14          13000        13000          13000.0   36 months   23.40%
# 15           9600         9600           9600.0   36 months   23.40%
# 16           3500         3500           3500.0   36 months   20.89%
# 17          25000        25000          25000.0   60 months   16.91%
# 18          16000        16000          16000.0   60 months   20.89%
# 19          13000        13000          13000.0   60 months   14.47%
# 20          10000        10000          10000.0   36 months   13.56%
# 21          13000        13000          13000.0   36 months   14.47%
# 22           7000         7000           7000.0   36 months   12.98%
# 23           3300         3300           3300.0   36 months   23.40%
# 24          20000        20000          20000.0   60 months   11.80%
# ...           ...          ...              ...         ...      ...
# 128387       6000         6000           6000.0   36 months   11.55%
# 128388      20000        20000          20000.0   36 months    8.46%
# 128389       6000         6000           5750.0   36 months   11.55%
# 128390      24000        24000          24000.0   36 months   19.92%
# 128391      35000        35000          34975.0   36 months    6.67%
# 128392       6500         6500           6500.0   36 months   26.31%
# 128393       6500         6500           6500.0   36 months   16.91%
# 128394       5000         5000           5000.0   36 months    6.11%
# 128395      22000        22000          22000.0   36 months   11.55%
# 128396      24000        24000          24000.0   60 months   15.02%
# 128397      20000        20000          20000.0   60 months   15.02%
# 128398      12000        12000          12000.0   60 months   18.94%
# 128399       5000         5000           5000.0   36 months   15.02%
# 128400      20000        20000          20000.0   60 months   15.02%
# 128401      20000        20000          20000.0   36 months   11.55%
# 128402      17500        17500          17500.0   60 months   22.35%
# 128403       5000         5000           5000.0   36 months   16.14%
# 128404       5000         5000           5000.0   36 months   16.14%
# 128405      22000        22000          22000.0   60 months    7.84%
# 128406       5600         5600           5600.0   36 months   13.56%
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
# 128411      10000        10000          10000.0   36 months   16.91%
#
#         installment grade sub_grade                              emp_title  \
# 0            324.23     B        B1                                    NaN
# 1            155.68     E        E1                               Security
# 2            180.69     D        D1                         Administrative
# 3            620.81     D        D4                               Operator
# 4            311.35     E        E1                                Manager
# 5            710.26     B        B4                     Nursing Supervisor
# 6            323.37     B        B5                                    NaN
# 7            777.23     D        D2                            Postmaster
# 8             84.92     C        C1                                   Chef
# 9            276.49     C        C1                                    NaN
# 10           264.50     D        D3                       Material Handler
# 11           406.04     D        D1              Instructional Coordinator
# 12           481.99     E        E4       Financial Relationship Associate
# 13           352.69     C        C2                                    NaN
# 14           505.95     E        E1                    Sale Representative
# 15           373.62     E        E1                    driver coordinator
# 16           131.67     D        D4                          gas attendant
# 17           620.11     C        C5                             Processor
# 18           431.87     D        D4            Neonatal Nurse Practitioner
# 19           305.67     C        C2                    Stationary Engineer
# 20           339.65     C        C1                                    NaN
# 21           447.29     C        C2                      Exhibits director
# 22           235.80     B        B5                       Worship Director
# 23           128.44     E        E1                        Program Manager
# 24           442.88     B        B4                                    NaN
# ...             ...   ...       ...                                    ...
# 128387       198.00     B        B4                               ENGINEER
# 128388       630.99     A        A5                      Welder/Blacksmith
# 128389       198.00     B        B4                          RN Supervisor
# 128390       890.95     D        D3                    Corrections officer
# 128391      1075.43     A        A2                                    NaN
# 128392       262.97     E        E4               Merchandise Team Captain
# 128393       231.46     C        C5  Senior Accountant, Fixed Assets Acctg
# 128394       152.36     A        A1                Implementation Manager
# 128395       726.00     B        B4                Sr. application analyst
# 128396       571.22     C        C3    Instructional Technology Specialist
# 128397       476.01     C        C3                  Technical Supvervisor
# 128398       310.90     D        D2      Senior Business Account Executive
# 128399       173.38     C        C3                                   Tech
# 128400       476.01     C        C3                 production supervisor
# 128401       660.00     B        B4             secondary opps/lead coater
# 128402       486.82     D        D5                                    NaN
# 128403       176.14     C        C4                                    NaN
# 128404       176.14     C        C4             Oncology Medical Assistant
# 128405       444.40     A        A4                                  Owner
# 128406       190.21     C        C1                                    NaN
# 128407       797.53     C        C3                         Tax Consultant
# 128408       346.76     C        C3                         security guard
# 128409       169.83     C        C1                           Payoff Clerk
# 128410       327.68     B        B3                                    NaN
# 128411       356.08     C        C5                   Key Accounts Manager
#
#        emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0        < 1 year       MORTGAGE    280000.0        Not Verified  Dec-2018
# 1         3 years           RENT     90000.0     Source Verified  Dec-2018
# 2         6 years       MORTGAGE     59280.0     Source Verified  Dec-2018
# 3         5 years           RENT     68107.0     Source Verified  Dec-2018
# 4       10+ years            OWN     43000.0     Source Verified  Dec-2018
# 5       10+ years       MORTGAGE    150000.0        Not Verified  Dec-2018
# 6             NaN       MORTGAGE     35704.0        Not Verified  Dec-2018
# 7       10+ years       MORTGAGE     90000.0     Source Verified  Dec-2018
# 8       10+ years           RENT     55000.0        Not Verified  Dec-2018
# 9        < 1 year       MORTGAGE     40000.0        Not Verified  Dec-2018
# 10      10+ years       MORTGAGE     80000.0        Not Verified  Dec-2018
# 11        5 years       MORTGAGE     51000.0        Not Verified  Dec-2018
# 12       < 1 year           RENT     33000.0     Source Verified  Dec-2018
# 13            NaN       MORTGAGE     30000.0     Source Verified  Dec-2018
# 14        2 years       MORTGAGE     90000.0            Verified  Dec-2018
# 15        9 years           RENT     65000.0        Not Verified  Dec-2018
# 16      10+ years       MORTGAGE     40000.0     Source Verified  Dec-2018
# 17      10+ years       MORTGAGE     23878.0        Not Verified  Dec-2018
# 18        4 years       MORTGAGE    120000.0        Not Verified  Dec-2018
# 19      10+ years       MORTGAGE     75000.0        Not Verified  Dec-2018
# 20       < 1 year       MORTGAGE     65000.0        Not Verified  Dec-2018
# 21      10+ years       MORTGAGE     55000.0            Verified  Dec-2018
# 22        4 years       MORTGAGE    102500.0        Not Verified  Dec-2018
# 23        3 years           RENT     49700.0     Source Verified  Dec-2018
# 24            NaN       MORTGAGE     47590.0            Verified  Dec-2018
# ...           ...            ...         ...                 ...       ...
# 128387    2 years           RENT     90000.0        Not Verified  Oct-2018
# 128388  10+ years       MORTGAGE     97000.0     Source Verified  Oct-2018
# 128389    6 years           RENT     70000.0        Not Verified  Oct-2018
# 128390  10+ years           RENT     34000.0            Verified  Oct-2018
# 128391        NaN       MORTGAGE     85000.0     Source Verified  Oct-2018
# 128392  10+ years       MORTGAGE     35000.0            Verified  Oct-2018
# 128393    7 years           RENT     74160.0     Source Verified  Oct-2018
# 128394    9 years       MORTGAGE     82000.0        Not Verified  Oct-2018
# 128395  10+ years       MORTGAGE     72000.0     Source Verified  Oct-2018
# 128396  10+ years       MORTGAGE     60000.0        Not Verified  Oct-2018
# 128397  10+ years       MORTGAGE     75000.0            Verified  Oct-2018
# 128398    6 years           RENT    128000.0            Verified  Oct-2018
# 128399  10+ years       MORTGAGE     35000.0     Source Verified  Oct-2018
# 128400  10+ years       MORTGAGE     80000.0        Not Verified  Oct-2018
# 128401  10+ years            OWN     45000.0        Not Verified  Oct-2018
# 128402        NaN           RENT     25000.0            Verified  Oct-2018
# 128403        NaN            OWN      9200.0     Source Verified  Oct-2018
# 128404    3 years       MORTGAGE     46400.0     Source Verified  Oct-2018
# 128405  10+ years       MORTGAGE     55000.0        Not Verified  Oct-2018
# 128406        NaN           RENT     15600.0        Not Verified  Oct-2018
# 128407  10+ years       MORTGAGE     75000.0     Source Verified  Oct-2018
# 128408    5 years       MORTGAGE     38000.0        Not Verified  Oct-2018
# 128409  10+ years       MORTGAGE     35360.0        Not Verified  Oct-2018
# 128410        NaN           RENT     44400.0     Source Verified  Oct-2018
# 128411    2 years           RENT     80000.0        Not Verified  Oct-2018
#
#                loan_status pymnt_plan             purpose  \
# 0                  Current          n  debt_consolidation
# 1                  Current          n  debt_consolidation
# 2       Late (31-120 days)          n  debt_consolidation
# 3                  Current          n  debt_consolidation
# 4                  Current          n  debt_consolidation
# 5                  Current          n         credit_card
# 6                  Current          n    home_improvement
# 7                  Current          n  debt_consolidation
# 8               Fully Paid          n  debt_consolidation
# 9                  Current          n  debt_consolidation
# 10                 Current          n  debt_consolidation
# 11                 Current          n  debt_consolidation
# 12                 Current          n         credit_card
# 13                 Current          n  debt_consolidation
# 14                 Current          n               other
# 15                 Current          n         credit_card
# 16                 Current          n                 car
# 17                 Current          n  debt_consolidation
# 18                 Current          n         credit_card
# 19              Fully Paid          n  debt_consolidation
# 20                 Current          n         credit_card
# 21                 Current          n         credit_card
# 22                 Current          n               house
# 23                 Current          n            vacation
# 24                 Current          n         credit_card
# ...                    ...        ...                 ...
# 128387             Current          n         credit_card
# 128388             Current          n  debt_consolidation
# 128389         Charged Off          n             medical
# 128390  Late (31-120 days)          n  debt_consolidation
# 128391          Fully Paid          n  debt_consolidation
# 128392             Current          n    home_improvement
# 128393             Current          n  debt_consolidation
# 128394             Current          n               other
# 128395             Current          n  debt_consolidation
# 128396             Current          n  debt_consolidation
# 128397          Fully Paid          n         credit_card
# 128398             Current          n  debt_consolidation
# 128399             Current          n  debt_consolidation
# 128400             Current          n  debt_consolidation
# 128401             Current          n    home_improvement
# 128402             Current          n  debt_consolidation
# 128403             Current          n  debt_consolidation
# 128404          Fully Paid          n  debt_consolidation
# 128405             Current          n               other
# 128406             Current          n         credit_card
# 128407         Charged Off          n  debt_consolidation
# 128408             Current          n  debt_consolidation
# 128409             Current          n  debt_consolidation
# 128410             Current          n         credit_card
# 128411             Current          n               other
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 
# 9              Aug-2005               2                     NaN  ...
# 10             Apr-2005               0                    37.0  ...
# 11             Oct-2005               1                    52.0  ...
# 12             Sep-2010               1                     NaN  ...
# 13             Oct-1999               0                     NaN  ...
# 14             May-2007               0                     NaN  ...
# 15             Sep-2003               0                    16.0  ...
# 16             Oct-2004               1                    24.0  ...
# 17             Oct-2010               0                     NaN  ...
# 18             Jul-2005               0                     8.0  ...
# 19             Feb-2001               1                     NaN  ...
# 20             Dec-2004               1                    30.0  ...
# 21             Oct-2001               0                     NaN  ...
# 22             Dec-2002               0                    38.0  ...
# 23             Nov-2006               1                    43.0  ...
# 24             Sep-1999               0                    62.0  ...
# ...                 ...             ...                     ...  ...
# 128387         Sep-2010               1                    53.0  ...
# 128388         Jul-1999               1                    64.0  ...
# 128389         Dec-1993               0                    17.0  ...
# 128390         Jun-2006               0                     NaN  ...
# 128391         Apr-1997               2                    54.0  ...
# 128392         Mar-2004               0                    70.0  ...
# 128393         Jun-2006               0                    38.0  ...
# 128394         Feb-2005               0                    33.0  ...
# 128395         Jun-1999               0                    26.0  ...
# 128396         Apr-1999               1                    43.0  ...
# 128397         Apr-1991               2                     NaN  ...
# 128398         Nov-2007               1                    46.0  ...
# 128399         Jun-2003               0                    15.0  ...
# 128400         Oct-2005               0                     NaN  ...
# 128401         Dec-2003               0                    41.0  ...
# 128402         Oct-2001               0                     NaN  ...
# 128403         Apr-2015               1                     NaN  ...
# 128404         Nov-2003               0                    29.0  ...
# 128405         Apr-1987               0                     NaN  ...
# 128406         Aug-2012               0                     NaN  ...
# 128407         Aug-1985               2                    22.0  ...
# 128408         Jul-1982               0                     6.0  ...
# 128409         Jun-2006               0                    21.0  ...
# 128410         Oct-2008               2                    40.0  ...
# 128411         Sep-2006               0                    14.0  ...
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# 5                                    NaN                                 NaN
# 6                                    NaN                                 NaN
# 7                                    NaN                                 NaN
# 8                                    NaN                                 NaN
# 9                                    NaN                                 NaN
# 10                                   NaN                                 NaN
# 11                                   NaN                                 NaN
# 12                                   NaN                                 NaN
# 13                                   0.0                                 0.0
# 14                                   NaN                                 NaN
# 15                                   NaN                                 NaN
# 16                                   0.0                                 0.0
# 17                                   0.0                                 0.0
# 18                                   NaN                                 NaN
# 19                                   NaN                                 NaN
# 20                                   NaN                                 NaN
# 21                                   NaN                                 NaN
# 22                                   NaN                                 NaN
# 23                                   NaN                                 NaN
# 24                                   0.0                                 0.0
# ...                                  ...                                 ...
# 128387                               0.0                                 0.0
# 128388                               NaN                                 NaN
# 128389                               0.0                                 0.0
# 128390                               0.0                                 1.0
# 128391                               0.0                                 0.0
# 128392                               NaN                                 NaN
# 128393                               0.0                                 0.0
# 128394                               0.0                                 0.0
# 128395                               0.0                                 0.0
# 128396                               NaN                                 NaN
# 128397                               NaN                                 NaN
# 128398                               NaN                                 NaN
# 128399                               NaN                                 NaN
# 128400                               0.0                                 0.0
# 128401                               NaN                                 NaN
# 128402                               NaN                                 NaN
# 128403                               NaN                                 NaN
# 128404                               NaN                                 NaN
# 128405                               NaN                                 NaN
# 128406                               NaN                                 NaN
# 128407                               NaN                                 NaN
# 128408                               NaN                                 NaN
# 128409                               NaN                                 NaN
# 128410                               NaN                                 NaN
# 128411                               NaN                                 NaN
#
#         sec_app_mths_since_last_major_derog  hardship_flag hardship_type  \
# 0                                       NaN              N           NaN
# 1                                       NaN              N           NaN
# 2                                       NaN              N           NaN
# 3                                       NaN              N           NaN
# 4                                       NaN              N           NaN
# 5                                       NaN              N           NaN
# 6                                       NaN              N           NaN
# 7                                       NaN              N           NaN
# 8                                       NaN              N           NaN
# 9                                       NaN              N           NaN
# 10                                      NaN              N           NaN
# 11                                      NaN              N           NaN
# 12                                      NaN              N           NaN
# 13                                      NaN              N           NaN
# 14                                      NaN              N           NaN
# 15                                      NaN              N           NaN
# 16                                     46.0              N           NaN
# 17                                      NaN              N           NaN
# 18                                      NaN              N           NaN
# 19                                      NaN              N           NaN
# 20                                      NaN              N           NaN
# 21                                      NaN              N           NaN
# 22                                      NaN              N           NaN
# 23                                      NaN              N           NaN
# 24                                      NaN              N           NaN
# ...                                     ...            ...           ...
# 128387                                  NaN              N           NaN
# 128388                                  NaN              N           NaN
# 128389                                  NaN              N           NaN
# 128390                                 75.0              N           NaN
# 128391                                  NaN              N           NaN
# 128392                                  NaN              N           NaN
# 128393                                 58.0              N           NaN
# 128394                                 13.0              N           NaN
# 128395                                  NaN              N           NaN
# 128396                                  NaN              N           NaN
# 128397                                  NaN              N           NaN
# 128398                                  NaN              N           NaN
# 128399                                  NaN              N           NaN
# 128400                                  NaN              N           NaN
# 128401                                  NaN              N           NaN
# 128402                                  NaN              N           NaN
# 128403                                  NaN              N           NaN
# 128404                                  NaN              N           NaN
# 128405                                  NaN              N           NaN
# 128406                                  NaN              N           NaN
# 128407                                  NaN              N           NaN
# 128408                                  NaN              N           NaN
# 128409                                  NaN              N           NaN
# 128410                                  NaN              N           NaN
# 128411                                  NaN              N           NaN
#
#         hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0                   NaN             NaN            NaN              NaN
# 1                   NaN             NaN            NaN              NaN
# 2                   NaN             NaN            NaN              NaN
# 3                   NaN             NaN            NaN              NaN
# 4                   NaN             NaN            NaN              NaN
# 5                   NaN             NaN            NaN              NaN
# 6                   NaN             NaN            NaN              NaN
# 7                   NaN             NaN            NaN              NaN
# 8                   NaN             NaN            NaN              NaN
# 9                   NaN             NaN            NaN              NaN
# 10                  NaN             NaN            NaN              NaN
# 11                  NaN             NaN            NaN              NaN
# 12                  NaN             NaN            NaN              NaN
# 13                  NaN             NaN            NaN              NaN
# 14                  NaN             NaN            NaN              NaN
# 15                  NaN             NaN            NaN              NaN
# 16                  NaN             NaN            NaN              NaN
# 17                  NaN             NaN            NaN              NaN
# 18                  NaN             NaN            NaN              NaN
# 19                  NaN             NaN            NaN              NaN
# 20                  NaN             NaN            NaN              NaN
# 21                  NaN             NaN            NaN              NaN
# 22                  NaN             NaN            NaN              NaN
# 23                  NaN             NaN            NaN              NaN
# 24                  NaN             NaN            NaN              NaN
# ...                 ...             ...            ...              ...
# 128387              NaN             NaN            NaN              NaN
# 128388              NaN             NaN            NaN              NaN
# 128391                            NaN                           NaN
# 128392                            NaN                           NaN
# 128393                            NaN                           NaN
# 128394                            NaN                           NaN
# 128395                            NaN                           NaN
# 128396                            NaN                           NaN
# 128397                            NaN                           NaN
# 128398                            NaN                           NaN
# 128399                            NaN                           NaN
# 128400                            NaN                           NaN
# 128401                            NaN                           NaN
# 128402                            NaN                           NaN
# 128403                            NaN                           NaN
# 128404                            NaN                           NaN
# 128405                            NaN                           NaN
# 128406                            NaN                           NaN
# 128407                            NaN                           NaN
# 128408                            NaN                           NaN
# 128409                            NaN                           NaN
# 128410                            NaN                           NaN
# 128411                            NaN                           NaN
#
#        debt_settlement_flag debt_settlement_flag_date  settlement_status  \
# 0                         N                       NaN                NaN
# 1                         N                       NaN                NaN
# 2                         N                       NaN                NaN
# 3                         N                       NaN                NaN
# 4                         N                       NaN                NaN
# 5                         N                       NaN                NaN
# 6                         N                       NaN                NaN
# 7                         N                       NaN                NaN
# 8                         N                       NaN                NaN
# 9                         N                       NaN                NaN
# 10                        N                       NaN                NaN
# 11                        N                       NaN                NaN
# 12                        N                       NaN                NaN
# 13                        N                       NaN                NaN
# 14                        N                       NaN                NaN
# 15                        N                       NaN                NaN
# 16                        N                       NaN                NaN
# 17                        N                       NaN                NaN
# 18                        N                       NaN                NaN
# 19                        N                       NaN                NaN
# 20                        N                       NaN                NaN
# 21                        N                       NaN                NaN
# 22                        N                       NaN                NaN
# 23                        N                       NaN                NaN
# 24                        N                       NaN                NaN
# ...                     ...                       ...                ...
# 128387                    N                       NaN                NaN
# 128388                    N                       NaN                NaN
# 128389                    N                       NaN                NaN
# 128390                    N                       NaN                NaN
# 128391                    N                       NaN                NaN
# 128392                    N                       NaN                NaN
# 128393                    N                       NaN                NaN
# 128394                    N                       NaN                NaN
# 128395                    N                       NaN                NaN
# 128396                    N                       NaN                NaN
# 128397                    N                       NaN                NaN
# 128398                    N                       NaN                NaN
# 128399                    N                       NaN                NaN
# 128400                    N                       NaN                NaN
# 128401                    N                       NaN                NaN
# 128402                    N                       NaN                NaN
# 128403                    N                       NaN                NaN
# 128404                    N                       NaN                NaN
# 128405                    N                       NaN                NaN
# 128406                    N                       NaN                NaN
# 128407                    N                       NaN                NaN
# 128408                    N                       NaN                NaN
# 128409                    N                       NaN                NaN
# 128410                    N                       NaN                NaN
# 128411                    N                       NaN                NaN
#
#         settlement_date  settlement_amount settlement_percentage  \
# 0                   NaN                NaN                   NaN
# 1                   NaN                NaN                   NaN
# 2                   NaN                NaN                   NaN
# 3                   NaN                NaN                   NaN
# 4                   NaN                NaN                   NaN
# 5                   NaN                NaN                   NaN
# 6                   NaN                NaN                   NaN
# 7                   NaN                NaN                   NaN
# 8                   NaN                NaN                   NaN
# 9                   NaN                NaN                   NaN
# 10                  NaN                NaN                   NaN
# 11                  NaN                NaN                   NaN
# 12                  NaN                NaN                   NaN
# 13                  NaN                NaN                   NaN
# 14                  NaN                NaN                   NaN
# 15                  NaN                NaN                   NaN
# 16                  NaN                NaN                   NaN
# 17                  NaN                NaN                   NaN
# 18                  NaN                NaN                   NaN
# 19                  NaN                NaN                   NaN
# 20                  NaN                NaN                   NaN
# 21                  NaN                NaN                   NaN
# 22                  NaN                NaN                   NaN
# 23                  NaN                NaN                   NaN
# 24                  NaN                NaN                   NaN
# ...                 ...                ...                   ...
# 128387              NaN                NaN                   NaN
# 128388              NaN                NaN                   NaN
# 128389              NaN                NaN                   NaN
# 128390              NaN                NaN                   NaN
# 128391              NaN                NaN                   NaN
# 128392              NaN                NaN                   NaN
# 128393              NaN                NaN                   NaN
# 128394              NaN                NaN                   NaN
# 128395              NaN                NaN                   NaN
# 128396              NaN                NaN                   NaN
# 128397              NaN                NaN                   NaN
# 128398              NaN                NaN                   NaN
# 128399              NaN                NaN                   NaN
# 128400              NaN                NaN                   NaN
# 128401              NaN                NaN                   NaN
# 128402              NaN                NaN                   NaN
# 128403              NaN                NaN                   NaN
# 128404              NaN                NaN                   NaN
# 128405              NaN                NaN                   NaN
# 128406              NaN                NaN                   NaN
# 128407              NaN                NaN                   NaN
# 128408              NaN                NaN                   NaN
# 128409              NaN                NaN                   NaN
# 128410              NaN                NaN                   NaN
# 128411              NaN                NaN                   NaN
#
#         settlement_term
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# ...                 ...
# 128387              NaN
# 128388              NaN
# 128389              NaN
# 128390              NaN
# 128391              NaN
# 128392              NaN
# 128393              NaN
# 128394              NaN
# 128395              NaN
# 128396              NaN
# 128397              NaN
# 128398              NaN
# 128399              NaN
# 128400              NaN
# 128401              NaN
# 128402              NaN
# 128403              NaN
# 128404              NaN
# 128405              NaN
# 128406              NaN
# 128407              NaN
# 128408              NaN
# 128409              NaN
# 128410              NaN
# 128411              NaN
#
# [128412 rows x 140 columns]

# %%
df = df.drop(columns=['id', 'member_id', 'desc', 'url'])

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   36 months   10.33%       324.23
# 1       4000         4000           4000.0   36 months   23.40%       155.68
# 2       5000         5000           5000.0   36 months   17.97%       180.69
# 3      23000        23000          23000.0   60 months   20.89%       620.81
# 4       8000         8000           8000.0   36 months   23.40%       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# 0        Not Verified  Dec-2018             Current          n
# 1     Source Verified  Dec-2018             Current          n
# 2     Source Verified  Dec-2018  Late (31-120 days)          n
# 3     Source Verified  Dec-2018             Current          n
# 4     Source Verified  Dec-2018             Current          n
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    974xx         OR   6.15
# 1  debt_consolidation  Debt consolidation    070xx         NJ  26.33
# 2  debt_consolidation  Debt consolidation    490xx         MI  10.51
# 3  debt_consolidation  Debt consolidation    672xx         KS   0.52
# 4  debt_consolidation  Debt consolidation    357xx         AL  33.24
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  ...  \
# 0            2         Jan-1996               0                    18.0  ...
# 1            0         Sep-2006               4                    59.0  ...
# 2            0         Apr-2011               0                     NaN  ...
# 3            0         Feb-1997               0                     NaN  ...
# 4            0         Jan-1995               0                     NaN  ...
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog  hardship_flag hardship_type  \
# 0                                  NaN              N           NaN
# 1                                  NaN              N           NaN
# 2                                  NaN              N           NaN
# 3                                  NaN              N           NaN
# 4                                  NaN              N           NaN
#
#    hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0              NaN             NaN            NaN              NaN
# 1              NaN             NaN            NaN              NaN
# 2              NaN             NaN            NaN              NaN
# 3              NaN             NaN            NaN              NaN
# 4              NaN             NaN            NaN              NaN
#
#    hardship_start_date  hardship_end_date  payment_plan_start_date  \
# 0                  NaN                NaN                      NaN
# 1                  NaN                NaN                      NaN
# 2                  NaN                NaN                      NaN
# 3                  NaN                NaN                      NaN
# 4                  NaN                NaN                      NaN
#
#    hardship_length  hardship_dpd  hardship_loan_status  \
# 0              NaN           NaN                   NaN
# 1              NaN           NaN                   NaN
# 2              NaN           NaN                   NaN
# 3              NaN           NaN                   NaN
# 4              NaN           NaN                   NaN
#
#    orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                         NaN                            NaN
# 1                                         NaN                            NaN
# 2                                         NaN                            NaN
# 3                                         NaN                            NaN
# 4                                         NaN                            NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date  settlement_status  settlement_date  \
# 0                       NaN                NaN              NaN
# 1                       NaN                NaN              NaN
# 2                       NaN                NaN              NaN
# 3                       NaN                NaN              NaN
# 4                       NaN                NaN              NaN
#
#    settlement_amount settlement_percentage  settlement_term
# 0                NaN                   NaN              NaN
# 1                NaN                   NaN              NaN
# 2                NaN                   NaN              NaN
# 3                NaN                   NaN              NaN
# 4                NaN                   NaN              NaN
#
# [5 rows x 140 columns]

# %%
hardship_cols = [col for col in df.columns if col.startswith('hardship_')]

# %%
hardship_cols
# Out:
# ['hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount']

# %%
df.shape
# Out:
# (128412, 140)

# %%
df = df.drop(columns=hardship_cols)

# %%
df.shape
# Out:
# (128412, 128)

# %%
df.describe(exclude='number')
# Out:
#               term int_rate   grade sub_grade emp_title emp_length  \
# count       128412   128412  128412    128412    107465     116708
# unique           2       46       7        35     43892         11
# top      36 months   13.56%       A        A4   Teacher  10+ years
# freq         88179     6974   38011      9770      2090      38826
#
#        home_ownership verification_status   issue_d loan_status pymnt_plan  \
# count          128412              128412    128412      128412     128412
# unique              4                   3         3           7          2
# top          MORTGAGE        Not Verified  Oct-2018     Current          n
# freq            63490               58350     46305      108584     128398
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# freq                 70603               70603     1370      17879
#
#        earliest_cr_line revol_util initial_list_status last_pymnt_d  \
# count            128412     128256              128412       128253
# unique              644       1074                   2           12
# top            Aug-2006         0%                   w     Aug-2019
# freq               1130       1132              114498       105424
#
#        next_pymnt_d last_credit_pull_d application_type  \
# count        112289             128411           128412
# unique            3                 12                2
# top        Sep-2019           Aug-2019       Individual
# freq         112228             117910           111630
#
#        verification_status_joint sec_app_earliest_cr_line  \
# count                      14848                    16782
# unique                         3                      573
# top                 Not Verified                 Aug-2006
# freq                        6360                      155
#
#        payment_plan_start_date debt_settlement_flag debt_settlement_flag_date  \
# count                       27               128412                       111
# unique                       3                    2                         6
# top                   Aug-2019                    N                  Aug-2019
# freq                        15               128301                        48
#
#        settlement_status settlement_date
# count                111             111
# unique                 3               7
# top               ACTIVE        Jul-2019
# freq                  99              43

# %%
df.describe(exclude='category')
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv        term int_rate  \
# count   128412.000000  128412.000000    128412.000000      128412   128412
# unique            NaN            NaN              NaN           2       46
# top               NaN            NaN              NaN   36 months   13.56%
# freq              NaN            NaN              NaN       88179     6974
# mean     15971.321021   15971.321021     15968.498166         NaN      NaN
# std      10150.384233   10150.384233     10152.168970         NaN      NaN
# min       1000.000000    1000.000000       725.000000         NaN      NaN
# 25%       8000.000000    8000.000000      8000.000000         NaN      NaN
# 50%      14000.000000   14000.000000     14000.000000         NaN      NaN
# 75%      21600.000000   21600.000000     21600.000000         NaN      NaN
# max      40000.000000   40000.000000     40000.000000         NaN      NaN
#
#           installment   grade sub_grade emp_title emp_length home_ownership  \
# count   128412.000000  128412    128412    107465     116708         128412
# unique            NaN       7        35     43892         11              4
# top               NaN       A        A4   Teacher  10+ years       MORTGAGE
# freq              NaN   38011      9770      2090      38826          63490
# mean       463.254376     NaN       NaN       NaN        NaN            NaN
# std        285.718332     NaN       NaN       NaN        NaN            NaN
# min         30.480000     NaN       NaN       NaN        NaN            NaN
# 25%        253.630000     NaN       NaN       NaN        NaN            NaN
# 50%        382.905000     NaN       NaN       NaN        NaN            NaN
# 75%        622.680000     NaN       NaN       NaN        NaN            NaN
# max       1618.240000     NaN       NaN       NaN        NaN            NaN
#
#           annual_inc verification_status   issue_d loan_status pymnt_plan  \
# count   1.284120e+05              128412    128412      128412     128412
# unique           NaN                   3         3           7          2
# top              NaN        Not Verified  Oct-2018     Current          n
# freq             NaN               58350     46305      108584     128398
# mean    8.279733e+04                 NaN       NaN         NaN        NaN
# std     1.082985e+05                 NaN       NaN         NaN        NaN
# min     0.000000e+00                 NaN       NaN         NaN        NaN
# 25%     4.705800e+04                 NaN       NaN         NaN        NaN
# 50%     6.800000e+04                 NaN       NaN         NaN        NaN
# 75%     9.900000e+04                 NaN       NaN         NaN        NaN
# max     9.757200e+06                 NaN       NaN         NaN        NaN
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# freq                 70603               70603     1370      17879
# mean                   NaN                 NaN      NaN        NaN
# std                    NaN                 NaN      NaN        NaN
# min                    NaN                 NaN      NaN        NaN
# 25%                    NaN                 NaN      NaN        NaN
# 50%                    NaN                 NaN      NaN        NaN
# 75%                    NaN                 NaN      NaN        NaN
# max                    NaN                 NaN      NaN        NaN
#
#                   dti    delinq_2yrs earliest_cr_line  inq_last_6mths  \
# count   128175.000000  128412.000000           128412   128412.000000
# unique            NaN            NaN              644             NaN
# top               NaN            NaN         Aug-2006             NaN
# freq              NaN            NaN             1130             NaN
# mean        19.933178       0.227837              NaN        0.447038
# std         20.143542       0.733793              NaN        0.734480
# min          0.000000       0.000000              NaN        0.000000
# 25%         11.760000       0.000000              NaN        0.000000
# 50%         17.990000       0.000000              NaN        0.000000
# 75%         25.300000       0.000000              NaN        1.000000
# max        999.000000      24.000000              NaN        5.000000
#
#         mths_since_last_delinq  ...  tot_hi_cred_lim  total_bal_ex_mort  \
# count             56216.000000  ...     1.284120e+05       1.284120e+05
# unique                     NaN  ...              NaN                NaN
# top                        NaN  ...              NaN                NaN
# freq                       NaN  ...              NaN                NaN
# mean                 36.880337  ...     1.884852e+05       5.356097e+04
# std                  21.813805  ...     1.965536e+05       5.599335e+04
# min                   0.000000  ...     0.000000e+00       0.000000e+00
# 25%                  19.000000  ...     5.315975e+04       2.009100e+04
# 50%                  34.000000  ...     1.177000e+05       3.846900e+04
# 75%                  53.000000  ...     2.736065e+05       6.804125e+04
# max                 160.000000  ...     9.999999e+06       2.622906e+06
#
#         total_bc_limit  total_il_high_credit_limit revol_bal_joint  \
# count    128412.000000                1.284120e+05    1.678200e+04
# unique             NaN                         NaN             NaN
# top                NaN                         NaN             NaN
# freq               NaN                         NaN             NaN
# mean      27439.534163                4.682180e+04    3.664280e+04
# std       26377.282557                4.957491e+04    3.252566e+04
# min           0.000000                0.000000e+00    0.000000e+00
# 25%       10100.000000                1.500000e+04    1.610400e+04
# 50%       19800.000000                3.460500e+04    2.858500e+04
# 75%       36100.000000                6.328950e+04    4.722875e+04
# max      666200.000000                2.118996e+06    1.110019e+06
#
#         sec_app_earliest_cr_line sec_app_inq_last_6mths  sec_app_mort_acc  \
# count                      16782           16782.000000      16782.000000
# unique                       573                    NaN               NaN
# top                     Aug-2006                    NaN               NaN
# freq                         155                    NaN               NaN
# mean                         NaN               0.585985          1.587177
# std                          NaN               0.936053          1.801878
# min                          NaN               0.000000          0.000000
# 25%                          NaN               0.000000          0.000000
# 50%                          NaN               0.000000          1.000000
# 75%                          NaN               1.000000          3.000000
# max                          NaN               6.000000         15.000000
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# count       16782.000000        16524.000000         16782.000000
# unique               NaN                 NaN                  NaN
# top                  NaN                 NaN                  NaN
# freq                 NaN                 NaN                  NaN
# mean           11.436003           55.878831             3.027112
# std             6.690119           26.071241             3.254318
# min             0.000000            0.000000             0.000000
# 25%             7.000000           36.400000             1.000000
# 50%            10.000000           57.500000             2.000000
# 75%            15.000000           76.900000             4.000000
# max            67.000000          170.100000            34.000000
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# count            16782.000000                      16782.000000
# unique                    NaN                               NaN
# top                       NaN                               NaN
# freq                      NaN                               NaN
# mean                12.423907                          0.036170
# std                  8.190067                          0.347726
# min                  0.000000                          0.000000
# 25%                  7.000000                          0.000000
# 50%                 11.000000                          0.000000
# 75%                 16.000000                          0.000000
# max                 95.000000                         21.000000
#
#         sec_app_collections_12_mths_ex_med  \
# count                         16782.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                              0.062984
# std                               0.364083
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              15.000000
#
#         sec_app_mths_since_last_major_derog  deferral_term  \
# count                           5154.000000           27.0
# unique                                  NaN            NaN
# top                                     NaN            NaN
# freq                                    NaN            NaN
# mean                              38.515910            3.0
# std                               23.659436            0.0
# min                                0.000000            3.0
# 25%                               19.000000            3.0
# 50%                               37.000000            3.0
# 75%                               58.000000            3.0
# max                              153.000000            3.0
#
#        payment_plan_start_date  orig_projected_additional_accrued_interest  \
# count                       27                                   26.000000
# unique                       3                                         NaN
# top                   Aug-2019                                         NaN
# freq                        15                                         NaN
# mean                       NaN                                  654.789231
# std                        NaN                                  370.729150
# min                        NaN                                   83.280000
# 25%                        NaN                                  438.135000
# 50%                        NaN                                  582.030000
# 75%                        NaN                                  872.205000
# max                        NaN                                 1662.030000
#
#        debt_settlement_flag debt_settlement_flag_date  settlement_status  \
# count                128412                       111                111
# unique                    2                         6                  3
# top                       N                  Aug-2019             ACTIVE
# freq                 128301                        48                 99
# mean                    NaN                       NaN                NaN
# std                     NaN                       NaN                NaN
# min                     NaN                       NaN                NaN
# 25%                     NaN                       NaN                NaN
# 50%                     NaN                       NaN                NaN
# 75%                     NaN                       NaN                NaN
# max                     NaN                       NaN                NaN
#
#         settlement_date  settlement_amount settlement_percentage  \
# count               111         111.000000            111.000000
# unique                7                NaN                   NaN
# top            Jul-2019                NaN                   NaN
# freq                 43                NaN                   NaN
# mean                NaN        7330.395946             53.095495
# std                 NaN        4682.992392             10.260846
# min                 NaN         696.450000             40.000000
# 25%                 NaN        3956.500000             45.000000
# 50%                 NaN        6596.390000             50.000000
# 75%                 NaN        9502.000000             60.000000
# max                 NaN       22161.000000             98.240000
#
#         settlement_term
# count        111.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean          18.045045
# std            6.577354
# min            1.000000
# 25%           14.000000
# 50%           18.000000
# 75%           24.000000
# max           24.000000
#
# [11 rows x 128 columns]

# %%
df['int_rate']
# Out:
# 0          10.33%
# 1          23.40%
# 2          17.97%
# 3          20.89%
# 4          23.40%
# 5          11.80%
# 6          12.98%
# 7          18.94%
# 8          13.56%
# 9          13.56%
# 10         19.92%
# 11         17.97%
# 12         26.31%
# 13         14.47%
# 14         23.40%
# 15         23.40%
# 16         20.89%
# 17         16.91%
# 18         20.89%
# 19         14.47%
# 20         13.56%
# 21         14.47%
# 22         12.98%
# 23         23.40%
# 24         11.80%
#            ...
# 128387     11.55%
# 128388      8.46%
# 128389     11.55%
# 128390     19.92%
# 128391      6.67%
# 128392     26.31%
# 128393     16.91%
# 128394      6.11%
# 128395     11.55%
# 128396     15.02%
# 128397     15.02%
# 128398     18.94%
# 128399     15.02%
# 128400     15.02%
# 128401     11.55%
# 128402     22.35%
# 128403     16.14%
# 128404     16.14%
# 128405      7.84%
# 128406     13.56%
# 128407     15.02%
# 128408     15.02%
# 128409     13.56%
# 128410     11.06%
# 128411     16.91%
# Name: int_rate, Length: 128412, dtype: object

# %%
a = '16.91%'
a[:-1]
# Out:
# '16.91'

# %%
a.strip('%')
# Out:
# '16.91'

# %%
float(a.replace('%', ''))
# Out:
# 16.91

# %%
def remove_percent_to_float(x):
  try:
    return float(x[:-1])
  except: 
    return float(x)

# %%
remove_percent_to_float('16.91%')
# Out:
# 16.91

# %%
df['int_rate'].value_counts(dropna=False)
# Out:
#  13.56%    6974
#  15.02%    6767
#  14.47%    6103
#  16.14%    5637
#   8.19%    5554
#  16.91%    5524
#  11.80%    4983
#   6.11%    4639
#  17.97%    4287
#   7.84%    4212
#   8.81%    4192
#  11.55%    4049
#   6.46%    4030
#  10.72%    4003
#  18.94%    3955
#  12.98%    3873
#  19.92%    3717
#   8.46%    3602
#  10.33%    3495
#  10.47%    3477
#  12.73%    3219
#   7.21%    3133
#  20.89%    3066
#  11.31%    3028
#  10.08%    2989
#   6.67%    2914
#   7.56%    2907
#   7.02%    2822
#  11.06%    2738
#  22.35%    2046
#  23.40%    1848
#  27.27%    1314
#  25.34%    1005
#  24.37%     907
#  26.31%     886
#  28.72%     170
#  29.69%      94
#  30.17%      51
#  30.79%      46
#  30.65%      38
#  30.75%      34
#  30.84%      32
#   6.00%      29
#  30.94%       8
#  30.89%       8
#  30.99%       7
# Name: int_rate, dtype: int64

# %%
a = ['16.91%', '12.23%', '15.75%']
[remove_percent_to_float(i) for i in a]
# Out:
# [16.91, 12.23, 15.75]

# %%
df['int_rate'] = df['int_rate'].apply(remove_percent_to_float)

# %%
df['int_rate'].dtype
# Out:
# dtype('float64')

# %%
df['int_rate']
# Out:
# 0         10.33
# 1         23.40
# 2         17.97
# 3         20.89
# 4         23.40
# 5         11.80
# 6         12.98
# 7         18.94
# 8         13.56
# 9         13.56
# 10        19.92
# 11        17.97
# 12        26.31
# 13        14.47
# 14        23.40
# 15        23.40
# 16        20.89
# 17        16.91
# 18        20.89
# 19        14.47
# 20        13.56
# 21        14.47
# 22        12.98
# 23        23.40
# 24        11.80
#           ...
# 128387    11.55
# 128388     8.46
# 128389    11.55
# 128390    19.92
# 128391     6.67
# 128392    26.31
# 128393    16.91
# 128394     6.11
# 128395    11.55
# 128396    15.02
# 128397    15.02
# 128398    18.94
# 128399    15.02
# 128400    15.02
# 128401    11.55
# 128402    22.35
# 128403    16.14
# 128404    16.14
# 128405     7.84
# 128406    13.56
# 128407    15.02
# 128408    15.02
# 128409    13.56
# 128410    11.06
# 128411    16.91
# Name: int_rate, Length: 128412, dtype: float64

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# 0        Not Verified  Dec-2018             Current          n
# 1     Source Verified  Dec-2018             Current          n
# 2     Source Verified  Dec-2018  Late (31-120 days)          n
# 3     Source Verified  Dec-2018             Current          n
# 4     Source Verified  Dec-2018             Current          n
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    974xx         OR   6.15
# 1  debt_consolidation  Debt consolidation    070xx         NJ  26.33
# 2  debt_consolidation  Debt consolidation    490xx         MI  10.51
# 3  debt_consolidation  Debt consolidation    672xx         KS   0.52
# 4  debt_consolidation  Debt consolidation    357xx         AL  33.24
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  ...  \
# 0            2         Jan-1996               0                    18.0  ...
# 1            0         Sep-2006               4                    59.0  ...
# 2            0         Apr-2011               0                     NaN  ...
# 3            0         Feb-1997               0                     NaN  ...
# 4            0         Jan-1995               0                     NaN  ...
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0           367828              61364           20900
# 1            98655              66926           21900
# 2           136927              11749           13800
# 3             7500                976            3300
# 4           199744              31078            2300
#
#    total_il_high_credit_limit revol_bal_joint  sec_app_earliest_cr_line  \
# 0                       54912             NaN                       NaN
# 1                       71555             NaN                       NaN
# 2                       10000             NaN                       NaN
# 3                           0             NaN                       NaN
# 4                       32206             NaN                       NaN
#
#   sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                 NaN                  NaN                    NaN
# 2                 NaN                  NaN                    NaN
# 3                 NaN                  NaN                    NaN
# 4                 NaN                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog  deferral_term payment_plan_start_date  \
# 0                                  NaN            NaN                     NaN
# 1                                  NaN            NaN                     NaN
# 2                                  NaN            NaN                     NaN
# 3                                  NaN            NaN                     NaN
# 4                                  NaN            NaN                     NaN
#
#    orig_projected_additional_accrued_interest debt_settlement_flag  \
# 0                                         NaN                    N
# 1                                         NaN                    N
# 2                                         NaN                    N
# 3                                         NaN                    N
# 4                                         NaN                    N
#
#   debt_settlement_flag_date  settlement_status  settlement_date  \
# 0                       NaN                NaN              NaN
# 1                       NaN                NaN              NaN
# 2                       NaN                NaN              NaN
# 3                       NaN                NaN              NaN
# 4                       NaN                NaN              NaN
#
#    settlement_amount settlement_percentage  settlement_term
# 0                NaN                   NaN              NaN
# 1                NaN                   NaN              NaN
# 2                NaN                   NaN              NaN
# 3                NaN                   NaN              NaN
# 4                NaN                   NaN              NaN
#
# [5 rows x 128 columns]

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
df.describe(exclude='number')
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       128412  128412    128412    107465     116708         128412
# unique           2       7        35     43892         11              4
# top      36 months       A        A4   Teacher  10+ years       MORTGAGE
# freq         88179   38011      9770      2090      38826          63490
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               128412    128412      128412     128412
# unique                   3         3           7          2
# top           Not Verified  Oct-2018     Current          n
# freq                 58350     46305      108584     128398
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# freq                 70603               70603     1370      17879
#
#        earliest_cr_line revol_util initial_list_status last_pymnt_d  \
# count            128412     128256              128412       128253
# unique              644       1074                   2           12
# top            Aug-2006         0%                   w     Aug-2019
# freq               1130       1132              114498       105424
#
#        next_pymnt_d last_credit_pull_d application_type  \
# count        112289             128411           128412
# unique            3                 12                2
# top        Sep-2019           Aug-2019       Individual
# freq         112228             117910           111630
#
#        verification_status_joint sec_app_earliest_cr_line  \
# count                      14848                    16782
# unique                         3                      573
# top                 Not Verified                 Aug-2006
# freq                        6360                      155
#
#        payment_plan_start_date debt_settlement_flag debt_settlement_flag_date  \
# count                       27               128412                       111
# unique                       3                    2                         6
# top                   Aug-2019                    N                  Aug-2019
# freq                        15               128301                        48
#
#        settlement_status settlement_date
# count                111             111
# unique                 3               7
# top               ACTIVE        Jul-2019
# freq                  99              43

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().lower()
  else:
    return 'unknown'

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# unknown               20947
# teacher                2557
# manager                2395
# registered nurse       1418
# driver                 1258
# supervisor             1160
# truck driver            920
# rn                      834
# office manager          805
# sales                   803
# general manager         791
# project manager         720
# owner                   625
# director                523
# operations manager      518
# sales manager           500
# police officer          440
# nurse                   425
# technician              420
# engineer                412
# Name: emp_title, dtype: int64

# %%
type(np.NaN)
# Out:
# float

# %% [markdown]
# ## Clean emp_title_manager

# %%
df['emp_title_manager'] = df['emp_title'].str.contains('manager')

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'payment_plan_start_date', 'orig_projected_additional_accrued_interest',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'emp_title_manager'],
#       dtype='object', length=129)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        security    3 years           RENT     90000.0
# 2     D        D1  administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        operator    5 years           RENT     68107.0
# 4     E        E1         manager  10+ years            OWN     43000.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# 0        Not Verified  Dec-2018             Current          n
# 1     Source Verified  Dec-2018             Current          n
# 2     Source Verified  Dec-2018  Late (31-120 days)          n
# 3     Source Verified  Dec-2018             Current          n
# 4     Source Verified  Dec-2018             Current          n
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    974xx         OR   6.15
# 1  debt_consolidation  Debt consolidation    070xx         NJ  26.33
# 2  debt_consolidation  Debt consolidation    490xx         MI  10.51
# 3  debt_consolidation  Debt consolidation    672xx         KS   0.52
# 4  debt_consolidation  Debt consolidation    357xx         AL  33.24
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  ...  \
# 0            2         Jan-1996               0                    18.0  ...
# 1            0         Sep-2006               4                    59.0  ...
# 2            0         Apr-2011               0                     NaN  ...
# 3            0         Feb-1997               0                     NaN  ...
# 4            0         Jan-1995               0                     NaN  ...
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0              61364           20900                       54912
# 1              66926           21900                       71555
# 2              11749           13800                       10000
# 3                976            3300                           0
# 4              31078            2300                       32206
#
#    revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1              NaN                      NaN                     NaN
# 2              NaN                      NaN                     NaN
# 3              NaN                      NaN                     NaN
# 4              NaN                      NaN                     NaN
#
#   sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0              NaN               NaN                 NaN                  NaN
# 1              NaN               NaN                 NaN                  NaN
# 2              NaN               NaN                 NaN                  NaN
# 3              NaN               NaN                 NaN                  NaN
# 4              NaN               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    deferral_term  payment_plan_start_date  \
# 0            NaN                      NaN
# 1            NaN                      NaN
# 2            NaN                      NaN
# 3            NaN                      NaN
# 4            NaN                      NaN
#
#   orig_projected_additional_accrued_interest  debt_settlement_flag  \
# 0                                        NaN                     N
# 1                                        NaN                     N
# 2                                        NaN                     N
# 3                                        NaN                     N
# 4                                        NaN                     N
#
#   debt_settlement_flag_date settlement_status  settlement_date  \
# 0                       NaN               NaN              NaN
# 1                       NaN               NaN              NaN
# 2                       NaN               NaN              NaN
# 3                       NaN               NaN              NaN
# 4                       NaN               NaN              NaN
#
#    settlement_amount  settlement_percentage settlement_term  emp_title_manager
# 0                NaN                    NaN             NaN              False
# 1                NaN                    NaN             NaN              False
# 2                NaN                    NaN             NaN              False
# 3                NaN                    NaN             NaN              False
# 4                NaN                    NaN             NaN               True
#
# [5 rows x 129 columns]

# %%
mask = df['emp_title_manager'] == True
managers = df[mask]
plebians = df[~mask]

# %%
managers.shape[0]
# Out:
# 17885

# %%
plebians.shape[0]
# Out:
# 110527

# %%
df.shape[0]
# Out:
# 128412

# %%
assert managers.shape[0] + plebians.shape[0]  == df.shape[0]

# this code shows that plebians and managers are equal to total df by 
# not coming up with an error once ran

# %% [markdown]
# ## Work with dates

# %%
df['issue_d']
# Out:
# 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
# 5         Dec-2018
# 6         Dec-2018
# 7         Dec-2018
# 8         Dec-2018
# 9         Dec-2018
# 10        Dec-2018
# 11        Dec-2018
# 12        Dec-2018
# 13        Dec-2018
# 14        Dec-2018
# 15        Dec-2018
# 16        Dec-2018
# 17        Dec-2018
# 18        Dec-2018
# 19        Dec-2018
# 20        Dec-2018
# 21        Dec-2018
# 22        Dec-2018
# 23        Dec-2018
# 24        Dec-2018
#             ...
# 128387    Oct-2018
# 128388    Oct-2018
# 128389    Oct-2018
# 128390    Oct-2018
# 128391    Oct-2018
# 128392    Oct-2018
# 128393    Oct-2018
# 128394    Oct-2018
# 128395    Oct-2018
# 128396    Oct-2018
# 128397    Oct-2018
# 128398    Oct-2018
# 128399    Oct-2018
# 128400    Oct-2018
# 128401    Oct-2018
# 128402    Oct-2018
# 128403    Oct-2018
# 128404    Oct-2018
# 128405    Oct-2018
# 128406    Oct-2018
# 128407    Oct-2018
# 128408    Oct-2018
# 128409    Oct-2018
# 128410    Oct-2018
# 128411    Oct-2018
# Name: issue_d, Length: 128412, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_d']
# Out:
# 0        2018-12-01
# 1        2018-12-01
# 2        2018-12-01
# 3        2018-12-01
# 4        2018-12-01
# 5        2018-12-01
# 6        2018-12-01
# 7        2018-12-01
# 8        2018-12-01
# 9        2018-12-01
# 10       2018-12-01
# 11       2018-12-01
# 12       2018-12-01
# 13       2018-12-01
# 14       2018-12-01
# 15       2018-12-01
# 16       2018-12-01
# 17       2018-12-01
# 18       2018-12-01
# 19       2018-12-01
# 20       2018-12-01
# 21       2018-12-01
# 22       2018-12-01
# 23       2018-12-01
# 24       2018-12-01
#             ...
# 128387   2018-10-01
# 128388   2018-10-01
# 128389   2018-10-01
# 128390   2018-10-01
# 128391   2018-10-01
# 128392   2018-10-01
# 128393   2018-10-01
# 128394   2018-10-01
# 128395   2018-10-01
# 128396   2018-10-01
# 128397   2018-10-01
# 128398   2018-10-01
# 128399   2018-10-01
# 128400   2018-10-01
# 128401   2018-10-01
# 128402   2018-10-01
# 128403   2018-10-01
# 128404   2018-10-01
# 128405   2018-10-01
# 128406   2018-10-01
# 128407   2018-10-01
# 128408   2018-10-01
# 128409   2018-10-01
# 128410   2018-10-01
# 128411   2018-10-01
# Name: issue_d, Length: 128412, dtype: datetime64[ns]

# %%
df['issue_d'].dt.weekday
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# 5         5
# 6         5
# 7         5
# 8         5
# 9         5
# 10        5
# 11        5
# 12        5
# 13        5
# 14        5
# 15        5
# 16        5
# 17        5
# 18        5
# 19        5
# 20        5
# 21        5
# 22        5
# 23        5
# 24        5
#          ..
# 128387    0
# 128388    0
# 128389    0
# 128390    0
# 128391    0
# 128392    0
# 128393    0
# 128394    0
# 128395    0
# 128396    0
# 128397    0
# 128398    0
# 128399    0
# 128400    0
# 128401    0
# 128402    0
# 128403    0
# 128404    0
# 128405    0
# 128406    0
# 128407    0
# 128408    0
# 128409    0
# 128410    0
# 128411    0
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        security    3 years           RENT     90000.0
# 2     D        D1  administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        operator    5 years           RENT     68107.0
# 4     E        E1         manager  10+ years            OWN     43000.0
#
#   verification_status    issue_d         loan_status pymnt_plan  \
# 0        Not Verified 2018-12-01             Current          n
# 1     Source Verified 2018-12-01             Current          n
# 2     Source Verified 2018-12-01  Late (31-120 days)          n
# 3     Source Verified 2018-12-01             Current          n
# 4     Source Verified 2018-12-01             Current          n
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    974xx         OR   6.15
# 1  debt_consolidation  Debt consolidation    070xx         NJ  26.33
# 2  debt_consolidation  Debt consolidation    490xx         MI  10.51
# 3  debt_consolidation  Debt consolidation    672xx         KS   0.52
# 4  debt_consolidation  Debt consolidation    357xx         AL  33.24
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  ...  \
# 0            2         Jan-1996               0                    18.0  ...
# 1            0         Sep-2006               4                    59.0  ...
# 2            0         Apr-2011               0                     NaN  ...
# 3            0         Feb-1997               0                     NaN  ...
# 4            0         Jan-1995               0                     NaN  ...
#
#    total_il_high_credit_limit  revol_bal_joint  sec_app_earliest_cr_line  \
# 0                       54912              NaN                       NaN
# 1                       71555              NaN                       NaN
# 2                       10000              NaN                       NaN
# 3                           0              NaN                       NaN
# 4                       32206              NaN                       NaN
#
#    sec_app_inq_last_6mths sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN              NaN               NaN
# 1                     NaN              NaN               NaN
# 2                     NaN              NaN               NaN
# 3                     NaN              NaN               NaN
# 4                     NaN              NaN               NaN
#
#   sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                NaN                  NaN                    NaN
# 1                NaN                  NaN                    NaN
# 2                NaN                  NaN                    NaN
# 3                NaN                  NaN                    NaN
# 4                NaN                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog  deferral_term  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4                                  NaN            NaN
#
#    payment_plan_start_date  orig_projected_additional_accrued_interest  \
# 0                      NaN                                         NaN
# 1                      NaN                                         NaN
# 2                      NaN                                         NaN
# 3                      NaN                                         NaN
# 4                      NaN                                         NaN
#
#    debt_settlement_flag debt_settlement_flag_date  settlement_status  \
# 0                     N                       NaN                NaN
# 1                     N                       NaN                NaN
# 2                     N                       NaN                NaN
# 3                     N                       NaN                NaN
# 4                     N                       NaN                NaN
#
#   settlement_date settlement_amount  settlement_percentage  settlement_term  \
# 0             NaN               NaN                    NaN              NaN
# 1             NaN               NaN                    NaN              NaN
# 2             NaN               NaN                    NaN              NaN
# 3             NaN               NaN                    NaN              NaN
# 4             NaN               NaN                    NaN              NaN
#
#    emp_title_manager issue_year  issue_month
# 0              False       2018           12
# 1              False       2018           12
# 2              False       2018           12
# 3              False       2018           12
# 4               True       2018           12
#
# [5 rows x 131 columns]

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['days_from_cr_line_to_loan'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        security    3 years           RENT     90000.0
# 2     D        D1  administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        operator    5 years           RENT     68107.0
# 4     E        E1         manager  10+ years            OWN     43000.0
#
#   verification_status    issue_d         loan_status pymnt_plan  \
# 0        Not Verified 2018-12-01             Current          n
# 1     Source Verified 2018-12-01             Current          n
# 2     Source Verified 2018-12-01  Late (31-120 days)          n
# 3     Source Verified 2018-12-01             Current          n
# 4     Source Verified 2018-12-01             Current          n
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    974xx         OR   6.15
# 1  debt_consolidation  Debt consolidation    070xx         NJ  26.33
# 2  debt_consolidation  Debt consolidation    490xx         MI  10.51
# 3  debt_consolidation  Debt consolidation    672xx         KS   0.52
# 4  debt_consolidation  Debt consolidation    357xx         AL  33.24
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  ...  \
# 0            2       1996-01-01               0                    18.0  ...
# 1            0       2006-09-01               4                    59.0  ...
# 2            0       2011-04-01               0                     NaN  ...
# 3            0       1997-02-01               0                     NaN  ...
# 4            0       1995-01-01               0                     NaN  ...
#
#    revol_bal_joint  sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                       NaN                     NaN
# 1              NaN                       NaN                     NaN
# 2              NaN                       NaN                     NaN
# 3              NaN                       NaN                     NaN
# 4              NaN                       NaN                     NaN
#
#    sec_app_mort_acc sec_app_open_acc  sec_app_revol_util sec_app_open_act_il  \
# 0               NaN              NaN                 NaN                 NaN
# 1               NaN              NaN                 NaN                 NaN
# 2               NaN              NaN                 NaN                 NaN
# 3               NaN              NaN                 NaN                 NaN
# 4               NaN              NaN                 NaN                 NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    deferral_term  payment_plan_start_date  \
# 0            NaN                      NaN
# 1            NaN                      NaN
# 2            NaN                      NaN
# 3            NaN                      NaN
# 4            NaN                      NaN
#
#    orig_projected_additional_accrued_interest  debt_settlement_flag  \
# 0                                         NaN                     N
# 1                                         NaN                     N
# 2                                         NaN                     N
# 3                                         NaN                     N
# 4                                         NaN                     N
#
#    debt_settlement_flag_date settlement_status  settlement_date  \
# 0                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 2                        NaN               NaN              NaN
# 3                        NaN               NaN              NaN
# 4                        NaN               NaN              NaN
#
#   settlement_amount settlement_percentage  settlement_term  emp_title_manager  \
# 0               NaN                   NaN              NaN              False
# 1               NaN                   NaN              NaN              False
# 2               NaN                   NaN              NaN              False
# 3               NaN                   NaN              NaN              False
# 4               NaN                   NaN              NaN               True
#
#    issue_year issue_month  days_from_cr_line_to_loan
# 0        2018          12                       8370
# 1        2018          12                       4474
# 2        2018          12                       2801
# 3        2018          12                       7973
# 4        2018          12                       8735
#
# [5 rows x 132 columns]

# %%
df['issue_d'].dt.strftime('%Y %B %d')
# Out:
# 0         2018 December 01
# 1         2018 December 01
# 2         2018 December 01
# 3         2018 December 01
# 4         2018 December 01
# 5         2018 December 01
# 6         2018 December 01
# 7         2018 December 01
# 8         2018 December 01
# 9         2018 December 01
# 10        2018 December 01
# 11        2018 December 01
# 12        2018 December 01
# 13        2018 December 01
# 14        2018 December 01
# 15        2018 December 01
# 16        2018 December 01
# 17        2018 December 01
# 18        2018 December 01
# 19        2018 December 01
# 20        2018 December 01
# 21        2018 December 01
# 22        2018 December 01
# 23        2018 December 01
# 24        2018 December 01
#                 ...
# 128387     2018 October 01
# 128388     2018 October 01
# 128389     2018 October 01
# 128390     2018 October 01
# 128391     2018 October 01
# 128392     2018 October 01
# 128393     2018 October 01
# 128394     2018 October 01
# 128395     2018 October 01
# 128396     2018 October 01
# 128397     2018 October 01
# 128398     2018 October 01
# 128399     2018 October 01
# 128400     2018 October 01
# 128401     2018 October 01
# 128402     2018 October 01
# 128403     2018 October 01
# 128404     2018 October 01
# 128405     2018 October 01
# 128406     2018 October 01
# 128407     2018 October 01
# 128408     2018 October 01
# 128409     2018 October 01
# 128410     2018 October 01
# 128411     2018 October 01
# Name: issue_d, Length: 128412, dtype: object

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
