# %% [markdown]
# <a href="https://colab.research.google.com/github/RedZeptic/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/module4-makefeatures/Thomas_Mineo_LS_DS_114_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip # Getting the Zip File
# Out:
# --2019-09-06 04:09:37--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.2’
#
# LoanStats_2018Q4.cs     [                 <=>]  21.58M   839KB/s    in 27s
#
# 2019-09-06 04:10:04 (833 KB/s) - ‘LoanStats_2018Q4.csv.zip.2’ saved [22631049]

# %%
# !unzip LoanStats_2018Q4.csv.zip # Unpackaging the CSV from the Zip File
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv # Looking at the rough data
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
import pandas as pd
import numpy as np

# %%
orig_df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, na_values=['n/a'], engine='python')
orig_df.head(15)
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN      10000        10000          10000.0   36 months
# 1  NaN        NaN       4000         4000           4000.0   36 months
# 2  NaN        NaN       5000         5000           5000.0   36 months
# 3  NaN        NaN      23000        23000          23000.0   60 months
# 4  NaN        NaN       8000         8000           8000.0   36 months
# 5  NaN        NaN      32075        32075          32075.0   60 months
# 6  NaN        NaN       9600         9600           9600.0   36 months
# 7  NaN        NaN      30000        30000          30000.0   60 months
# 8  NaN        NaN       2500         2500           2500.0   36 months
# 9  NaN        NaN      12000        12000          12000.0   60 months
# 10 NaN        NaN      10000        10000          10000.0   60 months
# 11 NaN        NaN      16000        16000          16000.0   60 months
# ...

# %%
# Run this block to Reset the Dataframe

df = orig_df.drop(columns=['id','member_id','desc','url'])
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   36 months   10.33%       324.23
# 1       4000         4000           4000.0   36 months   23.40%       155.68
# 2       5000         5000           5000.0   36 months   17.97%       180.69
# 3      23000        23000          23000.0   60 months   20.89%       620.81
# 4       8000         8000           8000.0   36 months   23.40%       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
# Setting some Pandas display options for the dataframe
pd.set_option('display.max_rows', 450)
pd.set_option('display.max_columns', df.shape[1])

# %%
df.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
# Checking for null / NaN values
df.isnull().sum().sort_values(ascending=False)
# Out:
# orig_projected_additional_accrued_interest    128386
# hardship_loan_status                          128385
# hardship_dpd                                  128385
# hardship_reason                               128385
# hardship_status                               128385
# deferral_term                                 128385
# hardship_amount                               128385
# hardship_start_date                           128385
# hardship_end_date                             128385
# payment_plan_start_date                       128385
# hardship_length                               128385
# hardship_type                                 128385
# hardship_payoff_balance_amount                128385
# hardship_last_payment_amount                  128385
# settlement_percentage                         128301
# debt_settlement_flag_date                     128301
# settlement_status                             128301
# settlement_date                               128301
# ...

# %%
df['term'].head(15)
# Out:
# 0      36 months
# 1      36 months
# 2      36 months
# 3      60 months
# 4      36 months
# 5      60 months
# 6      36 months
# 7      60 months
# 8      36 months
# 9      60 months
# 10     60 months
# 11     60 months
# 12     60 months
# 13     60 months
# 14     36 months
# Name: term, dtype: object

# %%
# ' month' Dropping function
def month_remover(string):
  return string.replace(' months', '')

df['term'] = df['term'].apply(month_remover)

# %%
df['term'].head(15)
# Out:
# 0      36
# 1      36
# 2      36
# 3      60
# 4      36
# 5      60
# 6      36
# 7      60
# 8      36
# 9      60
# 10     60
# 11     60
# 12     60
# 13     60
# 14     36
# Name: term, dtype: object

# %%
df['term'] = pd.to_numeric(df['term'])

# %%
df['term'].head(5)
# Out:
# 0    36
# 1    36
# 2    36
# 3    60
# 4    36
# Name: term, dtype: int64

# %%
loan_status_list = ['Current', 'Fully Paid']

# %%
df['loan_status_is_great'] = 0
df['loan_status_is_great'] = df['loan_status'].isin(loan_status_list) * 1

# %%
df.head(4)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      10000        10000          10000.0    36   10.33%       324.23     B
# 1       4000         4000           4000.0    36   23.40%       155.68     E
# 2       5000         5000           5000.0    36   17.97%       180.69     D
# 3      23000        23000          23000.0    60   20.89%       620.81     D
#
#   sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1        E1        Security    3 years           RENT     90000.0
# 2        D1  Administrative    6 years       MORTGAGE     59280.0
# 3        D4        Operator    5 years           RENT     68107.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# 0        Not Verified  Dec-2018             Current          n
# 1     Source Verified  Dec-2018             Current          n
# ...

# %%
# defining new features, making them replicas of the original feature
df['last_pymnt_d_month'] = df['last_pymnt_d']
df['last_pymnt_d_year'] = df['last_pymnt_d']

# %%
df['last_pymnt_d_month'] = pd.to_datetime(df['last_pymnt_d_month'], infer_datetime_format=True)
df['last_pymnt_d_year'] = pd.to_datetime(df['last_pymnt_d_year'], infer_datetime_format=True)

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d_month'].dt.month
df['last_pymnt_d_year'] = df['last_pymnt_d_year'].dt.year

# %%
df[['last_pymnt_d', 'last_pymnt_d_month', 'last_pymnt_d_year']]
# Out:
#        last_pymnt_d  last_pymnt_d_month  last_pymnt_d_year
# 0          Jul-2019                 7.0             2019.0
# 1          Jul-2019                 7.0             2019.0
# 2          Jun-2019                 6.0             2019.0
# 3          Jul-2019                 7.0             2019.0
# 4          Jul-2019                 7.0             2019.0
# 5          Jul-2019                 7.0             2019.0
# 6          Aug-2019                 8.0             2019.0
# 7          Jul-2019                 7.0             2019.0
# 8          May-2019                 5.0             2019.0
# 9          Jul-2019                 7.0             2019.0
# 10         Jul-2019                 7.0             2019.0
# 11         Jul-2019                 7.0             2019.0
# 12         Jul-2019                 7.0             2019.0
# 13         Jul-2019                 7.0             2019.0
# 14         Jul-2019                 7.0             2019.0
# ...

# %%
df[['last_pymnt_d','last_pymnt_d_month','last_pymnt_d_year']] = df[['last_pymnt_d','last_pymnt_d_month','last_pymnt_d_year']].fillna(0)

# %%
df[['last_pymnt_d', 'last_pymnt_d_month', 'last_pymnt_d_year']]
# Out:
#        last_pymnt_d  last_pymnt_d_month  last_pymnt_d_year
# 0          Jul-2019                 7.0             2019.0
# 1          Jul-2019                 7.0             2019.0
# 2          Jun-2019                 6.0             2019.0
# 3          Jul-2019                 7.0             2019.0
# 4          Jul-2019                 7.0             2019.0
# 5          Jul-2019                 7.0             2019.0
# 6          Aug-2019                 8.0             2019.0
# 7          Jul-2019                 7.0             2019.0
# 8          May-2019                 5.0             2019.0
# 9          Jul-2019                 7.0             2019.0
# 10         Jul-2019                 7.0             2019.0
# 11         Jul-2019                 7.0             2019.0
# 12         Jul-2019                 7.0             2019.0
# 13         Jul-2019                 7.0             2019.0
# 14         Jul-2019                 7.0             2019.0
# ...

# %%
df['last_pymnt_d_month'] = pd.to_numeric(df['last_pymnt_d_month'],downcast='integer')
df['last_pymnt_d_year'] = pd.to_numeric(df['last_pymnt_d_year'],downcast='integer')

# %%
df[['last_pymnt_d', 'last_pymnt_d_month', 'last_pymnt_d_year']]
# Out:
#        last_pymnt_d  last_pymnt_d_month  last_pymnt_d_year
# 0          Jul-2019                   7               2019
# 1          Jul-2019                   7               2019
# 2          Jun-2019                   6               2019
# 3          Jul-2019                   7               2019
# 4          Jul-2019                   7               2019
# 5          Jul-2019                   7               2019
# 6          Aug-2019                   8               2019
# 7          Jul-2019                   7               2019
# 8          May-2019                   5               2019
# 9          Jul-2019                   7               2019
# 10         Jul-2019                   7               2019
# 11         Jul-2019                   7               2019
# 12         Jul-2019                   7               2019
# 13         Jul-2019                   7               2019
# 14         Jul-2019                   7               2019
# ...

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
