# %% [markdown]
# <a href="https://colab.research.google.com/github/ericriveraisme/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/module4-makefeatures/Eric_Rivera_Complete_LSPT3_DS_114_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd
import numpy as np


# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-09-12 21:10:11--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [        <=>         ]  21.58M  1.68MB/s    in 13s
#
# 2019-09-12 21:10:24 (1.67 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22631049]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv')
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,123,124,125,126,127,128,129,130,131,132,133,134,135,136,138,139,140,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
df1 = pd.read_csv('LoanStats_2018Q4.csv', header=1)
df1.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,123,124,125,128,129,130,133,138,139,140) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df1.tail()
# Out:
#                                                       id  ...  settlement_term
# 128409                                               NaN  ...              NaN
# 128410                                               NaN  ...              NaN
# 128411                                               NaN  ...              NaN
# 128412  Total amount funded in policy code 1: 2050909275  ...              NaN
# 128413   Total amount funded in policy code 2: 820109297  ...              NaN
#
# [5 rows x 144 columns]

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4264.17","4264.17","1891.55","1891.55","1335.83","555.72","0.0","0.0","0.0","Aug-2019","190.21","Sep-2019","Aug-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
df2 = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
df2.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df2.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128407 NaN        NaN  ...                    NaN              NaN
# 128408 NaN        NaN  ...                    NaN              NaN
# 128409 NaN        NaN  ...                    NaN              NaN
# 128410 NaN        NaN  ...                    NaN              NaN
# 128411 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df2.shape
# Out:
# (128412, 144)

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

df2.isnull().sum()
# Out:
# id                                            128412
# member_id                                     128412
# loan_amnt                                          0
# funded_amnt                                        0
# funded_amnt_inv                                    0
# term                                               0
# int_rate                                           0
# installment                                        0
# grade                                              0
# sub_grade                                          0
# emp_title                                      20947
# emp_length                                     11704
# home_ownership                                     0
# annual_inc                                         0
# verification_status                                0
# issue_d                                            0
# loan_status                                        0
# pymnt_plan                                         0
# ...

# %%
df2.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# desc                                          128412
# member_id                                     128412
# url                                           128412
# orig_projected_additional_accrued_interest    128386
# hardship_type                                 128385
# hardship_last_payment_amount                  128385
# hardship_payoff_balance_amount                128385
# hardship_reason                               128385
# hardship_loan_status                          128385
# hardship_dpd                                  128385
# hardship_length                               128385
# payment_plan_start_date                       128385
# hardship_end_date                             128385
# hardship_start_date                           128385
# hardship_amount                               128385
# deferral_term                                 128385
# hardship_status                               128385
# ...

# %%
df3 = df2

df = df3.drop(columns=['id', 'member_id', 'desc', 'url'])

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   36 months   10.33%       324.23
# 1       4000         4000           4000.0   36 months   23.40%       155.68
# 2       5000         5000           5000.0   36 months   17.97%       180.69
# 3      23000        23000          23000.0   60 months   20.89%       620.81
# 4       8000         8000           8000.0   36 months   23.40%       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
hardship_cols = [col for col in df.columns if col.startswith('hardship_')]

hardship_cols
# Out:
# ['hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount']

# %%
df.shape
# Out:
# (128412, 140)

# %%
df = df.drop(columns=hardship_cols)
df.shape
# Out:
# (128412, 128)

# %%
df.describe(exclude='number')
# Out:
#               term int_rate   grade sub_grade emp_title emp_length  \
# count       128412   128412  128412    128412    107465     116708
# unique           2       46       7        35     43892         11
# top      36 months   13.56%       A        A4   Teacher  10+ years
# freq         88179     6974   38011      9770      2090      38826
#
#        home_ownership verification_status   issue_d loan_status pymnt_plan  \
# count          128412              128412    128412      128412     128412
# unique              4                   3         3           7          2
# top          MORTGAGE        Not Verified  Oct-2018     Current          n
# freq            63490               58350     46305      108584     128398
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# ...

# %%
df['int_rate']
# Out:
# 0          10.33%
# 1          23.40%
# 2          17.97%
# 3          20.89%
# 4          23.40%
# 5          11.80%
# 6          12.98%
# 7          18.94%
# 8          13.56%
# 9          13.56%
# 10         19.92%
# 11         17.97%
# 12         26.31%
# 13         14.47%
# 14         23.40%
# 15         23.40%
# 16         20.89%
# 17         16.91%
# 18         20.89%
# 19         14.47%
# 20         13.56%
# 21         14.47%
# 22         12.98%
# 23         23.40%
# 24         11.80%
#            ...
# 128387     11.55%
# 128388      8.46%
# 128389     11.55%
# 128390     19.92%
# 128391      6.67%
# 128392     26.31%
# 128393     16.91%
# 128394      6.11%
# 128395     11.55%
# 128396     15.02%
# 128397     15.02%
# 128398     18.94%
# 128399     15.02%
# 128400     15.02%
# 128401     11.55%
# 128402     22.35%
# 128403     16.14%
# 128404     16.14%
# 128405      7.84%
# 128406     13.56%
# 128407     15.02%
# 128408     15.02%
# 128409     13.56%
# 128410     11.06%
# ...

# %%
def remove_percent_to_float(x):
  return float(x[:-1])

# %%
df['int_rate'] = df['int_rate'].apply(remove_percent_to_float)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
df.describe(exclude='number')
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       128412  128412    128412    107465     116708         128412
# unique           2       7        35     43892         11              4
# top      36 months       A        A4   Teacher  10+ years       MORTGAGE
# freq         88179   38011      9770      2090      38826          63490
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               128412    128412      128412     128412
# unique                   3         3           7          2
# top           Not Verified  Oct-2018     Current          n
# freq                 58350     46305      108584     128398
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# ...

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().lower()
  else:
    return 'unknown'

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# unknown               20947
# teacher                2557
# manager                2395
# registered nurse       1418
# driver                 1258
# supervisor             1160
# truck driver            920
# rn                      834
# office manager          805
# sales                   803
# general manager         791
# project manager         720
# owner                   625
# director                523
# operations manager      518
# sales manager           500
# police officer          440
# nurse                   425
# technician              420
# engineer                412
# Name: emp_title, dtype: int64

# %% [markdown]
# Spending Time Until I Realize DF['Term'] is already an int64...

# %%
#df['term'] = df['term'].apply(remove_percent_to_float)
#def remove_percent_to_int(x):
  #return int(x[:-' '])
#df['term'] = df['term'].apply(remove_percent_to_int)


#df['term'].astype('bool').dtypes
#df['term'] = pd.to_datetime(df['term'], infer_datetime_format=True)
# = df['term',['months']].astype(int)

# No idea how I converted it, but it seems to have cut off more than I meant to
# It shows only the 3 or the 6, but the dtype of 'term' is an int...?

#df1['term'].strip('months')

#remove_percent_to_int_v2 = lambda x: int(x[:-1])
#df1['term'] = df1['term'].apply(remove_percent_to_int_v2)
df1['term'] = df1['term'].str.contains('36 months|60 months')
df1['term'].value_counts()
# Out:
# Series([], Name: term, dtype: int64)

# %%
df1['term'].isna().sum()
# Out:
# 2

# %%
df1['term'].fillna(method='ffill')

#df1['term'].interpolate()
df1['term'].isna().sum()
# Out:
# 128414

# %%
#df1['term'].isna().sum()

#df1['term'] = df1['term'].astype(int)


#df1['term'].str.strip(' ')
df1['term'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: term, dtype: float64

# %%
df2['term'].interpolate(method='pad')
# Out:
# 0         3
# 1         3
# 2         3
# 3         6
# 4         3
# 5         6
# 6         3
# 7         6
# 8         3
# 9         6
# 10        6
# 11        6
# 12        6
# 13        6
# 14        3
# 15        3
# 16        3
# 17        6
# 18        6
# 19        6
# 20        3
# 21        3
# 22        3
# 23        3
# 24        6
#          ..
# 128387    3
# 128388    3
# 128389    3
# 128390    3
# 128391    3
# 128392    3
# 128393    3
# 128394    3
# 128395    3
# 128396    6
# 128397    6
# 128398    6
# 128399    3
# 128400    6
# 128401    3
# 128402    6
# 128403    3
# 128404    3
# 128405    6
# 128406    3
# 128407    3
# 128408    3
# 128409    3
# 128410    3
# 128411    3
# Name: term, Length: 128412, dtype: int64

# %%
#df5 =df1['term']df1['term']df1['term']df1['term']


#df2['term'] = df1['term'].apply(remove_percent_to_int)

df2['term']
# Out:
# 0         3
# 1         3
# 2         3
# 3         6
# 4         3
# 5         6
# 6         3
# 7         6
# 8         3
# 9         6
# 10        6
# 11        6
# 12        6
# 13        6
# 14        3
# 15        3
# 16        3
# 17        6
# 18        6
# 19        6
# 20        3
# 21        3
# 22        3
# 23        3
# 24        6
#          ..
# 128387    3
# 128388    3
# 128389    3
# 128390    3
# 128391    3
# 128392    3
# 128393    3
# 128394    3
# 128395    3
# 128396    6
# 128397    6
# 128398    6
# 128399    3
# 128400    6
# 128401    3
# 128402    6
# 128403    3
# 128404    3
# 128405    6
# 128406    3
# 128407    3
# 128408    3
# 128409    3
# 128410    3
# 128411    3
# Name: term, Length: 128412, dtype: int64

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      10000        10000          10000.0     3     10.33       324.23     B
# 1       4000         4000           4000.0     3     23.40       155.68     E
# 2       5000         5000           5000.0     3     17.97       180.69     D
# 3      23000        23000          23000.0     6     20.89       620.81     D
# 4       8000         8000           8000.0     3     23.40       311.35     E
#
#   sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0        B1         unknown   < 1 year       MORTGAGE    280000.0
# 1        E1        security    3 years           RENT     90000.0
# 2        D1  administrative    6 years       MORTGAGE     59280.0
# 3        D4        operator    5 years           RENT     68107.0
# 4        E1         manager  10+ years            OWN     43000.0
#
#   verification_status    issue_d         loan_status pymnt_plan  \
# ...

# %%
#df['term'] = pd.to_datetime(df['term'], infer_datetime_format=True)

#df['term'].astype(str).astype(int)

set(df2['term'].sort_values())
# Out:
# {3, 6}

# %%
df2['term'].dtype

#if np.issubdtype(dtype.type, np.integer):
 #return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
# Out:
# dtype('int64')

# %% [markdown]
# # Work With Dates

# %%
#df['issue_d']

df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)
df['issue_d']
# Out:
# 0        2018-12-01
# 1        2018-12-01
# 2        2018-12-01
# 3        2018-12-01
# 4        2018-12-01
# 5        2018-12-01
# 6        2018-12-01
# 7        2018-12-01
# 8        2018-12-01
# 9        2018-12-01
# 10       2018-12-01
# 11       2018-12-01
# 12       2018-12-01
# 13       2018-12-01
# 14       2018-12-01
# 15       2018-12-01
# 16       2018-12-01
# 17       2018-12-01
# 18       2018-12-01
# 19       2018-12-01
# 20       2018-12-01
# 21       2018-12-01
# 22       2018-12-01
# 23       2018-12-01
# 24       2018-12-01
#             ...
# 128387   2018-10-01
# 128388   2018-10-01
# 128389   2018-10-01
# 128390   2018-10-01
# 128391   2018-10-01
# 128392   2018-10-01
# 128393   2018-10-01
# 128394   2018-10-01
# 128395   2018-10-01
# 128396   2018-10-01
# 128397   2018-10-01
# 128398   2018-10-01
# 128399   2018-10-01
# 128400   2018-10-01
# 128401   2018-10-01
# 128402   2018-10-01
# 128403   2018-10-01
# 128404   2018-10-01
# 128405   2018-10-01
# ...

# %%
df['issue_d'].dt.weekday
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# 5         5
# 6         5
# 7         5
# 8         5
# 9         5
# 10        5
# 11        5
# 12        5
# 13        5
# 14        5
# 15        5
# 16        5
# 17        5
# 18        5
# 19        5
# 20        5
# 21        5
# 22        5
# 23        5
# 24        5
#          ..
# 128387    0
# 128388    0
# 128389    0
# 128390    0
# 128391    0
# 128392    0
# 128393    0
# 128394    0
# 128395    0
# 128396    0
# 128397    0
# 128398    0
# 128399    0
# 128400    0
# 128401    0
# 128402    0
# 128403    0
# 128404    0
# 128405    0
# 128406    0
# 128407    0
# 128408    0
# 128409    0
# 128410    0
# 128411    0
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        security    3 years           RENT     90000.0
# 2     D        D1  administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        operator    5 years           RENT     68107.0
# 4     E        E1         manager  10+ years            OWN     43000.0
#
# ...

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

df['day_from_cr_line_to_loan'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        security    3 years           RENT     90000.0
# 2     D        D1  administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        operator    5 years           RENT     68107.0
# 4     E        E1         manager  10+ years            OWN     43000.0
#
# ...

# %%
df['issue_d'].dt.strftime('%Y %B %d')
# Out:
# 0         2018 December 01
# 1         2018 December 01
# 2         2018 December 01
# 3         2018 December 01
# 4         2018 December 01
# 5         2018 December 01
# 6         2018 December 01
# 7         2018 December 01
# 8         2018 December 01
# 9         2018 December 01
# 10        2018 December 01
# 11        2018 December 01
# 12        2018 December 01
# 13        2018 December 01
# 14        2018 December 01
# 15        2018 December 01
# 16        2018 December 01
# 17        2018 December 01
# 18        2018 December 01
# 19        2018 December 01
# 20        2018 December 01
# 21        2018 December 01
# 22        2018 December 01
# 23        2018 December 01
# 24        2018 December 01
#                 ...
# 128387     2018 October 01
# 128388     2018 October 01
# 128389     2018 October 01
# 128390     2018 October 01
# 128391     2018 October 01
# 128392     2018 October 01
# 128393     2018 October 01
# 128394     2018 October 01
# ...

# %% [markdown]
# # Actual Assignment Work

# %%
df['loan_status'].value_counts()
# Out:
# Current               108584
# Fully Paid             13929
# Late (31-120 days)      2291
# Charged Off             2194
# In Grace Period          849
# Late (16-30 days)        560
# Default                    5
# Name: loan_status, dtype: int64

# %%
# Making a column named loan_status_is_great

df['loan_status_is_great'] = df['loan_status'].str.contains('Current|Fully Paid')
df['loan_status_is_great'].value_counts()
# Out:
# True     122513
# False      5899
# Name: loan_status_is_great, dtype: int64

# %%
df['loan_status_is_great'] = df['loan_status_is_great'].astype(int)
df['loan_status_is_great'].head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: loan_status_is_great, dtype: int64

# %%
# Now that everything is a 1 or 0 for the create column, we create the last_pymnt_d_month
# and last_pymnt_d_year columns
df['last_pymnt_d'].isna().sum()
# Out:
# 159

# %%
df['last_pymnt_d'] = df['last_pymnt_d'].fillna(method='ffill')

df['last_pymnt_d'].isna().sum()
# Out:
# 0

# %%
df['last_pymnt_d'].head()
# Out:
# 0    Jul-2019
# 1    Jul-2019
# 2    Jun-2019
# 3    Jul-2019
# 4    Jul-2019
# Name: last_pymnt_d, dtype: object

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year

# %%
df['last_pymnt_d'].head()
# Out:
# 0   2019-07-01
# 1   2019-07-01
# 2   2019-06-01
# 3   2019-07-01
# 4   2019-07-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
df['last_pymnt_d_month'].head()
# Out:
# 0    7
# 1    7
# 2    6
# 3    7
# 4    7
# Name: last_pymnt_d_month, dtype: int64

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        security    3 years           RENT     90000.0
# 2     D        D1  administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        operator    5 years           RENT     68107.0
# 4     E        E1         manager  10+ years            OWN     43000.0
#
# ...

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
