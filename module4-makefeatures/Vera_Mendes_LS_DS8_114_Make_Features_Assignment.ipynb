# %% [markdown]
# <a href="https://colab.research.google.com/github/VeraMendes/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/module4-makefeatures/Vera_Mendes_LS_DS8_114_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-09-06 05:28:19--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [        <=>         ]  21.58M  1.70MB/s    in 13s
#
# 2019-09-06 05:28:32 (1.69 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22631049]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4264.17","4264.17","1891.55","1891.55","1335.83","555.72","0.0","0.0","0.0","Aug-2019","190.21","Sep-2019","Aug-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
import pandas as pd
import numpy as np

# %%
# Remove first line of code and turn second line as the column_headers
# Remove last two lines of code, footer
# turn any 'n/a' values into NaN

df1 = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, na_values=['n/a'])
# df.head(20)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %%
# checking for number of columns
df1.shape[1]
# Out:
# 144

# %%
# setting pandas display options

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
# viewing all the column headers
list(df1.columns)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
# checking dataframe dimensions
df1.shape
# Out:
# (128412, 144)

# %%
# looking for all the NaN values on my dataset and putting them in order by showing first the columns where there are more NaN values descending to the ones with less NaN values

df1.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# desc                                          128412
# member_id                                     128412
# url                                           128412
# orig_projected_additional_accrued_interest    128386
# hardship_type                                 128385
# hardship_last_payment_amount                  128385
# hardship_payoff_balance_amount                128385
# hardship_reason                               128385
# hardship_loan_status                          128385
# hardship_dpd                                  128385
# hardship_length                               128385
# payment_plan_start_date                       128385
# hardship_end_date                             128385
# hardship_start_date                           128385
# hardship_amount                               128385
# deferral_term                                 128385
# hardship_status                               128385
# ...

# %%
# all values are NaN on first 4 columns, we will drop these 4 columns
df1 = df1.drop(columns = ['id', 'desc', 'member_id', 'url'])

# %%
# checking dataset to make sure alterations were made
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   36 months   10.33%       324.23
# 1       4000         4000           4000.0   36 months   23.40%       155.68
# 2       5000         5000           5000.0   36 months   17.97%       180.69
# 3      23000        23000          23000.0   60 months   20.89%       620.81
# 4       8000         8000           8000.0   36 months   23.40%       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
#  checking again for null values

df1.isnull().sum().sort_values(ascending=False)
# Out:
# orig_projected_additional_accrued_interest    128386
# hardship_loan_status                          128385
# hardship_dpd                                  128385
# hardship_reason                               128385
# hardship_status                               128385
# deferral_term                                 128385
# hardship_amount                               128385
# hardship_start_date                           128385
# hardship_end_date                             128385
# payment_plan_start_date                       128385
# hardship_length                               128385
# hardship_type                                 128385
# hardship_payoff_balance_amount                128385
# hardship_last_payment_amount                  128385
# settlement_percentage                         128301
# debt_settlement_flag_date                     128301
# settlement_status                             128301
# settlement_date                               128301
# ...

# %%
# checking for types of objects
df1.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
# removing the % from the object

value = '12.03%'

value.strip('%')
# Out:
# '12.03'

# %%
# checking type of object

type(value.strip('%'))
# Out:
# str

# %%
# changing type of object from string to float

type(float(value.strip('%')))
# Out:
# float

# %%
#  function that works in any cell to remove percent and to change the object from a string into a float

def remove_percent_to_float(string):
  return float(string.strip('%'))

# %%
value2 = '15.02%'

# testing function on example value 2
remove_percent_to_float(value2)
# Out:
# 15.02

# %%
# using function on column 'int_rate' in dataframe

df1 ['int_rate'] = df1 ['int_rate']. apply(remove_percent_to_float)

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
df1.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
int_list = ['14.04%', '11.34%', '17.58%']

[remove_percent_to_float(item) for item in int_list]
# Out:
# [14.04, 11.34, 17.58]

# %%
# other way of doing this function: casting
# df['int_rate'] = pd.Series ([remove_percent_to_float(item) for item in list(df['int_rate'])])

# %%
# looking into top 20 job titles 

df1['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
# looking into the unique job titles

df1.describe(exclude='number')
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       128412  128412    128412    107465     116708         128412
# unique           2       7        35     43892         11              4
# top      36 months       A        A4   Teacher  10+ years       MORTGAGE
# freq         88179   38011      9770      2090      38826          63490
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               128412    128412      128412     128412
# unique                   3         3           7          2
# top           Not Verified  Oct-2018     Current          n
# freq                 58350     46305      108584     128398
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# ...

# %%
#  other way of looking into unique job titles

df1['emp_title']. value_counts(dropna=False).reset_index().shape[0]
# Out:
# 43893

# %%
# looking for null values on 'emp_title' 

df1['emp_title'].isnull().sum()
# Out:
# 20947

# %%
examples = ['owner', 'Supervisor', 'Project Manager', np.NaN]

# %%
type(np.NaN)
# Out:
# float

# %%
# define all NaN emp_title as Known

def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'

df1['emp_title'] = df1['emp_title']. apply(clean_title)
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
#  checking 'emp_title' column

df1 ['emp_title'].value_counts().head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
# looking into the number of unique job titles now

df1['emp_title'].value_counts(dropna=False).reset_index().shape[0]
# Out:
# 34902

# %%
# looking for management class

df1['emp_title_manager'] = df1['emp_title'].str.contains('Manager')
df1['emp_title_manager']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23         True
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
# 30         True
# 31        False
# 32        False
# 33        False
# 34        False
# 35        False
# 36        False
# 37         True
# 38        False
# 39        False
# 40        False
# 41        False
# 42        False
# 43        False
# 44        False
# 45        False
# 46        False
# 47        False
# 48         True
# 49        False
# 50        False
# 51        False
# 52        False
# 53        False
# 54         True
# ...

# %%
#  creating conditions to filter data and even do new smaller datasets out of the original
# condition in this new dataset is being a manager

condition = (df1['emp_title_manager'] == True)
df1[condition].head()
# Out:
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 4        8000         8000           8000.0   36 months     23.40
# 23       3300         3300           3300.0   36 months     23.40
# 30       2000         2000           2000.0   36 months     17.97
# 37       8000         8000           8000.0   36 months     11.80
# 48      16500        16500          16500.0   60 months     17.97
#
#     installment grade sub_grade        emp_title emp_length home_ownership  \
# 4        311.35     E        E1          Manager  10+ years            OWN
# 23       128.44     E        E1  Program Manager    3 years           RENT
# 30        72.28     D        D1  Account Manager    4 years           RENT
# 37       264.96     B        B4  Program Manager    7 years       MORTGAGE
# 48       418.73     D        D1     Case Manager    5 years       MORTGAGE
#
#     annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
# same thing, different code (checking shape of dataset too)

managers = df1[df1['emp_title'].str.contains('Manager')]
print(managers.shape)
managers.head()
# Out:
# (17882, 141)
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 4        8000         8000           8000.0   36 months     23.40
# 23       3300         3300           3300.0   36 months     23.40
# 30       2000         2000           2000.0   36 months     17.97
# 37       8000         8000           8000.0   36 months     11.80
# 48      16500        16500          16500.0   60 months     17.97
#
#     installment grade sub_grade        emp_title emp_length home_ownership  \
# 4        311.35     E        E1          Manager  10+ years            OWN
# 23       128.44     E        E1  Program Manager    3 years           RENT
# 30        72.28     D        D1  Account Manager    4 years           RENT
# 37       264.96     B        B4  Program Manager    7 years       MORTGAGE
# 48       418.73     D        D1     Case Manager    5 years       MORTGAGE
#
#     annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
# new dataset of not_managers

not_managers = df1[df1['emp_title_manager'] == False]
print(not_managers.shape)
not_managers.head()
# Out:
# (110530, 141)
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 5      32075        32075          32075.0   60 months     11.80       710.26
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1            Security    3 years           RENT     90000.0
# 2     D        D1      Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4            Operator    5 years           RENT     68107.0
# 5     B        B4  Nursing Supervisor  10+ years       MORTGAGE    150000.0
#
# ...

# %%
managers['int_rate'].hist(bins=20);

# %%
not_managers['int_rate'].hist(bins=20);

# %%
managers['int_rate'].plot.density();

# %%
not_managers['int_rate'].plot.density();

# %%
managers['int_rate'].mean()
# Out:
# 12.760582149647124

# %%
not_managers['int_rate'].mean()
# Out:
# 12.957160770832932

# %%
# looking for dates

df1 ['issue_d']
# Out:
# 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
# 5         Dec-2018
# 6         Dec-2018
# 7         Dec-2018
# 8         Dec-2018
# 9         Dec-2018
# 10        Dec-2018
# 11        Dec-2018
# 12        Dec-2018
# 13        Dec-2018
# 14        Dec-2018
# 15        Dec-2018
# 16        Dec-2018
# 17        Dec-2018
# 18        Dec-2018
# 19        Dec-2018
# 20        Dec-2018
# 21        Dec-2018
# 22        Dec-2018
# 23        Dec-2018
# 24        Dec-2018
# 25        Dec-2018
# 26        Dec-2018
# 27        Dec-2018
# 28        Dec-2018
# 29        Dec-2018
# 30        Dec-2018
# 31        Dec-2018
# 32        Dec-2018
# 33        Dec-2018
# 34        Dec-2018
# 35        Dec-2018
# 36        Dec-2018
# 37        Dec-2018
# 38        Dec-2018
# 39        Dec-2018
# 40        Dec-2018
# 41        Dec-2018
# 42        Dec-2018
# 43        Dec-2018
# 44        Dec-2018
# 45        Dec-2018
# 46        Dec-2018
# ...

# %%
# date formating

df1 ['issue_d'] = pd.to_datetime(df1 ['issue_d'], infer_datetime_format=True)

# %%
df1.dtypes
# Out:
# loan_amnt                                              int64
# funded_amnt                                            int64
# funded_amnt_inv                                      float64
# term                                                  object
# int_rate                                             float64
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# issue_d                                       datetime64[ns]
# loan_status                                           object
# ...

# %%
df1['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# looking only at month in date 

df1['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
# 5         12
# 6         12
# 7         12
# 8         12
# 9         12
# 10        12
# 11        12
# 12        12
# 13        12
# 14        12
# 15        12
# 16        12
# 17        12
# 18        12
# 19        12
# 20        12
# 21        12
# 22        12
# 23        12
# 24        12
# 25        12
# 26        12
# 27        12
# 28        12
# 29        12
# 30        12
# 31        12
# 32        12
# 33        12
# 34        12
# 35        12
# 36        12
# 37        12
# 38        12
# 39        12
# 40        12
# 41        12
# 42        12
# 43        12
# 44        12
# 45        12
# 46        12
# 47        12
# 48        12
# 49        12
# 50        12
# 51        12
# 52        12
# 53        12
# 54        12
# 55        12
# 56        12
# 57        12
# 58        12
# 59        12
# 60        12
# 61        12
# 62        12
# 63        12
# 64        12
# 65        12
# ...

# %%
# creating two new columns, one with year and the other one with month

df1['issue_year'] = df1['issue_d'].dt.year
df1['issue_month'] = df1['issue_d'].dt.month

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
# date format for column 'earliest_cr_line'

df1 ['earliest_cr_line'] = pd.to_datetime(df1['earliest_cr_line'], 
                                        infer_datetime_format=True)

# %%
# looking at this in days 

df1['issue_d'] - df1['earliest_cr_line']
# Out:
# 0         8370 days
# 1         4474 days
# 2         2801 days
# 3         7973 days
# 4         8735 days
# 5         4870 days
# 6         5509 days
# 7        11506 days
# 8         6453 days
# 9         4870 days
# 10        4992 days
# 11        4809 days
# 12        3013 days
# 13        7001 days
# 14        4232 days
# 15        5570 days
# 16        5174 days
# 17        2983 days
# 18        4901 days
# 19        6512 days
# 20        5113 days
# 21        6270 days
# 22        5844 days
# 23        4413 days
# 24        7031 days
# 25        4474 days
# 26        8157 days
# 27        6574 days
# 28        4686 days
# 29        5935 days
# 30        5143 days
# 31        7700 days
# 32        7427 days
# 33        1979 days
# 34        4901 days
# 35        2648 days
# 36        7062 days
# 37        9862 days
# 38       10015 days
# 39       11201 days
# 40        2282 days
# 41        2891 days
# 42        1522 days
# 43        4413 days
# 44        1522 days
# ...

# %%
# creating the column called 'days_from_earliest_credit_to_issue'

df1['days_from_earliest_credit_to_issue'] = (df1['issue_d'] - df1['earliest_cr_line']).dt.days
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
# description of values on column 'days_from_earliest_credit_to_issue'

df1['days_from_earliest_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean       5859.891490
# std        2886.535578
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# Name: days_from_earliest_credit_to_issue, dtype: float64

# %%
#  looking for the max value in years

25171/365
# Out:
# 68.96164383561644

# %%
df1.dtypes
# Out:
# loan_amnt                                              int64
# funded_amnt                                            int64
# funded_amnt_inv                                      float64
# term                                                  object
# int_rate                                             float64
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# issue_d                                       datetime64[ns]
# loan_status                                           object
# ...

# %%
print(df1['term'])
# Out:
# 0          36 months
# 1          36 months
# 2          36 months
# 3          60 months
# 4          36 months
# 5          60 months
# 6          36 months
# 7          60 months
# 8          36 months
# 9          60 months
# 10         60 months
# 11         60 months
# 12         60 months
# 13         60 months
# 14         36 months
# 15         36 months
# 16         36 months
# 17         60 months
# 18         60 months
# 19         60 months
# 20         36 months
# 21         36 months
# 22         36 months
# 23         36 months
# 24         60 months
# 25         36 months
# 26         36 months
# 27         60 months
# 28         36 months
# 29         36 months
# 30         36 months
# 31         36 months
# 32         36 months
# 33         36 months
# 34         36 months
# 35         36 months
# 36         36 months
# 37         36 months
# 38         60 months
# 39         36 months
# 40         36 months
# 41         36 months
# 42         60 months
# ...

# %%
def remove_months(string):
  return int(string.strip('months'))

df1['term'] = df1['term'].apply(remove_months)

# %%
print(df1['term'])
# Out:
# 0         36
# 1         36
# 2         36
# 3         60
# 4         36
# 5         60
# 6         36
# 7         60
# 8         36
# 9         60
# 10        60
# 11        60
# 12        60
# 13        60
# 14        36
# 15        36
# 16        36
# 17        60
# 18        60
# 19        60
# 20        36
# 21        36
# 22        36
# 23        36
# 24        60
# 25        36
# 26        36
# 27        60
# 28        36
# 29        36
# 30        36
# 31        36
# 32        36
# 33        36
# 34        36
# 35        36
# 36        36
# 37        36
# 38        60
# 39        36
# 40        36
# 41        36
# 42        60
# 43        60
# 44        36
# 45        36
# 46        60
# 47        36
# 48        60
# 49        36
# 50        36
# 51        36
# 52        36
# 53        60
# 54        36
# 55        36
# 56        60
# 57        36
# 58        60
# 59        36
# 60        60
# 61        36
# 62        36
# 63        36
# 64        60
# 65        36
# ...

# %%
# checking term is now int

df1.dtypes
# Out:
# loan_amnt                                              int64
# funded_amnt                                            int64
# funded_amnt_inv                                      float64
# term                                                   int64
# int_rate                                             float64
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# issue_d                                       datetime64[ns]
# loan_status                                           object
# ...

# %%
# Creating a function to define column 'loan_status_is_great'

def loan_status(loan_status):
  if loan_status == 'Current':
    return 1 
  elif loan_status == 'Fully Paid':
    return 1
  else:
    return 0

# Make a column named loan_status_is_great

df1['loan_status_is_great'] = df1['loan_status'].apply(loan_status)

df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      10000        10000          10000.0    36     10.33       324.23     B
# 1       4000         4000           4000.0    36     23.40       155.68     E
# 2       5000         5000           5000.0    36     17.97       180.69     D
# 3      23000        23000          23000.0    60     20.89       620.81     D
# 4       8000         8000           8000.0    36     23.40       311.35     E
#
#   sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1        E1        Security    3 years           RENT     90000.0
# 2        D1  Administrative    6 years       MORTGAGE     59280.0
# 3        D4        Operator    5 years           RENT     68107.0
# 4        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status    issue_d         loan_status pymnt_plan  \
# ...

# %%
#  checking for null values
df1['last_pymnt_d']. isnull().sum()
# Out:
# 159

# %%
#  looking for the mode of 'last_pymnt_d' column
last_pymnt_d_mode = df1.last_pymnt_d.mode()
print(last_pymnt_d_mode[0])
# Out:
# Aug-2019

# %%
#  replacing NaN values in 'last_pymnt_d' column by the mode 
df1['last_pymnt_d'] = df1['last_pymnt_d'].fillna(last_pymnt_d_mode[0])

# %%
# checking again for NaN values
df1['last_pymnt_d']. isnull().sum()
# Out:
# 0

# %%
# infering datetime format

df1['last_pymnt_d'] = pd.to_datetime(df1['last_pymnt_d'], infer_datetime_format=True)

df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      10000        10000          10000.0    36     10.33       324.23     B
# 1       4000         4000           4000.0    36     23.40       155.68     E
# 2       5000         5000           5000.0    36     17.97       180.69     D
# 3      23000        23000          23000.0    60     20.89       620.81     D
# 4       8000         8000           8000.0    36     23.40       311.35     E
#
#   sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1        E1        Security    3 years           RENT     90000.0
# 2        D1  Administrative    6 years       MORTGAGE     59280.0
# 3        D4        Operator    5 years           RENT     68107.0
# 4        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status    issue_d         loan_status pymnt_plan  \
# ...

# %%
# creating columns 'last_pymnt_d_year' & 'last_pymnt_d_month'

df1['last_pymnt_d_year'] = df1['last_pymnt_d'].dt.year.astype(int)

df1['last_pymnt_d_month'] = df1['last_pymnt_d'].dt.month.astype(int)

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      10000        10000          10000.0    36     10.33       324.23     B
# 1       4000         4000           4000.0    36     23.40       155.68     E
# 2       5000         5000           5000.0    36     17.97       180.69     D
# 3      23000        23000          23000.0    60     20.89       620.81     D
# 4       8000         8000           8000.0    36     23.40       311.35     E
#
#   sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1        E1        Security    3 years           RENT     90000.0
# 2        D1  Administrative    6 years       MORTGAGE     59280.0
# 3        D4        Operator    5 years           RENT     68107.0
# 4        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status    issue_d         loan_status pymnt_plan  \
# ...

# %%
#  checking value types to make sure the month and year comes as integer
df1.dtypes
# Out:
# loan_amnt                                              int64
# funded_amnt                                            int64
# funded_amnt_inv                                      float64
# term                                                   int64
# int_rate                                             float64
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# issue_d                                       datetime64[ns]
# loan_status                                           object
# ...

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
#  LendingClub options:

#  creating new dataset so I don't conflict with previous work done.

df2 = df1

df2['revol_util']. isnull().sum()
# Out:
# 156

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
