# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavani-Rajan/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/module4-makefeatures/LS_DS_114_Make_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Make features
#
# Objectives
# -  understand the purpose of feature engineering
# -  work with strings in pandas
# - work with dates and times in pandas
#
# Links
# - [Feature Engineering](https://en.wikipedia.org/wiki/Feature_engineering)
# - Python Data Science Handbook
#   - [Chapter 3.10](https://jakevdp.github.io/PythonDataScienceHandbook/03.10-working-with-strings.html), Vectorized String Operations
#   - [Chapter 3.11](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html), Working with Time Series
# - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)

# %% [markdown]
# ## Get LendingClub data
#
# [Source](https://www.lendingclub.com/info/download-data.action)

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-09-06 04:38:43--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [                 <=>]  21.58M   879KB/s    in 25s
#
# 2019-09-06 04:39:08 (871 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22631049]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# shows the first set of data
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# shows the end set of the data
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4264.17","4264.17","1891.55","1891.55","1335.83","555.72","0.0","0.0","0.0","Aug-2019","190.21","Sep-2019","Aug-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %% [markdown]
# ## Load LendingClub data
#
# pandas documentation
# - [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# - [`options.display`](https://pandas.pydata.org/pandas-docs/stable/options.html#available-options)

# %%
import pandas as pd

#df = pd.read_csv('LoanStats_2018Q4.csv')

# to remove the bold rendering of data header = 1

# df = pd.read_csv('LoanStats_2018Q4.csv',header = 1)

## na_values - Additional strings to recognize as NA/NaN
#df = pd.read_csv('LoanStats_2018Q4.csv',header = 1,na_values=['n/a'])

## to clean the data in the bottom use skip footer
df = pd.read_csv('LoanStats_2018Q4.csv',header = 1,na_values=['n/a'],skipfooter=2)


df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   del sys.path[0]
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
# set display option to avoid truncation of rows and/or columns

pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       4000         4000           4000.0   36 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN      23000        23000          23000.0   60 months
# 4 NaN        NaN       8000         8000           8000.0   36 months
#
#   int_rate  installment grade sub_grade       emp_title emp_length  \
# 0   10.33%       324.23     B        B1             NaN   < 1 year
# 1   23.40%       155.68     E        E1        Security    3 years
# 2   17.97%       180.69     D        D1  Administrative    6 years
# 3   20.89%       620.81     D        D4        Operator    5 years
# 4   23.40%       311.35     E        E1         Manager  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d  \
# 0       MORTGAGE    280000.0        Not Verified  Dec-2018
# ...

# %%
df['emp_title']
# Out:
# 0                                              NaN
# 1                                         Security
# 2                                   Administrative
# 3                                         Operator
# 4                                          Manager
# 5                               Nursing Supervisor
# 6                                              NaN
# 7                                      Postmaster
# 8                                             Chef
# 9                                              NaN
# 10                                Material Handler
# 11                       Instructional Coordinator
# 12                Financial Relationship Associate
# 13                                             NaN
# 14                             Sale Representative
# 15                             driver coordinator
# 16                                   gas attendant
# 17                                      Processor
# ...

# %%
# To get the no. of column headers of my dataset
# list shows them vertically
# len gives the length of it

len(list(df.columns))
# Out:
# 144

# %%
# I can use the shape method to get the number of rows or columns
df.shape[0]
# Out:
# 128412

# %% [markdown]
# ## To look at the null values in the dataset
#
# ## isna() and isnull both works

# %%
#df.isnull().sum()

# to sort this - default is ascending

df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# desc                                          128412
# member_id                                     128412
# url                                           128412
# orig_projected_additional_accrued_interest    128386
# hardship_type                                 128385
# hardship_last_payment_amount                  128385
# hardship_payoff_balance_amount                128385
# hardship_reason                               128385
# hardship_loan_status                          128385
# hardship_dpd                                  128385
# hardship_length                               128385
# payment_plan_start_date                       128385
# hardship_end_date                             128385
# hardship_start_date                           128385
# hardship_amount                               128385
# deferral_term                                 128385
# hardship_status                               128385
# ...

# %%
df_new = df.drop(columns=['id', 'member_id', 'desc', 'url'])
df_new.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   36 months   10.33%       324.23
# 1       4000         4000           4000.0   36 months   23.40%       155.68
# 2       5000         5000           5000.0   36 months   17.97%       180.69
# 3      23000        23000          23000.0   60 months   20.89%       620.81
# 4       8000         8000           8000.0   36 months   23.40%       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
#   verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
df_new.isnull().sum().sort_values(ascending=False)
# Out:
# orig_projected_additional_accrued_interest    128386
# hardship_loan_status                          128385
# hardship_dpd                                  128385
# hardship_reason                               128385
# hardship_status                               128385
# deferral_term                                 128385
# hardship_amount                               128385
# hardship_start_date                           128385
# hardship_end_date                             128385
# payment_plan_start_date                       128385
# hardship_length                               128385
# hardship_type                                 128385
# hardship_payoff_balance_amount                128385
# hardship_last_payment_amount                  128385
# settlement_percentage                         128301
# debt_settlement_flag_date                     128301
# settlement_status                             128301
# settlement_date                               128301
# ...

# %% [markdown]
# ## Work with strings

# %% [markdown]
# For machine learning, we usually want to replace strings with numbers.
#
# We can get info about which columns have a datatype of "object" (strings)

# %%
df_new['int_rate']
# Out:
# 0          10.33%
# 1          23.40%
# 2          17.97%
# 3          20.89%
# 4          23.40%
# 5          11.80%
# 6          12.98%
# 7          18.94%
# 8          13.56%
# 9          13.56%
# 10         19.92%
# 11         17.97%
# 12         26.31%
# 13         14.47%
# 14         23.40%
# 15         23.40%
# 16         20.89%
# 17         16.91%
# 18         20.89%
# 19         14.47%
# 20         13.56%
# 21         14.47%
# 22         12.98%
# 23         23.40%
# 24         11.80%
# 25         20.89%
# 26         26.31%
# 27         16.14%
# 28         18.94%
# 29         15.02%
# 30         17.97%
# 31         13.56%
# 32         17.97%
# 33         12.98%
# 34         11.80%
# 35         10.72%
# 36         12.98%
# 37         11.80%
# 38         14.47%
# 39         10.72%
# 40         11.80%
# 41         23.40%
# 42         20.89%
# 43         19.92%
# 44         10.33%
# 45          6.46%
# 46         14.47%
# 47         11.31%
# 48         17.97%
# 49         15.02%
# ...

# %%
df_new.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %% [markdown]
# ### Convert `int_rate`
#
# Define a function to remove percent signs from strings and convert to floats

# %%
# string is list of characters

int_rate = '15.02%'
#int_rate[1:3]

# -1 denotes last character from the string  
int_rate[:-1]
# Out:
# '15.02'

# %%
# remove characters at the beginning or end of a string
int_rate = '15.02%'
int_rate.strip('%')
# Out:
# '15.02'

# %%
# Remove characters in the middle of a string
int_rate = '14.59%'
int_rate.replace('.', '')
# Out:
# '1459%'

# %%
int_rate='15.02%'
type(int_rate.strip('%'))
# Out:
# str

# %%
type(float(int_rate.strip('%')))
# Out:
# float

# %%
# Write a function that will work on any given cell in a dataframe column
def remove_percent_to_float(string):
  return float(string.strip('%'))

int_rate='35.47%'
remove_percent_to_float(int_rate)
# Out:
# 35.47

# %% [markdown]
# Apply the function to the `int_rate` column

# %%
df_new['int_rate'] = df_new['int_rate'].apply(remove_percent_to_float)

# %%
df_new.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
df_new.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %% [markdown]
# # List Comprehension Example

# %%
int_list = ['15.02%', '13.56%', '16.91%']

# %%
[remove_percent_to_float(item) for item in int_list]
# Out:
# [15.02, 13.56, 16.91]

# %%
#load df and df_new before this command

list(df_new['int_rate'])
# Out:
# [10.33,
#  23.4,
#  17.97,
#  20.89,
#  23.4,
#  11.8,
#  12.98,
#  18.94,
#  13.56,
#  13.56,
#  19.92,
#  17.97,
#  26.31,
#  14.47,
#  23.4,
#  23.4,
#  20.89,
#  16.91,
#  20.89,
#  14.47,
#  13.56,
#  14.47,
#  12.98,
#  23.4,
#  11.8,
#  20.89,
#  26.31,
#  16.14,
#  18.94,
#  15.02,
#  17.97,
#  13.56,
#  17.97,
#  12.98,
#  11.8,
#  10.72,
#  12.98,
#  11.8,
#  14.47,
#  10.72,
#  11.8,
#  23.4,
#  20.89,
#  19.92,
#  10.33,
#  6.46,
#  14.47,
#  11.31,
#  17.97,
#  15.02,
#  8.81,
#  15.02,
#  16.91,
#  14.47,
#  25.34,
#  14.47,
#  12.98,
#  10.72,
#  19.92,
#  17.97,
#  12.98,
#  16.14,
#  10.33,
#  20.89,
#  17.97,
#  17.97,
#  12.98,
#  23.4,
#  14.47,
#  19.92,
#  14.47,
#  16.91,
#  6.46,
#  10.33,
#  13.56,
#  14.47,
#  10.33,
#  12.98,
#  12.98,
#  16.14,
#  15.02,
#  27.27,
#  16.91,
#  14.47,
#  15.02,
#  13.56,
#  16.91,
#  12.98,
#  14.47,
#  14.47,
#  17.97,
#  16.14,
#  11.8,
#  18.94,
#  11.8,
#  11.8,
#  18.94,
#  11.31,
#  7.56,
#  18.94,
#  11.31,
#  23.4,
# ...

# %%
# Cast int_rate column to a list
# use a list comprehension to remove '%' and cast to float
# Cast the altered list back to a dataframe column (Series)
# overwrite the original column with the new column
df_new['int_rate'] = pd.Series([remove_percent_to_float(item) for item in list(df['int_rate'])])

# %%
df_new.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %% [markdown]
# ### Clean `emp_title`
#
# Look at top 20 titles

# %%
# value_counts gives the value for each title
# by default drops na 

#df['emp_title'].value_counts()

#df['emp_title'].value_counts(dropna=False)

# top 20 use .head(20)

df_new['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df_new.describe(exclude='number')
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       128412  128412    128412    107465     116708         128412
# unique           2       7        35     43892         11              4
# top      36 months       A        A4   Teacher  10+ years       MORTGAGE
# freq         88179   38011      9770      2090      38826          63490
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               128412    128412      128412     128412
# unique                   3         3           7          2
# top           Not Verified  Oct-2018     Current          n
# freq                 58350     46305      108584     128398
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# ...

# %%
#df_new['emp_title'].value_counts(dropna=False)

# convert to a two col dstaframe with new index 
# use reset_index()
#df_new['emp_title'].value_counts(dropna=False).reset_index()

# To get the number of unique employment titles, use shape[0]
df_new['emp_title'].value_counts(dropna=False).reset_index().shape[0]
# Out:
# 43893

# %% [markdown]
# How often is `emp_title` null?

# %%
df_new['emp_title'].isnull().sum()
# Out:
# 20947

# %% [markdown]
# Clean the title and handle missing values

# %%
import numpy as np
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
type(np.NaN)
# Out:
# float

# %%
def clean_title(title):
  if isinstance(title,str):
    return title.strip().title()
  else:
    return "Unknown"
   
df_new['emp_title'] = df_new['emp_title'].apply(clean_title)

df_new.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
df_new['emp_title'].value_counts().head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df_new['emp_title'].value_counts(dropna=False).reset_index().shape[0]
# Out:
# 34902

# %%
df_new['emp_title'].iloc[10]
# Out:
# 'Material Handler'

# %%
# You might need to do something like this to take 
# our data cleaning to the next level

# Dict for various titles
dict = {"Nurse": ['Registered Nurse', 'Nurse', 'Rn'],
 'Owner': ["Owner", "Founder"]}
#for _ in dict:
 # if df_new['emp_title'].iloc[_] in dict:
  #  df_new['emp_title'].iloc[_] = dict
  #  break
#df_new['emp_title'].head(20)

# %% [markdown]
# ### Create `emp_title_manager`
#
# pandas documentation: [`str.contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html)

# %%
# I *have* to use the square bracket syntax when creating new dataframe column
df_new['emp_title']
# Out:
# 0                                          Unknown
# 1                                         Security
# 2                                   Administrative
# 3                                         Operator
# 4                                          Manager
# 5                               Nursing Supervisor
# 6                                          Unknown
# 7                                       Postmaster
# 8                                             Chef
# 9                                          Unknown
# 10                                Material Handler
# 11                       Instructional Coordinator
# 12                Financial Relationship Associate
# 13                                         Unknown
# 14                             Sale Representative
# 15                              Driver Coordinator
# 16                                   Gas Attendant
# 17                                       Processor
# ...

# %%
# I CANNOT create a new column using dot syntax
# I *have* to use the square bracket syntax when creating new dataframe column

# dot syntax is used in python to access an attribute of a class
df_new.emp_title

# An example of using dot syntax to access an "attribute" on an object (dataframe)
df_new.shape
# Out:
# (128412, 140)

# %%
# Python Guiding Principles:
 import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
df_new['emp_title_manager'] = True
df_new['emp_title_manager']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
# 30        True
# 31        True
# 32        True
# 33        True
# 34        True
# 35        True
# 36        True
# 37        True
# 38        True
# 39        True
# 40        True
# 41        True
# 42        True
# 43        True
# 44        True
# 45        True
# 46        True
# 47        True
# 48        True
# 49        True
# 50        True
# 51        True
# 52        True
# 53        True
# 54        True
# 55        True
# 56        True
# 57        True
# ...

# %%
df_new['emp_title_manager'] = df_new['emp_title'].str.contains('Manager')
df_new['emp_title_manager']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23         True
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
# 30         True
# 31        False
# 32        False
# 33        False
# 34        False
# 35        False
# 36        False
# 37         True
# 38        False
# 39        False
# 40        False
# 41        False
# 42        False
# 43        False
# 44        False
# 45        False
# 46        False
# 47        False
# 48         True
# 49        False
# 50        False
# 51        False
# 52        False
# 53        False
# 54         True
# ...

# %% [markdown]
# ## Dataframe filtering
#
# ### create new dataframes on certain conditions.
#
# ### the new dataframe will hold rows that meets those conditions

# %%
condition = (df_new['emp_title_manager'] == True)
print(condition.shape)
df_new[condition].head()
# Out:
# (128412,)
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 4        8000         8000           8000.0   36 months     23.40
# 23       3300         3300           3300.0   36 months     23.40
# 30       2000         2000           2000.0   36 months     17.97
# 37       8000         8000           8000.0   36 months     11.80
# 48      16500        16500          16500.0   60 months     17.97
#
#     installment grade sub_grade        emp_title emp_length home_ownership  \
# 4        311.35     E        E1          Manager  10+ years            OWN
# 23       128.44     E        E1  Program Manager    3 years           RENT
# 30        72.28     D        D1  Account Manager    4 years           RENT
# 37       264.96     B        B4  Program Manager    7 years       MORTGAGE
# 48       418.73     D        D1     Case Manager    5 years       MORTGAGE
#
#     annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
managers = df_new[df_new['emp_title'].str.contains('Manager')]
print(managers.shape)
managers.head()
# Out:
# (17882, 141)
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 4        8000         8000           8000.0   36 months     23.40
# 23       3300         3300           3300.0   36 months     23.40
# 30       2000         2000           2000.0   36 months     17.97
# 37       8000         8000           8000.0   36 months     11.80
# 48      16500        16500          16500.0   60 months     17.97
#
#     installment grade sub_grade        emp_title emp_length home_ownership  \
# 4        311.35     E        E1          Manager  10+ years            OWN
# 23       128.44     E        E1  Program Manager    3 years           RENT
# 30        72.28     D        D1  Account Manager    4 years           RENT
# 37       264.96     B        B4  Program Manager    7 years       MORTGAGE
# 48       418.73     D        D1     Case Manager    5 years       MORTGAGE
#
#     annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
## who are non managers

non_managers = df_new[df_new['emp_title_manager'] == False]
print(non_managers.shape)
non_managers.head()
# Out:
# (110530, 144)
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 5      32075        32075          32075.0   60 months     11.80       710.26
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1            Security    3 years           RENT     90000.0
# 2     D        D1      Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4            Operator    5 years           RENT     68107.0
# 5     B        B4  Nursing Supervisor  10+ years       MORTGAGE    150000.0
#
# ...

# %%
managers['int_rate'].hist(bins=20);

# %%
non_managers['int_rate'].hist(bins=20);

# %%
managers['int_rate'].plot.density()

# %%
non_managers['int_rate'].plot.density()

# %%
managers['int_rate'].mean()
# Out:
# 12.760582149647124

# %%
non_managers['int_rate'].mean()
# Out:
# 12.957160770832932

# %% [markdown]
# ## Work with dates

# %% [markdown]
# pandas documentation
# - [to_datetime](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)
# - [Time/Date Components](https://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components) "You can access these properties via the `.dt` accessor"

# %%
df_new['issue_d']
# Out:
# 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
# 5         Dec-2018
# 6         Dec-2018
# 7         Dec-2018
# 8         Dec-2018
# 9         Dec-2018
# 10        Dec-2018
# 11        Dec-2018
# 12        Dec-2018
# 13        Dec-2018
# 14        Dec-2018
# 15        Dec-2018
# 16        Dec-2018
# 17        Dec-2018
# 18        Dec-2018
# 19        Dec-2018
# 20        Dec-2018
# 21        Dec-2018
# 22        Dec-2018
# 23        Dec-2018
# 24        Dec-2018
# 25        Dec-2018
# 26        Dec-2018
# 27        Dec-2018
# 28        Dec-2018
# 29        Dec-2018
# 30        Dec-2018
# 31        Dec-2018
# 32        Dec-2018
# 33        Dec-2018
# 34        Dec-2018
# 35        Dec-2018
# 36        Dec-2018
# 37        Dec-2018
# 38        Dec-2018
# 39        Dec-2018
# 40        Dec-2018
# 41        Dec-2018
# 42        Dec-2018
# 43        Dec-2018
# 44        Dec-2018
# 45        Dec-2018
# 46        Dec-2018
# ...

# %%
print(df_new['issue_d'].dtypes)
# Out:
# object

# %%
df_new['issue_d'] = pd.to_datetime(df_new['issue_d'], infer_datetime_format=True)

# %%
print(df_new['issue_d'].dtypes)
# Out:
# datetime64[ns]

# %%
df_new['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# .dt.year outputs only the year
df_new['issue_d'].dt.year.head()
# Out:
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# Name: issue_d, dtype: int64

# %%
# .dt.month outputs only the month
df_new['issue_d'].dt.month.head()
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: issue_d, dtype: int64

# %%
# to create a new col of issue year n issue month

df_new['issue_year']=df_new['issue_d'].dt.year
df_new['issue_month']=df_new['issue_d'].dt.month

df_new.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
df_new['earliest_cr_line'] = pd.to_datetime(df_new['earliest_cr_line'], 
                                        infer_datetime_format=True)

# %%
df_new['lapse_days']=(df_new['issue_d'] - df_new['earliest_cr_line']).dt.days
df_new['lapse_days'].head()
# Out:
# 0    8370
# 1    4474
# 2    2801
# 3    7973
# 4    8735
# Name: lapse_days, dtype: int64

# %%
df_new.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
df_new['lapse_days'].describe()
# Out:
# count    128412.000000
# mean       5859.891490
# std        2886.535578
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# Name: lapse_days, dtype: float64
