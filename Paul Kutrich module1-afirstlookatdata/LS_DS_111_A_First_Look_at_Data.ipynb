# %% [markdown]
# <a href="https://colab.research.google.com/github/llpk79/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/Paul%20Kutrich%20module1-afirstlookatdata/LS_DS_111_A_First_Look_at_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lambda School Data Science - A First Look at Data

# %% [markdown]
# ## Lecture - let's explore Python DS libraries and examples!
#
# The Python Data Science ecosystem is huge. You've seen some of the big pieces - pandas, scikit-learn, matplotlib. What parts do you want to see more of?

# %% [markdown]
# I'm excited to learn more of Seaborn and Sklearn. I've messed around with making some tensorflow models. Would be fun to be more proficient with that library as well.

# %% [markdown]
# ## Assignment - now it's your turn
#
# Pick at least one Python DS library, and using documentation/examples reproduce in this notebook something cool. It's OK if you don't fully understand it or get it 100% working, but do put in effort and look things up.

# %%
import seaborn as sns
fmri = sns.load_dataset('fmri')
fmri.head()
# some functional magnetic resonance imaging data for a bunch of test subjects.
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.tail()
# Out:
#      subject  timepoint event    region    signal
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %% [markdown]
# Looks like the researchers were giving a cue, stimuls, or both to subjects and measuring some signal from the fmri.
# It seems two brain regions were looked at: parietal and frontal.

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);
# Seaborn plots mean agregate values for each x and a 95% confidence interval by default.

# %%
sns.relplot(x="timepoint", y="signal", hue="subject",
            col="region", row="event", height=3,
            kind="line", estimator=None, data=fmri);
# Here we at the different test methods and lots of subjects.
# Looks like most follow a similar pattern, but there are a few that certainly don't.
# It would be nice to separate these some.

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            col="subject", col_wrap=5,
            height=3, aspect=.75, linewidth=2.5,
            kind="line", data=fmri.query("region == 'parietal'"));
# It can be much easier to detect patterns and deviations when things are a bit more spread out.
# Here we look at testing in one brain region among several subjects.

# %% [markdown]
# ### Assignment questions
#
# After you've worked on some code, answer the following questions in this text block:
#
# 1.  Describe in a paragraph of text what you did and why, as if you were writing an email to somebody interested but nontechnical.
#
#     I just explored a little more of the Seaborn data visualization library. It's a tool you can use with Python code to view relationships in data with very little coding.
#     I'm interseted in using it in presentations to make data usefull and accessable to people from various background and understanding of data and statistics.
#
# 2.  What was the most challenging part of what you did?
#
#     Probably just finding one thing out of so many interesting things to choose from.
#
# 3.  What was the most interesting thing you learned?
#
#     I'm just getting to know the Seaborn library, so it's all interesting. There are so many options on ways to present your data and findings. Wicked cool.
#
# 4.  What area would you like to explore with more time?
#
#     I'm sure I'll get my wish to know this and other libraries inside and out.

# %% [markdown]
# ## Stretch goals and resources
#
# Following are *optional* things for you to take a look at. Focus on the above assignment first, and make sure to commit and push your changes to GitHub (and since this is the first assignment of the sprint, open a PR as well).
#
# - [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/)
# - [scikit-learn documentation](http://scikit-learn.org/stable/documentation.html)
# - [matplotlib documentation](https://matplotlib.org/contents.html)
# - [Awesome Data Science](https://github.com/bulutyazilim/awesome-datascience) - a list of many types of DS resources
#
# Stretch goals:
#
# - Find and read blogs, walkthroughs, and other examples of people working through cool things with data science - and share with your classmates!
# - Write a blog post (Medium is a popular place to publish) introducing yourself as somebody learning data science, and talking about what you've learned already and what you're excited to learn more about.
