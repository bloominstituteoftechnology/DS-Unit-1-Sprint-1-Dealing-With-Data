# %% [markdown]
# <a href="https://colab.research.google.com/github/ameralhomdy/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/module4-sequence-your-narrative/LS_DS8_124_Sequence_your_narrative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Sequence your narrative
#
# Today we will create a sequence of visualizations inspired by [Hans Rosling's 200 Countries, 200 Years, 4 Minutes](https://www.youtube.com/watch?v=jbkSRLYSojo).
#
# Using this [data from Gapminder](https://github.com/open-numbers/ddf--gapminder--systema_globalis/):
# - [Income Per Person (GDP Per Capital, Inflation Adjusted) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv)
# - [Life Expectancy (in Years) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv)
# - [Population Totals, by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv)
# - [Entities](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv)
# - [Concepts](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv)

# %% [markdown]
# Objectives
# - sequence multiple visualizations
# - combine qualitative anecdotes with quantitative aggregates
#
# Links
# - [Hans Rosling’s TED talks](https://www.ted.com/speakers/hans_rosling)
# - [Spiralling global temperatures from 1850-2016](https://twitter.com/ed_hawkins/status/729753441459945474)
# - "[The Pudding](https://pudding.cool/) explains ideas debated in culture with visual essays."
# - [A Data Point Walks Into a Bar](https://lisacharlotterost.github.io/2016/12/27/datapoint-in-bar/): a thoughtful blog post about emotion and empathy in data storytelling

# %% [markdown]
# ## Make a plan
#
# #### How to present the data?
#
# Variables --> Visual Encodings
# - Income --> x
# - Lifespan --> y
# - Region --> color
# - Population --> size
# - Year --> animation frame (alternative: small multiple)
# - Country --> annotation
#
# Qualitative --> Verbal
# - Editorial / contextual explanation --> audio narration (alternative: text)
#
#
# #### How to structure the data?
#
# | Year | Country | Region   | Income | Lifespan | Population |
# |------|---------|----------|--------|----------|------------|
# | 1818 | USA     | Americas | ###    | ##       | #          |
# | 1918 | USA     | Americas | ####   | ###      | ##         |
# | 2018 | USA     | Americas | #####  | ###      | ###        |
# | 1818 | China   | Asia     | #      | #        | #          |
# | 1918 | China   | Asia     | ##     | ##       | ###        |
# | 2018 | China   | Asia     | ###    | ###      | #####      |

# %% [markdown]
# ## More imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load & look at data

# %%
income = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv')

# %%
lifespan = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv')

# %%
population = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv')

# %%
entities = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv')

# %%
concepts = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv')

# %%
income.shape, lifespan.shape, population.shape, entities.shape, concepts.shape
# Out:
# ((46513, 3), (44370, 3), (59297, 3), (273, 33), (590, 16))

# %%
income.head()
# Out:
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603

# %%
lifespan.head()
# Out:
#    geo  time  life_expectancy_years
# 0  abw  1800                  34.42
# 1  abw  1801                  34.42
# 2  abw  1802                  34.42
# 3  abw  1803                  34.42
# 4  abw  1804                  34.42

# %%
population.head()
# Out:
#    geo  time  population_total
# 0  afg  1800           3280000
# 1  afg  1801           3280000
# 2  afg  1802           3280000
# 3  afg  1803           3280000
# 4  afg  1804           3280000

# %%
pd.options.display.max_columns = 500
entities.head()
# Out:
#   country alt_5                    alternative_1 alternative_2 alternative_3  \
# 0    abkh   NaN                              NaN           NaN           NaN
# 1     abw   NaN                              NaN           NaN           NaN
# 2     afg   NaN  Islamic Republic of Afghanistan           NaN           NaN
# 3     ago   NaN                              NaN           NaN           NaN
# 4     aia   NaN                              NaN           NaN           NaN
#
#   alternative_4_cdiac arb1 arb2 arb3 arb4 arb5 arb6 g77_and_oecd_countries  \
# 0                 NaN  NaN  NaN  NaN  NaN  NaN  NaN                 others
# 1               Aruba  NaN  NaN  NaN  NaN  NaN  NaN                 others
# 2         Afghanistan  NaN  NaN  NaN  NaN  NaN  NaN                    g77
# 3              Angola  NaN  NaN  NaN  NaN  NaN  NaN                    g77
# 4                 NaN  NaN  NaN  NaN  NaN  NaN  NaN                 others
#
#   gapminder_list god_id gwid        income_groups  is--country  \
# 0       Abkhazia  GE-AB   i0                  NaN         True
# 1          Aruba     AW  i12          high_income         True
# 2    Afghanistan     AF   i1           low_income         True
# 3         Angola     AO   i7  upper_middle_income         True
# 4       Anguilla     AI   i8                  NaN         True
#
#   iso3166_1_alpha2 iso3166_1_alpha3  iso3166_1_numeric iso3166_2  landlocked  \
# 0              NaN              NaN                NaN       NaN         NaN
# 1               AW              ABW              533.0       NaN   coastline
# 2               AF              AFG                4.0       NaN  landlocked
# 3               AO              AGO               24.0       NaN   coastline
# 4               AI              AIA              660.0       NaN   coastline
#
#    latitude  longitude main_religion_2008         name        pandg  un_state  \
# 0       NaN        NaN                NaN     Abkhazia          NaN     False
# 1  12.50000  -69.96667          christian        Aruba          NaN     False
# 2  33.00000   66.00000             muslim  Afghanistan  AFGHANISTAN      True
# 3 -12.50000   18.50000          christian       Angola       ANGOLA      True
# 4  18.21667  -63.05000          christian     Anguilla          NaN     False
#
#   unicode_region_subtag upper_case_name world_4region        world_6region
# 0                   NaN             NaN        europe  europe_central_asia
# 1                    AW           ARUBA      americas              america
# 2                    AF     AFGHANISTAN          asia           south_asia
# 3                    AO          ANGOLA        africa   sub_saharan_africa
# 4                    AI        ANGUILLA      americas              america

# %%
concepts.head()
# Out:
#                                              concept color concept_type  \
# 0                  adults_with_hiv_percent_age_15_49   NaN      measure
# 1                          age_at_1st_marriage_women   NaN      measure
# 2                 aged_15_24_employment_rate_percent   NaN      measure
# 3               aged_15_24_unemployment_rate_percent   NaN      measure
# 4  aged_15_64_labour_force_participation_rate_per...   NaN      measure
#
#                                          description description_long domain  \
# 0  The estimated percentage of adults aged 15 to ...              NaN    NaN
# 1  The mean age, in years, of first marriage for ...              NaN    NaN
# 2  Percentage of total population, age group 15-2...              NaN    NaN
# 3  Percentage of total population, age group 15-2...              NaN    NaN
# 4  For age group 15-64, percentage of all labour ...              NaN    NaN
#
#   drill_up indicator_url                                            name  \
# 0      NaN           NaN                  Adults with HIV (%, age 15-49)
# 1      NaN           NaN                     Age at 1st marriage (women)
# 2      NaN           NaN                  Aged 15-24 employment rate (%)
# 3      NaN           NaN                Aged 15-24 unemployment rate (%)
# 4      NaN           NaN  Aged 15-64 labour force participation rate (%)
#
#                      name_catalog                           name_short  \
# 0  Adults with HIV (%, age 15-49)                      Adults with HIV
# 1     Age at 1st marriage (women)                  Age at 1st marriage
# 2                      Aged 15-24                  Employment rate (%)
# 3                      Aged 15-24                Unemployment rate (%)
# 4                      Aged 15-64  Labour force participation rate (%)
#
#               scales source source_long  \
# 0  ["log", "linear"]    NaN         NaN
# 1  ["linear", "log"]    NaN         NaN
# 2  ["linear", "log"]    NaN         NaN
# 3  ["linear", "log"]    NaN         NaN
# 4  ["linear", "log"]    NaN         NaN
#
#                                           source_url  \
# 0  https://www.gapminder.org/gapminder-world/docu...
# 1  https://www.gapminder.org/data/documentation/g...
# 2                       https://www.ilo.org/ilostat/
# 3                       https://www.ilo.org/ilostat/
# 4                       https://www.ilo.org/ilostat/
#
#                          tags
# 0                         hiv
# 1                  population
# 2             employment_rate
# 3                unemployment
# 4  labour_force_participation

# %% [markdown]
# ## Merge data

# %% [markdown]
# https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf

# %%
print(income.shape)
print(lifespan.shape)
# Out:
# (46513, 3)
# (44370, 3)

# %%
merged = pd.merge(income, lifespan)
merged = pd.merge(income, lifespan, how='inner', on=['geo', 'time'])

merged.shape
# Out:
# (40437, 4)

# %%
pd.options.display.max_rows = 500

merged = pd.merge(income, lifespan, how='outer', on=['geo', 'time'])

print(merged.shape)
merged.head()
# Out:
# (50446, 4)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                              603.0
# 1  afg  1801                                              603.0
# 2  afg  1802                                              603.0
# 3  afg  1803                                              603.0
# 4  afg  1804                                              603.0
#
#    life_expectancy_years
# 0                  28.21
# 1                  28.20
# 2                  28.19
# 3                  28.18
# 4                  28.17

# %%
# how to check for duplicates using a specific subset of columns
merged.duplicated(subset=['geo', 'time']).value_counts()
# Out:
# False    50446
# dtype: int64

# %%
# Count the number of unique values in a specific column
# if the final number does not match the num_rows of the column
# then you have duplicates
merged['geo'].nunique()
# Out:
# 216

# %%
merged = pd.merge(income, lifespan, how='left', on=['geo', 'time'])

print(merged.shape)
merged.head()
# Out:
# (46513, 4)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years
# 0                  28.21
# 1                  28.20
# 2                  28.19
# 3                  28.18
# 4                  28.17

# %%
merged = pd.merge(income, lifespan, how='right', on=['geo', 'time'])

print(merged.shape)
merged.head()
# Out:
# (44370, 4)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                              603.0
# 1  afg  1801                                              603.0
# 2  afg  1802                                              603.0
# 3  afg  1803                                              603.0
# 4  afg  1804                                              603.0
#
#    life_expectancy_years
# 0                  28.21
# 1                  28.20
# 2                  28.19
# 3                  28.18
# 4                  28.17

# %%
merged = pd.merge(income, lifespan)
print(merged.shape)
merged.head()
# Out:
# (40437, 4)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years
# 0                  28.21
# 1                  28.20
# 2                  28.19
# 3                  28.18
# 4                  28.17

# %%
merged.duplicated(subset=['geo', 'time']).value_counts()
# Out:
# False    40437
# dtype: int64

# %%
df = pd.merge(merged, population)
print(df.shape)
df.head()
# Out:
# (40437, 5)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years  population_total
# 0                  28.21           3280000
# 1                  28.20           3280000
# 2                  28.19           3280000
# 3                  28.18           3280000
# 4                  28.17           3280000

# %%
df = pd.merge(df, 
              entities[['country', 'name', 'world_4region', 'world_6region']], 
              left_on='geo', right_on='country')
print(df.shape)
df.head()
# Out:
# (40437, 9)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years  population_total country         name world_4region  \
# 0                  28.21           3280000     afg  Afghanistan          asia
# 1                  28.20           3280000     afg  Afghanistan          asia
# 2                  28.19           3280000     afg  Afghanistan          asia
# 3                  28.18           3280000     afg  Afghanistan          asia
# 4                  28.17           3280000     afg  Afghanistan          asia
#
#   world_6region
# 0    south_asia
# 1    south_asia
# 2    south_asia
# 3    south_asia
# 4    south_asia

# %%
df = df.rename(columns = {
    'country': 'country_code',
    'time': 'year', 
    'income_per_person_gdppercapita_ppp_inflation_adjusted': 'income', 
    'life_expectancy_years': 'lifespan',
    'population_total': 'population',
    'name': 'country',
    'world_6region': '6region',
    'world_4region': '4region'
})

df.head()
# Out:
#    geo  year  income  lifespan  population country_code      country 4region  \
# 0  afg  1800     603     28.21     3280000          afg  Afghanistan    asia
# 1  afg  1801     603     28.20     3280000          afg  Afghanistan    asia
# 2  afg  1802     603     28.19     3280000          afg  Afghanistan    asia
# 3  afg  1803     603     28.18     3280000          afg  Afghanistan    asia
# 4  afg  1804     603     28.17     3280000          afg  Afghanistan    asia
#
#       6region
# 0  south_asia
# 1  south_asia
# 2  south_asia
# 3  south_asia
# 4  south_asia

# %% [markdown]
# ## Explore data

# %%
df.dtypes
# Out:
# geo              object
# year              int64
# income            int64
# lifespan        float64
# population        int64
# country_code     object
# country          object
# 4region          object
# 6region          object
# dtype: object

# %%
df.describe()
# Out:
#                year         income      lifespan    population
# count  40437.000000   40437.000000  40437.000000  4.043700e+04
# mean    1909.292900    4619.492717     43.132080  1.371204e+07
# std       63.308682   10209.571045     16.313228  6.606335e+07
# min     1800.000000     247.000000      1.000000  2.128000e+03
# 25%     1854.000000     876.000000     31.160000  4.113310e+05
# 50%     1909.000000    1442.000000     35.500000  1.985952e+06
# 75%     1964.000000    3488.000000     55.970000  6.499707e+06
# max     2018.000000  177522.000000     84.170000  1.415046e+09

# %%
df.describe(exclude='number')
# Out:
#           geo country_code country 4region              6region
# count   40437        40437   40437   40437                40437
# unique    187          187     187       4                    6
# top       tto          tto  Guinea  africa  europe_central_asia
# freq      219          219     219   11826                10778

# %%
usa = df[df.country == 'United States']
usa.head()
# Out:
#        geo  year  income  lifespan  population country_code        country  \
# 38028  usa  1800    2127     39.41     6801854          usa  United States
# 38029  usa  1801    2167     39.41     6933517          usa  United States
# 38030  usa  1802    2202     39.41     7067728          usa  United States
# 38031  usa  1803    2166     39.41     7204538          usa  United States
# 38032  usa  1804    2165     39.41     7343995          usa  United States
#
#         4region  6region
# 38028  americas  america
# 38029  americas  america
# 38030  americas  america
# 38031  americas  america
# 38032  americas  america

# %%
usa.describe()
# Out:
#               year        income    lifespan    population
# count   219.000000    219.000000  219.000000  2.190000e+02
# mean   1909.000000  14572.936073   54.846256  1.163662e+08
# std      63.364028  15066.042247   15.202079  9.738644e+07
# min    1800.000000   2113.000000   31.000000  6.801854e+06
# 25%    1854.500000   3512.500000   39.410000  2.752198e+07
# 50%    1909.000000   7989.000000   51.780000  9.236198e+07
# 75%    1963.500000  20090.500000   70.270000  1.962540e+08
# max    2018.000000  54898.000000   79.140000  3.267667e+08

# %%
usa[usa.year.isin([1818,1918,2018])]
# Out:
#        geo  year  income  lifespan  population country_code        country  \
# 38046  usa  1818    2258     39.41     9879049          usa  United States
# 38146  usa  1918    9371     47.18   106721812          usa  United States
# 38246  usa  2018   54898     79.14   326766748          usa  United States
#
#         4region  6region
# 38046  americas  america
# 38146  americas  america
# 38246  americas  america

# %%
china = df[df.country=='China']
china[china.year.isin([1818, 1918, 2018])]
# Out:
#       geo  year  income  lifespan  population country_code country 4region  \
# 6854  chn  1818     985     32.00   374161494          chn   China    asia
# 6954  chn  1918     989     22.13   462444535          chn   China    asia
# 7054  chn  2018   16018     76.92  1415045928          chn   China    asia
#
#                 6region
# 6854  east_asia_pacific
# 6954  east_asia_pacific
# 7054  east_asia_pacific

# %% [markdown]
# ## Plot visualization

# %%
import seaborn as sns

now = df[df.year == 2018]
then = df[df.year == 1918]
now.head()
# Out:
#       geo  year  income  lifespan  population country_code  \
# 218   afg  2018    1867     58.69    36373176          afg
# 437   ago  2018    5846     65.19    30774205          ago
# 656   alb  2018   12424     78.01     2934363          alb
# 922   are  2018   68231     76.89     9541615          are
# 1141  arg  2018   18942     76.97    44688864          arg
#
#                    country   4region                   6region
# 218            Afghanistan      asia                south_asia
# 437                 Angola    africa        sub_saharan_africa
# 656                Albania    europe       europe_central_asia
# 922   United Arab Emirates      asia  middle_east_north_africa
# 1141             Argentina  americas                   america

# %%
sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
            sizes=(30, 400), alpha=0.7, data=then)
plt.xscale('log')
plt.title("The World in 1918")
plt.ylim(0,85)
plt.xlim(0,100000)

sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
            sizes=(30, 400), alpha=0.7, data=now)
plt.xscale('log')
plt.title("the World in 2018")
plt.ylim(0,85)
plt.xlim(0,100000)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:1442: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ret = ax.set_xlim(*args, **kwargs)
# (483.5453734847516, 100000)

# %%
# We *can* still use the figure/axes syntax from matplotlib with seaborn
# but it's much more common to use it when working with multiple subplots
# if we're working with just a single graph, then we typically use 
# plt.blahblahblah (pyplot) syntax with seaborn

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,8))

sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
            sizes=(30, 400), alpha=0.7, data=then, ax=ax[0]);

sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
            sizes=(30, 400), alpha=0.7, data=now, ax=ax[1]);

# %% [markdown]
# ## Analyze outliers

# %%
# Qatar is the richest country in 2018
now.sort_values('income', ascending=False)
# Out:
#        geo  year  income  lifespan  population country_code  \
# 30362  qat  2018  121033     80.71     2694849          qat
# 22212  lux  2018   99034     82.39      590321          lux
# 31895  sgp  2018   83888     84.03     5791901          sgp
# 5521   brn  2018   76943     77.36      434076          brn
# 20241  kwt  2018   68359     79.96     4197128          kwt
# 922    are  2018   68231     76.89     9541615          are
# 16956  irl  2018   65622     81.49     4803748          irl
# 27296  nor  2018   64846     82.39     5353363          nor
# 6616   che  2018   57133     83.45     8544034          che
# 38246  usa  2018   54898     79.14   326766748          usa
# 31238  sau  2018   50114     77.64    33554343          sau
# 27077  nld  2018   48542     81.92    17084459          nld
# 34304  swe  2018   47520     82.37     9982709          swe
# 17613  isl  2018   47356     82.60      337780          isl
# 10167  dnk  2018   46583     81.10     5754356          dnk
# 1798   aus  2018   45783     82.87    24772247          aus
# 9682   deu  2018   45166     81.25    82293457          deu
# 2017   aut  2018   44645     81.84     8751820          aut
# 3769   bhr  2018   44330     77.18     1566993          bhr
# 6397   can  2018   43773     82.16    36953765          can
# 2674   bel  2018   42760     81.23    11498519          bel
# 12138  fin  2018   40290     82.06     5542517          fin
# 13233  gbr  2018   40079     81.19    66573504          gbr
# 18708  jpn  2018   39105     84.17   127185332          jpn
# 12576  fra  2018   39006     82.62    65233271          fra
# 27953  omn  2018   38900     78.06     4829946          omn
# 24230  mlt  2018   37938     81.75      432089          mlt
# 20022  kor  2018   36767     81.35    51164435          kor
# 27734  nzl  2018   36354     81.77     4749598          nzl
# 18051  ita  2018   35192     82.62    59290969          ita
# 11481  esp  2018   34742     83.23    46397452          esp
# 17832  isr  2018   33434     82.41     8452841          isr
# 9463   cze  2018   32302     79.37    10625250          cze
# 9244   cyp  2018   32205     80.79     1189085          cyp
# 33866  svk  2018   31357     77.16     5449816          svk
# 34085  svn  2018   30946     81.12     2081260          svn
# 21993  ltu  2018   30368     75.31     2876475          ltu
# 36713  tto  2018   30332     73.37     1372598          tto
# 11700  est  2018   29457     77.66     1306788          est
# 29705  prt  2018   27909     81.30    10291196          prt
# 29267  pol  2018   27668     78.19    38104832          pol
# 34742  syc  2018   27546     74.23       95235          syc
# 25982  mys  2018   27248     75.91    32042458          mys
# 16299  hun  2018   26936     75.90     9688847          hun
# 22431  lva  2018   25524     75.13     1929938          lva
# 14766  grc  2018   25498     81.34    11142161          grc
# 37151  tur  2018   24881     79.61    81916871          tur
# 30800  rus  2018   24786     71.07   143964709          rus
# 18927  kaz  2018   24171     71.96    18403860          kaz
# 30581  rou  2018   23399     75.53    19580634          rou
# 28391  pan  2018   23374     79.40     4162618          pan
# 6835   chl  2018   23366     80.66    18197209          chl
# 15861  hrv  2018   22620     77.66     4164783          hrv
# 3988   bhs  2018   21920     74.10      399285          bhs
# 38027  ury  2018   21254     77.57     3469551          ury
# 1579   atg  2018   21035     77.60      103050          atg
# 25544  mus  2018   21003     74.89     1268315          mus
# 14547  gnq  2018   20459     66.13     1313894          gnq
# 9025   cub  2018   19963     79.34    11489082          cub
# 1141   arg  2018   18942     76.97    44688864          arg
# 3550   bgr  2018   18853     75.32     7036848          bgr
# 21117  lby  2018   18254     75.47     6470956          lby
# 36056  tkm  2018   17856     70.48     5851466          tkm
# 13014  gab  2018   17463     67.33     2067561          gab
# 17175  irn  2018   17402     76.47    82011735          irn
# 23526  mex  2018   17288     76.78   130759074          mex
# 4426   blr  2018   17159     73.76     9452113          blr
# 35618  tha  2018   16914     78.15    69183173          tha
# 24668  mne  2018   16606     77.35      629219          mne
# 2236   aze  2018   16552     72.30     9923914          aze
# 5959   bwa  2018   16467     66.92     2333201          bwa
# 8806   cri  2018   16240     81.42     4953199          cri
# 5302   brb  2018   16037     76.84      286388          brb
# 7054   chn  2018   16018     76.92  1415045928          chn
# 17394  irq  2018   15867     68.02    39339753          irq
# 10386  dom  2018   15227     76.11    10882996          dom
# 32990  srb  2018   14815     76.17     8762027          srb
# 5083   bra  2018   14341     75.70   210867954          bra
# 38903  ven  2018   14211     75.91    32381221          ven
# 23792  mkd  2018   13956     75.17     2085051          mkd
# 10605  dza  2018   13726     77.86    42008054          dza
# 8149   col  2018   13704     78.62    49464683          col
# 14985  grd  2018   13505     71.86      108339          grd
# 20679  lbn  2018   13438     80.45     6093509          lbn
# 33647  sur  2018   13150     71.62      568301          sur
# 23307  mdv  2018   12984     80.08      444259          mdv
# 28610  per  2018   12723     80.21    32551815          per
# 656    alb  2018   12424     78.01     2934363          alb
# 21555  lka  2018   12382     77.82    20950041          lka
# 39998  zaf  2018   12321     63.50    57398421          zaf
# 24887  mng  2018   12100     68.69     3121772          mng
# 4207   bih  2018   12052     77.93     3503554          bih
# 16518  idn  2018   11650     72.03   266794980          idn
# 36932  tun  2018   11599     77.96    11659174          tun
# 38684  vct  2018   11362     72.03      110200          vct
# 21336  lca  2018   10887     76.57      179667          lca
# 11043  egy  2018   10848     72.57    99375741          egy
# 26201  nam  2018   10549     65.69     2587801          nam
# 10824  ecu  2018   10209     78.31    16863425          ecu
# 13452  geo  2018   10062     74.31     3907131          geo
# 5740   btn  2018    9929     74.83      817054          btn
# 12357  fji  2018    9422     65.75      912241          fji
# 29924  pry  2018    9279     74.78     6896908          pry
# 1360   arm  2018    8662     75.97     2934152          arm
# 18270  jam  2018    8517     75.18     2898677          jam
# 18489  jor  2018    8452     76.65     9903802          jor
# 37808  ukr  2018    8327     72.29    44009214          ukr
# 32552  slv  2018    8293     75.75     6411558          slv
# 28829  phl  2018    7957     70.55   106512074          phl
# 15423  guy  2018    7739     68.15      782225          guy
# 22650  mar  2018    7719     75.46    36191805          mar
# 4645   blz  2018    7710     72.45      382444          blz
# 34523  swz  2018    7604     58.64     1391385          swz
# 15204  gtm  2018    7533     73.20    17245346          gtm
# 4864   bol  2018    6975     73.97    11215674          bol
# 16737  ind  2018    6890     69.10  1354051854          ind
# 38465  uzb  2018    6688     70.50    32364996          uzb
# 39122  vnm  2018    6553     74.88    96491146          vnm
# 8587   cpv  2018    6419     74.06      553335          cpv
# 20460  lao  2018    6306     67.93     6961210          lao
# 24449  mmr  2018    6104     70.31    53855735          mmr
# 39560  wsm  2018    5950     72.38      197695          wsm
# 437    ago  2018    5846     65.19    30774205          ago
# 7930   cog  2018    5616     63.86     5399895          cog
# 26639  nga  2018    5569     66.14   195875237          nga
# 36494  ton  2018    5499     70.70      109008          ton
# 26858  nic  2018    5470     78.72     6284757          nic
# 22869  mda  2018    5330     72.41     4041065          mda
# 28172  pak  2018    5221     67.96   200813818          pak
# 15642  hnd  2018    4591     73.06     9417167          hnd
# 31457  sdn  2018    4441     68.77    41511526          sdn
# 13671  gha  2018    4375     66.62    29463643          gha
# 40217  zmb  2018    3865     59.45    17609178          zmb
# 19584  khm  2018    3832     69.35    16245729          khm
# 7273   civ  2018    3764     61.16    24905843          civ
# 3331   bgd  2018    3722     73.41   166368149          bgd
# 25325  mrt  2018    3671     70.57     4540068          mrt
# 9901   dji  2018    3539     67.10      971408          dji
# 19365  kgz  2018    3493     71.45     6132932          kgz
# 12795  fsm  2018    3409     65.80      106227          fsm
# 33428  stp  2018    3185     70.86      208818          stp
# 7492   cmr  2018    3170     61.22    24678234          cmr
# 19146  ken  2018    3109     67.35    50950879          ken
# 21774  lso  2018    2960     51.12     2263010          lso
# 35837  tjk  2018    2922     72.19     9107211          tjk
# 34961  syr  2018    2900     69.82    18284407          syr
# 39341  vut  2018    2896     64.30      282117          vut
# 29048  png  2018    2804     61.14     8418346          png
# 37370  tza  2018    2780     65.46    59091392          tza
# 30143  pse  2018    2704     72.19     5052776          pse
# 31676  sen  2018    2573     66.85    16294270          sen
# 39779  yem  2018    2434     67.14    28915284          yem
# 27515  npl  2018    2424     71.51    29624035          npl
# 2893   ben  2018    2165     64.98    11485674          ben
# 32114  slb  2018    2106     63.57      623281          slb
# 24011  mli  2018    2021     62.91    19107706          mli
# 40436  zwe  2018    1952     60.18    16913261          zwe
# 31019  rwa  2018    1932     68.33    12501156          rwa
# 19803  kir  2018    1888     62.23      118414          kir
# 218    afg  2018    1867     58.69    36373176          afg
# 35180  tcd  2018    1855     60.52    15353184          tcd
# 33209  ssd  2018    1822     60.72    12919053          ssd
# 37589  uga  2018    1818     62.86    44270563          uga
# 11919  eth  2018    1801     66.42   107534882          eth
# 16080  hti  2018    1713     64.52    11112945          hti
# 3112   bfa  2018    1710     61.60    19751651          bfa
# 14109  gmb  2018    1574     67.84     2163765          gmb
# 14328  gnb  2018    1547     59.66     1907268          gnb
# 32333  sle  2018    1492     60.00     7719729          sle
# 36275  tls  2018    1487     73.34     1324094          tls
# 35399  tgo  2018    1478     63.09     7990926          tgo
# 23088  mdg  2018    1455     63.40    26262810          mdg
# 8368   com  2018    1439     68.00      832347          com
# 29486  prk  2018    1387     71.13    25610672          prk
# 13890  gin  2018    1282     61.90    13052608          gin
# 11262  eri  2018    1252     64.56     5187948          eri
# 25106  moz  2018    1196     61.07    30528673          moz
# 25763  mwi  2018    1134     61.03    19164728          mwi
# 26420  ner  2018     949     62.45    22311375          ner
# 20898  lbr  2018     801     65.43     4853516          lbr
# 7711   cod  2018     751     62.42    84004989          cod
# 2455   bdi  2018     691     61.14    11216450          bdi
# 6178   caf  2018     689     51.58     4737423          caf
# 32771  som  2018     629     58.03    15181925          som
#
#                               country   4region                   6region
# 30362                           Qatar      asia  middle_east_north_africa
# 22212                      Luxembourg    europe       europe_central_asia
# 31895                       Singapore      asia         east_asia_pacific
# 5521                           Brunei      asia         east_asia_pacific
# 20241                          Kuwait      asia  middle_east_north_africa
# 922              United Arab Emirates      asia  middle_east_north_africa
# 16956                         Ireland    europe       europe_central_asia
# 27296                          Norway    europe       europe_central_asia
# 6616                      Switzerland    europe       europe_central_asia
# 38246                   United States  americas                   america
# 31238                    Saudi Arabia      asia  middle_east_north_africa
# 27077                     Netherlands    europe       europe_central_asia
# 34304                          Sweden    europe       europe_central_asia
# 17613                         Iceland    europe       europe_central_asia
# 10167                         Denmark    europe       europe_central_asia
# 1798                        Australia      asia         east_asia_pacific
# 9682                          Germany    europe       europe_central_asia
# 2017                          Austria    europe       europe_central_asia
# 3769                          Bahrain      asia  middle_east_north_africa
# 6397                           Canada  americas                   america
# 2674                          Belgium    europe       europe_central_asia
# 12138                         Finland    europe       europe_central_asia
# 13233                  United Kingdom    europe       europe_central_asia
# 18708                           Japan      asia         east_asia_pacific
# 12576                          France    europe       europe_central_asia
# 27953                            Oman      asia  middle_east_north_africa
# 24230                           Malta    europe       europe_central_asia
# 20022                     South Korea      asia         east_asia_pacific
# 27734                     New Zealand      asia         east_asia_pacific
# 18051                           Italy    europe       europe_central_asia
# 11481                           Spain    europe       europe_central_asia
# 17832                          Israel      asia  middle_east_north_africa
# 9463                   Czech Republic    europe       europe_central_asia
# 9244                           Cyprus    europe       europe_central_asia
# 33866                 Slovak Republic    europe       europe_central_asia
# 34085                        Slovenia    europe       europe_central_asia
# 21993                       Lithuania    europe       europe_central_asia
# 36713             Trinidad and Tobago  americas                   america
# 11700                         Estonia    europe       europe_central_asia
# 29705                        Portugal    europe       europe_central_asia
# 29267                          Poland    europe       europe_central_asia
# 34742                      Seychelles    africa        sub_saharan_africa
# 25982                        Malaysia      asia         east_asia_pacific
# 16299                         Hungary    europe       europe_central_asia
# 22431                          Latvia    europe       europe_central_asia
# 14766                          Greece    europe       europe_central_asia
# 37151                          Turkey    europe       europe_central_asia
# 30800                          Russia    europe       europe_central_asia
# 18927                      Kazakhstan      asia       europe_central_asia
# 30581                         Romania    europe       europe_central_asia
# 28391                          Panama  americas                   america
# 6835                            Chile  americas                   america
# 15861                         Croatia    europe       europe_central_asia
# 3988                          Bahamas  americas                   america
# 38027                         Uruguay  americas                   america
# 1579              Antigua and Barbuda  americas                   america
# 25544                       Mauritius    africa        sub_saharan_africa
# 14547               Equatorial Guinea    africa        sub_saharan_africa
# 9025                             Cuba  americas                   america
# 1141                        Argentina  americas                   america
# 3550                         Bulgaria    europe       europe_central_asia
# 21117                           Libya    africa  middle_east_north_africa
# 36056                    Turkmenistan      asia       europe_central_asia
# 13014                           Gabon    africa        sub_saharan_africa
# 17175                            Iran      asia  middle_east_north_africa
# 23526                          Mexico  americas                   america
# 4426                          Belarus    europe       europe_central_asia
# 35618                        Thailand      asia         east_asia_pacific
# 24668                      Montenegro    europe       europe_central_asia
# 2236                       Azerbaijan    europe       europe_central_asia
# 5959                         Botswana    africa        sub_saharan_africa
# 8806                       Costa Rica  americas                   america
# 5302                         Barbados  americas                   america
# 7054                            China      asia         east_asia_pacific
# 17394                            Iraq      asia  middle_east_north_africa
# 10386              Dominican Republic  americas                   america
# 32990                          Serbia    europe       europe_central_asia
# 5083                           Brazil  americas                   america
# 38903                       Venezuela  americas                   america
# 23792                  Macedonia, FYR    europe       europe_central_asia
# 10605                         Algeria    africa  middle_east_north_africa
# 8149                         Colombia  americas                   america
# 14985                         Grenada  americas                   america
# 20679                         Lebanon      asia  middle_east_north_africa
# 33647                        Suriname  americas                   america
# 23307                        Maldives      asia                south_asia
# 28610                            Peru  americas                   america
# 656                           Albania    europe       europe_central_asia
# 21555                       Sri Lanka      asia                south_asia
# 39998                    South Africa    africa        sub_saharan_africa
# 24887                        Mongolia      asia         east_asia_pacific
# 4207           Bosnia and Herzegovina    europe       europe_central_asia
# 16518                       Indonesia      asia         east_asia_pacific
# 36932                         Tunisia    africa  middle_east_north_africa
# 38684  St. Vincent and the Grenadines  americas                   america
# 21336                       St. Lucia  americas                   america
# 11043                           Egypt    africa  middle_east_north_africa
# 26201                         Namibia    africa        sub_saharan_africa
# 10824                         Ecuador  americas                   america
# 13452                         Georgia    europe       europe_central_asia
# 5740                           Bhutan      asia                south_asia
# 12357                            Fiji      asia         east_asia_pacific
# 29924                        Paraguay  americas                   america
# 1360                          Armenia    europe       europe_central_asia
# 18270                         Jamaica  americas                   america
# 18489                          Jordan      asia  middle_east_north_africa
# 37808                         Ukraine    europe       europe_central_asia
# 32552                     El Salvador  americas                   america
# 28829                     Philippines      asia         east_asia_pacific
# 15423                          Guyana  americas                   america
# 22650                         Morocco    africa  middle_east_north_africa
# 4645                           Belize  americas                   america
# 34523                       Swaziland    africa        sub_saharan_africa
# 15204                       Guatemala  americas                   america
# 4864                          Bolivia  americas                   america
# 16737                           India      asia                south_asia
# 38465                      Uzbekistan      asia       europe_central_asia
# 39122                         Vietnam      asia         east_asia_pacific
# 8587                       Cape Verde    africa        sub_saharan_africa
# 20460                             Lao      asia         east_asia_pacific
# 24449                         Myanmar      asia         east_asia_pacific
# 39560                           Samoa      asia         east_asia_pacific
# 437                            Angola    africa        sub_saharan_africa
# 7930                      Congo, Rep.    africa        sub_saharan_africa
# 26639                         Nigeria    africa        sub_saharan_africa
# 36494                           Tonga      asia         east_asia_pacific
# 26858                       Nicaragua  americas                   america
# 22869                         Moldova    europe       europe_central_asia
# 28172                        Pakistan      asia                south_asia
# 15642                        Honduras  americas                   america
# 31457                           Sudan    africa        sub_saharan_africa
# 13671                           Ghana    africa        sub_saharan_africa
# 40217                          Zambia    africa        sub_saharan_africa
# 19584                        Cambodia      asia         east_asia_pacific
# 7273                    Cote d'Ivoire    africa        sub_saharan_africa
# 3331                       Bangladesh      asia                south_asia
# 25325                      Mauritania    africa        sub_saharan_africa
# 9901                         Djibouti    africa  middle_east_north_africa
# 19365                 Kyrgyz Republic      asia       europe_central_asia
# 12795           Micronesia, Fed. Sts.      asia         east_asia_pacific
# 33428           Sao Tome and Principe    africa        sub_saharan_africa
# 7492                         Cameroon    africa        sub_saharan_africa
# 19146                           Kenya    africa        sub_saharan_africa
# 21774                         Lesotho    africa        sub_saharan_africa
# 35837                      Tajikistan      asia       europe_central_asia
# 34961                           Syria      asia  middle_east_north_africa
# 39341                         Vanuatu      asia         east_asia_pacific
# 29048                Papua New Guinea      asia         east_asia_pacific
# 37370                        Tanzania    africa        sub_saharan_africa
# 30143                       Palestine      asia  middle_east_north_africa
# 31676                         Senegal    africa        sub_saharan_africa
# 39779                           Yemen      asia  middle_east_north_africa
# 27515                           Nepal      asia                south_asia
# 2893                            Benin    africa        sub_saharan_africa
# 32114                 Solomon Islands      asia         east_asia_pacific
# 24011                            Mali    africa        sub_saharan_africa
# 40436                        Zimbabwe    africa        sub_saharan_africa
# 31019                          Rwanda    africa        sub_saharan_africa
# 19803                        Kiribati      asia         east_asia_pacific
# 218                       Afghanistan      asia                south_asia
# 35180                            Chad    africa        sub_saharan_africa
# 33209                     South Sudan    africa        sub_saharan_africa
# 37589                          Uganda    africa        sub_saharan_africa
# 11919                        Ethiopia    africa        sub_saharan_africa
# 16080                           Haiti  americas                   america
# 3112                     Burkina Faso    africa        sub_saharan_africa
# 14109                          Gambia    africa        sub_saharan_africa
# 14328                   Guinea-Bissau    africa        sub_saharan_africa
# 32333                    Sierra Leone    africa        sub_saharan_africa
# 36275                     Timor-Leste      asia         east_asia_pacific
# 35399                            Togo    africa        sub_saharan_africa
# 23088                      Madagascar    africa        sub_saharan_africa
# 8368                          Comoros    africa        sub_saharan_africa
# 29486                     North Korea      asia         east_asia_pacific
# 13890                          Guinea    africa        sub_saharan_africa
# 11262                         Eritrea    africa        sub_saharan_africa
# 25106                      Mozambique    africa        sub_saharan_africa
# 25763                          Malawi    africa        sub_saharan_africa
# 26420                           Niger    africa        sub_saharan_africa
# 20898                         Liberia    africa        sub_saharan_africa
# 7711                 Congo, Dem. Rep.    africa        sub_saharan_africa
# 2455                          Burundi    africa        sub_saharan_africa
# 6178         Central African Republic    africa        sub_saharan_africa
# 32771                         Somalia    africa        sub_saharan_africa

# %%
now_qatar = now[now.country=='Qatar']
now_qatar.head()
# Out:
#        geo  year  income  lifespan  population country_code country 4region  \
# 30362  qat  2018  121033     80.71     2694849          qat   Qatar    asia
#
#                         6region
# 30362  middle_east_north_africa

# %%
sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
            sizes=(30,400), data=now)
plt.xscale('log')
plt.ylim(0,90)
plt.title("Qatar is Really Rich")
plt.text(x=now_qatar.income-5000, y= now_qatar.lifespan+1, s='Qatar')
plt.show()

# %% [markdown]
# ## Plot multiple years

# %%
years = [1818, 1918, 2018]
centuries = df[df.year.isin(years)]

centuries.head()
# Out:
#      geo  year  income  lifespan  population country_code      country  \
# 18   afg  1818     604     28.03     3308390          afg  Afghanistan
# 118  afg  1918     849      7.89     5704092          afg  Afghanistan
# 218  afg  2018    1867     58.69    36373176          afg  Afghanistan
# 237  ago  1818     668     26.98     1586896          ago       Angola
# 337  ago  1918    1174     12.01     3487015          ago       Angola
#
#     4region             6region
# 18     asia          south_asia
# 118    asia          south_asia
# 218    asia          south_asia
# 237  africa  sub_saharan_africa
# 337  africa  sub_saharan_africa

# %%
fig = sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
                  sizes=(30,400), col='year', data=centuries)

axes = fig.axes.flatten()
axes[0].set_title('Poor and Sick in 1818')
axes[1].set_title('Healthier, but still poor in 1918')
axes[2].set_title('Healthier and Richer in 2018');

# %% [markdown]
# ## Point out a story

# %%
years = [1918, 1938, 1978, 1998, 2018]

# %%
for year in years:
  sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
              sizes=(30,400), data=df[df.year==year])
  plt.xscale('log')
  plt.xlim((150, 150000))
  plt.ylim((0, 90))
  plt.title('Countries Above the Poverty Line in ' + str(year))
  plt.axvline(x=1000, color='grey')
