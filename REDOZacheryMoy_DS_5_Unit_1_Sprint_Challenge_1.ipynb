# %% [markdown]
# <a href="https://colab.research.google.com/github/zacherymoy/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/REDOZacheryMoy_DS_5_Unit_1_Sprint_Challenge_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Unit 1 Sprint Challenge 1
#
# ## Loading, cleaning, visualizing, and analyzing data
#
# In this sprint challenge you will look at a dataset of the survival of patients who underwent surgery for breast cancer.
#
# http://archive.ics.uci.edu/ml/datasets/Haberman%27s+Survival
#
# Data Set Information:
# The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# Attribute Information:
# 1. Age of patient at time of operation (numerical)
# 2. Patient's year of operation (year - 1900, numerical)
# 3. Number of positive axillary nodes detected (numerical)
# 4. Survival status (class attribute)
# -- 1 = the patient survived 5 years or longer
# -- 2 = the patient died within 5 year
#
# Sprint challenges are evaluated based on satisfactory completion of each part. It is suggested you work through it in order, getting each aspect reasonably working, before trying to deeply explore, iterate, or refine any given step. Once you get to the end, if you want to go back and improve things, go for it!

# %% [markdown]
# ## Part 1 - Load and validate the data
#
# - Load the data as a `pandas` data frame.
# - Validate that it has the appropriate number of observations (you can check the raw file, and also read the dataset description from UCI).
# - Validate that you have no missing values.
# - Add informative names to the features.
# - The survival variable is encoded as 1 for surviving >5 years and 2 for not - change this to be 0 for not surviving and 1 for surviving >5 years (0/1 is a more traditional encoding of binary variables)
#
# At the end, print the first five rows of the dataset to demonstrate the above.

# %%
# TODO
import pandas as pd
haberman_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data', header=None)
haberman_data.head()
# Out:
#     0   1  2  3
# 0  30  64  1  1
# 1  30  62  3  1
# 2  30  65  0  1
# 3  31  59  2  1
# 4  31  65  4  1

# %% [markdown]
# **Validate that it has the appropriate number of observations (you can check the raw file, and also read the dataset description from UCI).**
#
# Dataset description Link: http://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.names
# Number of Instances: 306
# Number of Attributes: 3

# %% [markdown]
# **- Validate that you have no missing values.**
# UCI states no missing values.

# %%
haberman_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ***- Add informative names to the features.**
# ***

# %%
haberman_data.columns=['age', 'Patient year of operation', 'Number of positive axillary nodes detected', 'Survival status'] 
haberman_data.head()
# Out:
#    age  ...  Survival status
# 0   30  ...                1
# 1   30  ...                1
# 2   30  ...                1
# 3   31  ...                1
# 4   31  ...                1
#
# [5 rows x 4 columns]

# %% [markdown]
# ![alt text](https://)
# ***  The survival variable is encoded as 1 for surviving >5 years and 2 for not - change this to be 0 for not surviving and 1 for surviving >5 years (0/1 is a more traditional encoding of binary variables)**
# ****

# %% [markdown]
# **At the end, print the first five rows of the dataset to demonstrate the above.**

# %%
haberman_data['Survival status'].replace(2, 0, inplace=True)

# %%
haberman_data.head()
# Out:
#    age  ...  Survival status
# 0   30  ...                1
# 1   30  ...                1
# 2   30  ...                1
# 3   31  ...                1
# 4   31  ...                1
#
# [5 rows x 4 columns]

# %% [markdown]
# ## Part 2 - Examine the distribution and relationships of the features
#
# Explore the data - create at least *2* tables (can be summary statistics or crosstabulations) and *2* plots illustrating the nature of the data.
#
# This is open-ended, so to remind - first *complete* this task as a baseline, then go on to the remaining sections, and *then* as time allows revisit and explore further.
#
# Hint - you may need to bin some variables depending on your chosen tables/plots.

# %%
haberman_data.describe()
# Out:
#               age  ...  Survival status
# count  306.000000  ...       306.000000
# mean    52.457516  ...         0.735294
# std     10.803452  ...         0.441899
# min     30.000000  ...         0.000000
# 25%     44.000000  ...         0.000000
# 50%     52.000000  ...         1.000000
# 75%     60.750000  ...         1.000000
# max     83.000000  ...         1.000000
#
# [8 rows x 4 columns]

# %%
pd.crosstab(haberman_data['age'], haberman_data['Number of positive axillary nodes detected'])
# Out:
# Number of positive axillary nodes detected  0   1   2   3   ...  30  35  46  52
# age                                                         ...
# 30                                           1   1   0   1  ...   0   0   0   0
# 31                                           0   0   1   0  ...   0   0   0   0
# 33                                           1   0   0   0  ...   0   0   0   0
# 34                                           2   1   0   0  ...   1   0   0   0
# 35                                           1   0   0   0  ...   0   0   0   0
# 36                                           1   1   0   0  ...   0   0   0   0
# 37                                           4   0   0   0  ...   0   0   0   0
# 38                                           3   2   1   1  ...   0   0   0   0
# 39                                           4   0   1   0  ...   0   0   0   0
# 40                                           2   0   1   0  ...   0   0   0   0
# ...

# %%
bins = [30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 85]
names = ['30-35', '35-40', '40-45', '45-50', '50-55', '55-60', '60-65', '65-70', '70-75', '75-80', '80-85']

haberman_data['AgeRange2'] = pd.cut(haberman_data['age'], bins, labels= names)

# %%
haberman_data.plot.scatter('age', 'Number of positive axillary nodes detected')

# %%
pd.crosstab(haberman_data['age'], haberman_data['Survival status'])
# Out:
# Survival status  0   1
# age
# 30               0   3
# 31               0   2
# 33               0   2
# 34               2   5
# 35               0   2
# 36               0   2
# 37               0   6
# 38               1   9
# 39               1   5
# 40               0   3
# 41               3   7
# 42               2   7
# 43               4   7
# 44               3   4
# 45               3   6
# 46               4   3
# 47               3   8
# 48               3   4
# 49               2   8
# 50               2  10
# 51               2   4
# 52               4  10
# 53               6   5
# 54               4   9
# 55               2   8
# 56               2   5
# 57               3   8
# 58               0   7
# 59               1   7
# 60               2   4
# 61               3   6
# 62               3   4
# 63               1   7
# 64               0   5
# 65               4   6
# 66               2   3
# 67               2   4
# 68               0   2
# ...

# %%
bins = [30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 85]
names = ['30-35', '35-40', '40-45', '45-50', '50-55', '55-60', '60-65', '65-70', '70-75', '75-80', '80-85']

haberman_data['AgeRange1'] = pd.cut(haberman_data['age'], bins, labels= names)

# %%
haberman_data.plot.scatter('age', 'Survival status')

# %%
pd.crosstab(haberman_data['Patient year of operation'], haberman_data['Survival status'])
# Out:
# Survival status             0   1
# Patient year of operation
# 58                         12  24
# 59                          9  18
# 60                          4  24
# 61                          3  23
# 62                          7  16
# 63                          8  22
# 64                          8  23
# 65                         13  15
# 66                          6  22
# 67                          4  21
# 68                          3  10
# 69                          4   7

# %%
bins = [58, 60, 62, 64, 66, 68, 70]
names = ['58-60', '60-62', '62-64', '64-66', '66-68', '68-70']

haberman_data['AgeRange'] = pd.cut(haberman_data['Patient year of operation'], bins, labels= names)

# %%
haberman_data.plot.scatter('Patient year of operation', 'Survival status')

# %%
pd.crosstab(haberman_data['Number of positive axillary nodes detected'], haberman_data['Survival status'])
# Out:
# Survival status                              0    1
# Number of positive axillary nodes detected
# 0                                           19  117
# 1                                            8   33
# 2                                            5   15
# 3                                            7   13
# 4                                            3   10
# 5                                            4    2
# 6                                            3    4
# 7                                            2    5
# 8                                            2    5
# 9                                            4    2
# 10                                           1    2
# 11                                           3    1
# 12                                           1    1
# 13                                           4    1
# 14                                           1    3
# 15                                           2    1
# ...

# %%
haberman_data.plot.scatter('Number of positive axillary nodes detected', 'Survival status')

# %% [markdown]
# ## Part 3 - Analysis and Interpretation
#
# Now that you've looked at the data, answer the following questions:
#
# - What is at least one feature that looks to have a positive relationship with survival?
# - What is at least one feature that looks to have a negative relationship with survival?
# - How are those two features related with each other, and what might that mean?
#
# Answer with text, but feel free to intersperse example code/results or refer to it from earlier.

# %%
There doesn't look like there's any positive or negative relationships with survival with age, number of 
positive auxilliary nodes, and patient year of operation.
