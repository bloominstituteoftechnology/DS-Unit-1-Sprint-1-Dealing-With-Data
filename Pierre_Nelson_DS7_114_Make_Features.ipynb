# %% [markdown]
# <a href="https://colab.research.google.com/github/alxanderpierre/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/Pierre_Nelson_DS7_114_Make_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame({'animal': ['cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog'], 
                   'country': ['USA', 'Canada', 'Canada', 'Canada', 'USA', 'Canada', 'USA', 'USA'], 
                   'gender': ['male','female','male','male','male','male','female','female'],
                   'cat_integers': [1,1,0,1,0,1,0,0]})

df.head(8)
# Out:
#   animal country  gender  cat_integers
# 0    cat     USA    male             1
# 1    cat  Canada  female             1
# 2    dog  Canada    male             0
# 3    cat  Canada    male             1
# 4    dog     USA    male             0
# 5    cat  Canada    male             1
# 6    dog     USA  female             0
# 7    dog     USA  female             0

# %%
pd.crosstab(df['animal'], df['country'])
# Out:
# country  Canada  USA
# animal
# cat           3    1
# dog           1    3

# %%
pd.crosstab(df['country'], df['gender'])
# Out:
# gender   female  male
# country
# Canada        1     3
# USA           2     2

# %%
pd.crosstab(df['country'], df['gender'], normalize='columns')
# Out:
# gender     female  male
# country
# Canada   0.333333   0.6
# USA      0.666667   0.4

# %%
pd.crosstab(df['country'], df['gender'], normalize='index')
# Out:
# gender   female  male
# country
# Canada     0.25  0.75
# USA        0.50  0.50

# %%
pd.crosstab(df['country'], df['gender'], normalize=True )
# Out:
# gender   female   male
# country
# Canada    0.125  0.375
# USA       0.250  0.250

# %%
pd.crosstab(df['country'],[df['gender'], df['animal']])
# Out:
# gender  female     male
# animal     cat dog  cat dog
# country
# Canada       1   0    2   1
# USA          0   2    1   1

# %%
pd.crosstab(df['country'], [df['gender'], df['animal']], margins=True,).T
# Out:
# country        Canada  USA  All
# gender animal
# female cat          1    0    1
#        dog          0    2    2
# male   cat          2    1    3
#        dog          1    1    2
# All                 4    4    8

# %%
crosstab = pd.crosstab(df['country'], [df['gender'], df['animal']], margins=True,)

# %%
crosstab.hist();

# %%
crosstab.plot();

# %% [markdown]
# # Make features
#
# Objectives
# -  understand the purpose of feature engineering
# -  work with strings in pandas
# - work with dates and times in pandas
#
# Links
# - [Feature Engineering](https://en.wikipedia.org/wiki/Feature_engineering)
# - Python Data Science Handbook
#   - [Chapter 3.10](https://jakevdp.github.io/PythonDataScienceHandbook/03.10-working-with-strings.html), Vectorized String Operations
#   - [Chapter 3.11](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html), Working with Time Series
# - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-08-08 22:11:11--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [        <=>         ]  21.56M  1.69MB/s    in 13s
#
# 2019-08-08 22:11:24 (1.68 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22606280]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4404.61","4404.61","1701.34","1701.34","1195.39","505.95","0.0","0.0","0.0","Jul-2019","190.21","Aug-2019","Jul-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %% [markdown]
# ## Load LendingClub data
#
# pandas documentation
# - [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# - [`options.display`](https://pandas.pydata.org/pandas-docs/stable/options.html#available-options)

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')

# %%
print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       4000         4000           4000.0   36 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN      23000        23000          23000.0   60 months
# 4 NaN        NaN       8000         8000           8000.0   36 months
#
#   int_rate  installment grade sub_grade       emp_title emp_length  \
# 0   10.33%       324.23     B        B1             NaN   < 1 year
# 1   23.40%       155.68     E        E1        Security    3 years
# 2   17.97%       180.69     D        D1  Administrative    6 years
# 3   20.89%       620.81     D        D4        Operator    5 years
# 4   23.40%       311.35     E        E1         Manager  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d        loan_status  \
# ...

# %%
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128407   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128408   15.02%       346.76     C        C3        security guard    5 years
# 128409   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128410   11.06%       327.68     B        B3                   NaN        NaN
# 128411   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
df = df.drop(['id', 'member_id', 'url', 'desc'], axis=1) #dropping all the columns that have nothing but nan values (not there for privacy response)

# %%
df = df.drop(['hardship_loan_status','hardship_dpd' ,'hardship_reason' , 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date','hardship_end_date' ,'hardship_length' ], axis=1)

# %%
df.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# ## Work with strings

# %% [markdown]
# For machine learning, we usually want to replace strings with numbers.
#
# We can get info about which columns have a datatype of "object" (strings)

# %%
df.dtypes

# %%
df.int_rate

# %%
#int_rate = '15.02%'
#int_rate[:-1]

# %%
#int_rate.strip('%')

# %%
type(int_rate.strip('%'))
# Out:
# str

# %%
example = float(int_rate.strip('%'))

# %%
example
# Out:
# 15.02

# %% [markdown]
# ### List Comprehension Example

# %%
def remove_percent_to_float(string):
  return float(string.strip('%'))

# %%
int_list = ['15.02%', '17.08%', '13.80%']
[remove_percent_to_float(item) for item in int_list]
# Out:
# [15.02, 17.08, 13.8]

# %%
df['int_rate'] = df['int_rate'].apply(remove_percent_to_float)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
df.int_rate

# %%
df.int_rate.dtype
# Out:
# dtype('float64')

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].value_counts(dropna=False).head(10)
# Out:
# NaN                 20947
# Teacher              2090
# Manager              1773
# Registered Nurse      952
# Driver                924
# RN                    726
# Supervisor            697
# Sales                 580
# Project Manager       526
# General Manager       523
# Name: emp_title, dtype: int64

# %%
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
import numpy as np

# %%
type(np.NaN)
# Out:
# float

# %%
example = ['owner','Supervisor', 'Project Manager', np.NaN]

# %%
def clean_title(item): 
  if isinstance(item, str):
    return item.strip().title()
  else:
    return 'Unknown'

[clean_title(item) for item in example]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

# %%
df.emp_title.value_counts(dropna=False).head(10)
# Out:
# Unknown             20947
# Teacher              2557
# Manager              2395
# Registered Nurse     1418
# Driver               1258
# Supervisor           1160
# Truck Driver          920
# Rn                    834
# Office Manager        805
# Sales                 803
# Name: emp_title, dtype: int64

# %%
df.emp_title.nunique()
# Out:
# 34902

# %%
pd.value_counts(df['emp_title'])

# %%
df.emp_title.nunique()
# Out:
# 34902

# %% [markdown]
# ### Create `emp_title_manager`
#
# pandas documentation: [`str.contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html)

# %%
df.emp_title_manager = True
print(df.emp_title_manager)
# Out:
# True

# %%
df['emp_title_manager'] = True
print(df['emp_title_manager'])

# %%
df['emp_title_manager'] = df['emp_title'].str.contains('Manager')

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
#Dataframe Filtering Example

# %%
print(df.emp_title_manager)

# %%
condition = (df['emp_title_manager'] == True)
managers = df[condition]
print(managers.shape)
# Out:
# (17882, 132)

# %%
managers.head()
# Out:
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 4        8000         8000           8000.0   36 months     23.40
# 21      35000        35000          35000.0   60 months     15.02
# 30      25000        25000          25000.0   60 months     16.14
# 35       8000         8000           8000.0   36 months     11.80
# 46      16500        16500          16500.0   60 months     17.97
#
#     installment grade sub_grade           emp_title emp_length home_ownership  \
# 4        311.35     E        E1             Manager  10+ years            OWN
# 21       833.02     C        C3    Sr Sales Manager  10+ years       MORTGAGE
# 30       609.82     C        C4  Production Manager    5 years       MORTGAGE
# 35       264.96     B        B4     Program Manager    7 years       MORTGAGE
# 46       418.73     D        D1        Case Manager    5 years       MORTGAGE
#
#     annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
not_manager = df[df['emp_title_manager'] == False]
print(not_manager.shape)
not_manager.head()
# Out:
# (110530, 132)
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 5      32075        32075          32075.0   60 months     11.80       710.26
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1            Security    3 years           RENT     90000.0
# 2     D        D1      Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4            Operator    5 years           RENT     68107.0
# 5     B        B4  Nursing Supervisor  10+ years       MORTGAGE    150000.0
#
# ...

# %%
managers['int_rate'].hist(bins=20)

# %%
not_manager['int_rate'].hist(bins=20);

# %%
managers.int_rate.plot.density();

# %%
not_manager.int_rate.plot.density();

# %%
managers.int_rate.mean()
# Out:
# 12.760582149647123

# %%
not_manager.int_rate.mean()
# Out:
# 12.957292318828944

# %% [markdown]
# ## Work with dates

# %%
df.issue_d.head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
df.issue_d.describe()
# Out:
# count       128412
# unique           3
# top       Oct-2018
# freq         46305
# Name: issue_d, dtype: object

# %%
df.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df.issue_d.head()
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
df.issue_d.dt.year.head()
# Out:
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# Name: issue_d, dtype: int64

# %%
df.issue_d.dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
# 5         12
# 6         12
# 7         12
# 8         12
# 9         12
# 10        12
# 11        12
# 12        12
# 13        12
# 14        12
# 15        12
# 16        12
# 17        12
# 18        12
# 19        12
# 20        12
# 21        12
# 22        12
# 23        12
# 24        12
# 25        12
# 26        12
# 27        12
# 28        12
# 29        12
# 30        12
# 31        12
# 32        12
# 33        12
# 34        12
# 35        12
# 36        12
# 37        12
# 38        12
# 39        12
# 40        12
# 41        12
# 42        12
# 43        12
# 44        12
# 45        12
# 46        12
# 47        12
# 48        12
# 49        12
# 50        12
# 51        12
# 52        12
# 53        12
# 54        12
# 55        12
# 56        12
# 57        12
# 58        12
# 59        12
# 60        12
# 61        12
# 62        12
# 63        12
# 64        12
# 65        12
# ...

# %%
df['isssue_year'] = df.issue_d.dt.year

# %%
df['issue_month'] = df.issue_d.dt.month

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df.earliest_cr_line.head()
# Out:
# 0    Jan-1996
# 1    Sep-2006
# 2    Apr-2011
# 3    Feb-1997
# 4    Jan-1995
# Name: earliest_cr_line, dtype: object

# %%
df.earliest_cr_line = pd.to_datetime(df['earliest_cr_line'], 
                                     infer_datetime_format=False)

# %%
df['days_from_earliest_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df.days_from_earliest_credit_to_issue.describe()
# Out:
# count    128412.000000
# mean       5859.891490
# std        2886.535578
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# dtype: float64

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   36 months     10.33       324.23
# 1       4000         4000           4000.0   36 months     23.40       155.68
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3      23000        23000          23000.0   60 months     20.89       620.81
# 4       8000         8000           8000.0   36 months     23.40       311.35
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1         Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     D        D4        Operator    5 years           RENT     68107.0
# 4     E        E1         Manager  10+ years            OWN     43000.0
#
# ...
