# %% [markdown]
# <a href="https://colab.research.google.com/github/LilySu/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/Lily_Su_DS_Assignment_3__LS_DS_111_A_First_Look_at_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url="http://samplecsvs.s3.amazonaws.com/SalesJan2009.csv"
c=pd.read_csv(url)

# %%
c.head()
# Out:
#   Transaction_date   Product Price Payment_Type               Name  \
# 0      1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1      1/2/09 4:53  Product1  1200         Visa             Betina
# 2     1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3     1/3/09 14:44  Product1  1200         Visa              Gouya
# 4     1/4/09 12:56  Product2  3600         Visa            Gerd W
#
#                            City     State         Country Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/09 6:00
# 1  Parkville                           MO   United States     1/2/09 4:42
# 2  Astoria                             OR   United States    1/1/09 16:21
# 3                        Echuca  Victoria       Australia   9/25/05 21:13
# 4  Cahaba Heights                      AL   United States  11/15/08 15:47
#
#      Last_Login   Latitude   Longitude
# 0   1/2/09 6:08  51.500000   -1.116667
# ...

# %%
c.plot(style='k--', label='Series');

# %%
# c=c.astype(float)
# c['Transaction_date'] = pd.to_datetime(c['Transaction_date'])    
c.plot.bar(x="Payment_Type", y="Price");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-1289725bfa25> in <module>()
# ----> 1 c.plot.bar(x="Payment_Type", y="Price");
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwds)
#    2714         axes : matplotlib.AxesSubplot or np.array of them
#    2715         """
# -> 2716         return self(kind='bar', x=x, y=y, **kwds)
#    2717
#    2718     def barh(self, x=None, y=None, **kwds):
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
from pandas.plotting import radviz
import matplotlib.pyplot as plt
c = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
# c=c.cumsum()
c.plot(x='Transaction_date', y='Price')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Transaction_date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-86d14707639d> in <module>()
# ...

# %%
c.iloc[5].plot(kind='bar');
