# %% [markdown]
# <a href="https://colab.research.google.com/github/NikuDubenco/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/Nicolae_Dubenco_DS4_124_Make_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Make features
#
# Objectives
# -  understand the purpose of feature engineering
# -  work with strings in pandas
# - work with dates and times in pandas
#
# Links
# - [Feature Engineering](https://en.wikipedia.org/wiki/Feature_engineering)
# - Python Data Science Handbook
#   - [Chapter 3.10](https://jakevdp.github.io/PythonDataScienceHandbook/03.10-working-with-strings.html), Vectorized String Operations
#   - [Chapter 3.11](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html), Working with Time Series

# %% [markdown]
# ## Get LendingClub data
#
# [Source](https://www.lendingclub.com/info/download-data.action)

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-04-25 16:44:33--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [                <=> ]  21.37M   887KB/s    in 25s
#
# 2019-04-25 16:44:58 (880 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22408410]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %% [markdown]
# ## Load LendingClub data
#
# pandas documentation
# - [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# - [`options.display`](https://pandas.pydata.org/pandas-docs/stable/options.html#available-options)

# %%
import pandas as pd

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)
df.head(20)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0   NaN        NaN    10000.0      10000.0          10000.0   36 months
# 1   NaN        NaN     2500.0       2500.0           2500.0   36 months
# 2   NaN        NaN    12000.0      12000.0          12000.0   60 months
# 3   NaN        NaN    15000.0      15000.0          14975.0   60 months
# 4   NaN        NaN    16000.0      16000.0          16000.0   60 months
# 5   NaN        NaN     9600.0       9600.0           9600.0   36 months
# 6   NaN        NaN     4000.0       4000.0           4000.0   36 months
# 7   NaN        NaN     3500.0       3500.0           3500.0   36 months
# ...

# %%
pd.options.display.max_rows = 500
pd.options.display.max_columns = 500
df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# member_id                                     128412
# url                                           128412
# desc                                          128412
# hardship_loan_status                          128411
# hardship_amount                               128411
# hardship_start_date                           128411
# hardship_end_date                             128411
# payment_plan_start_date                       128411
# hardship_length                               128411
# hardship_dpd                                  128411
# hardship_payoff_balance_amount                128411
# orig_projected_additional_accrued_interest    128411
# hardship_status                               128411
# hardship_last_payment_amount                  128411
# hardship_reason                               128411
# hardship_type                                 128411
# deferral_term                                 128411
# ...

# %%
df.tail()
# Out:
#                                                       id  member_id  \
# 128409                                               NaN        NaN
# 128410                                               NaN        NaN
# 128411                                               NaN        NaN
# 128412  Total amount funded in policy code 1: 2050909275        NaN
# 128413   Total amount funded in policy code 2: 820109297        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128409     5000.0       5000.0           5000.0   36 months   13.56%
# 128410    10000.0      10000.0           9750.0   36 months   11.06%
# 128411    10000.0      10000.0          10000.0   36 months   16.91%
# 128412        NaN          NaN              NaN         NaN      NaN
# 128413        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       2500         2500           2500.0   36 months
# 2 NaN        NaN      12000        12000          12000.0   60 months
# 3 NaN        NaN      15000        15000          14975.0   60 months
# 4 NaN        NaN      16000        16000          16000.0   60 months
#
#   int_rate  installment grade sub_grade                  emp_title emp_length  \
# 0   10.33%       324.23     B        B1                        NaN   < 1 year
# 1   13.56%        84.92     C        C1                       Chef  10+ years
# 2   13.56%       276.49     C        C1                        NaN   < 1 year
# 3   14.47%       352.69     C        C2                        NaN        NaN
# 4   17.97%       406.04     D        D1  Instructional Coordinator    5 years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
df.shape
# Out:
# (128412, 145)

# %% [markdown]
# ## Work with strings

# %% [markdown]
# For machine learning, we usually want to replace strings with numbers.
#
# We can get info about which columns have a datatype of "object" (strings)

# %%
df.dtypes
# Out:
# id                                            float64
# member_id                                     float64
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# ...

# %%
df['int_rate']
# Out:
# 0          10.33%
# 1          13.56%
# 2          13.56%
# 3          14.47%
# 4          17.97%
# 5          23.40%
# 6          23.40%
# 7          20.89%
# 8          12.98%
# 9          23.40%
# 10         26.31%
# 11         18.94%
# 12         19.92%
# 13         17.97%
# 14         20.89%
# 15         11.80%
# 16         23.40%
# 17         15.02%
# 18         11.31%
# 19         10.33%
# 20         27.27%
# 21         16.14%
# 22         26.31%
# 23         15.02%
# 24         18.94%
# 25         11.31%
# 26         11.31%
# 27         14.47%
# 28         16.14%
# 29         14.47%
# 30         23.40%
# 31         10.72%
# 32         11.80%
# 33         15.02%
# 34         14.47%
# 35         11.31%
# 36         23.40%
# 37         10.33%
# 38         14.47%
# 39         11.80%
# 40         12.98%
# 41         19.92%
# 42         17.97%
# 43          6.46%
# 44         10.72%
# 45         12.98%
# 46         11.80%
# 47         20.89%
# 48         18.94%
# 49         16.14%
# ...

# %%
df.describe()
# Out:
#         id  member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  0.0        0.0  128412.000000  128412.000000    128412.000000
# mean   NaN        NaN   15971.321021   15971.321021     15968.498166
# std    NaN        NaN   10150.384233   10150.384233     10152.168970
# min    NaN        NaN    1000.000000    1000.000000       725.000000
# 25%    NaN        NaN    8000.000000    8000.000000      8000.000000
# 50%    NaN        NaN   14000.000000   14000.000000     14000.000000
# 75%    NaN        NaN   21600.000000   21600.000000     21600.000000
# max    NaN        NaN   40000.000000   40000.000000     40000.000000
#
#          installment    annual_inc  url  desc            dti    delinq_2yrs  \
# count  128412.000000  1.284120e+05  0.0   0.0  128175.000000  128412.000000
# mean      463.261221  8.279733e+04  NaN   NaN      19.933178       0.227837
# std       285.718371  1.082985e+05  NaN   NaN      20.143542       0.733793
# ...

# %%
df.describe(exclude='number')
# Out:
#               term int_rate   grade sub_grade emp_title emp_length  \
# count       128412   128412  128412    128412    107465     116708
# unique           2       46       7        35     43892         11
# top      36 months   13.56%       A        A4   Teacher  10+ years
# freq         88179     6976   38011      9770      2090      38826
#
#        home_ownership verification_status   issue_d loan_status pymnt_plan  \
# count          128412              128412    128412      128412     128412
# unique              4                   3         3           6          2
# top          MORTGAGE        Not Verified  Oct-2018     Current          n
# freq            63490               58350     46305      121676     128411
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# ...

# %% [markdown]
# ### Convert `int_rate`
#
# Define a function to remove percent signs from strings and convert to floats

# %%
# '13.56%'.strip('%')  =>> '13.56' ; default is ' '; and is doing for the first or last caracter
# df['int_rate'] = df.int_rate.strip('%').float()

def remove_percent(string):
  return float(string.strip('%'))

df.int_rate = df.int_rate.apply(remove_percent)
df.int_rate.head()
# Out:
# 0    10.33
# 1    13.56
# 2    13.56
# 3    14.47
# 4    17.97
# Name: int_rate, dtype: float64

# %% [markdown]
# Apply the function to the `int_rate` column

# %% [markdown]
# Filtering the data frame

# %%
df[df['term'] == ' 36 months'].shape
# Out:
# (88179, 145)

# %%
int_rate_greater_than_13 = df[df['int_rate'] >= 14.0]
int_rate_greater_than_13.reset_index()

# %% [markdown]
# ### Clean `emp_title`
#
# Look at top 20 titles

# %%
df.emp_title.value_counts().head(20)
# Out:
# Teacher                     2090
# Manager                     1773
# Registered Nurse             952
# Driver                       924
# RN                           726
# Supervisor                   697
# Sales                        580
# Project Manager              526
# General Manager              523
# Office Manager               521
# Owner                        420
# Director                     402
# Truck Driver                 387
# Operations Manager           387
# Nurse                        326
# Engineer                     325
# Sales Manager                304
# manager                      301
# Supervisor                   270
# Administrative Assistant     269
# Name: emp_title, dtype: int64

# %% [markdown]
# How often is `emp_title` null?

# %%
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
df.emp_title.value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
dtype(np.NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-104ce35b7a21> in <module>()
# ----> 1 dtype(np.NaN)
#
# NameError: name 'dtype' is not defined

# %% [markdown]
# Clean the title and handle missing values

# %%
import numpy as np

def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'

# %%
df.emp_title = df.emp_title.apply(clean_title)

# %%
df.emp_title.head(20)
# Out:
# 0                              Unknown
# 1                                 Chef
# 2                              Unknown
# 3                              Unknown
# 4            Instructional Coordinator
# 5                   Driver Coordinator
# 6                             Security
# 7                        Gas Attendant
# 8                              Unknown
# 9                              Manager
# 10    Financial Relationship Associate
# 11                          Postmaster
# 12                    Material Handler
# 13                      Administrative
# 14                            Operator
# 15                  Nursing Supervisor
# 16                 Sale Representative
# 17                    Sr Sales Manager
# 18                             Unknown
# 19                            Optician
# Name: emp_title, dtype: object

# %% [markdown]
# ### Create `emp_title_manager`
#
# pandas documentation: [`str.contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html)

# %%
df['emp_title_manager'] = df['emp_title'].str.contains('Manager')

# %%
managers = df[df['emp_title_manager'] == True]
plebians = df[df['emp_title_manager'] == False]

# %%
import seaborn as sns
sns.distplot(managers['int_rate'], bins=50);

# %% [markdown]
# ## Work with dates

# %% [markdown]
# pandas documentation
# - [to_datetime](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)
# - [Time/Date Components](https://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components) "You can access these properties via the `.dt` accessor"

# %%
df['issue_d'].head().values
# Out:
# array(['Dec-2018', 'Dec-2018', 'Dec-2018', 'Dec-2018', 'Dec-2018'],
#       dtype=object)

# %%
df['issue_d'].describe()
# Out:
# count       128412
# unique           3
# top       Oct-2018
# freq         46305
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_d'].dt.year
df['issue_d'].dt.month

# %%
df['issue_year'] = df['issue_d'].dt.year
df.shape
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       2500         2500           2500.0   36 months
# 2 NaN        NaN      12000        12000          12000.0   60 months
# 3 NaN        NaN      15000        15000          14975.0   60 months
# 4 NaN        NaN      16000        16000          16000.0   60 months
#
#    int_rate  installment grade sub_grade                  emp_title  \
# 0     10.33       324.23     B        B1                    Unknown
# 1     13.56        84.92     C        C1                       Chef
# 2     13.56       276.49     C        C1                    Unknown
# 3     14.47       352.69     C        C2                    Unknown
# 4     17.97       406.04     D        D1  Instructional Coordinator
#
#   emp_length home_ownership  annual_inc verification_status    issue_d  \
# ...

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['earlier_cr_line']

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
# - Convert the `term` column from string to integer.
#
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %% [markdown]
# #### Convert the term column from string to integer.

# %%
def term_to_int(string):
  for caracters in string.split():
    if caracters.isdigit() == True:
      return int(caracters)

print(type((term_to_int(' 36 months'))))

# [int(s) for s in df['term'].split() if s.isdigit()]
# Out:
# <class 'int'>

# %%
df['term'] = df['term'].apply(term_to_int)
df['term'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ####Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.

# %%
df['loan_status'].unique()
# Out:
# array(['Current', 'Fully Paid', 'Late (31-120 days)', 'Charged Off',
#        'In Grace Period', 'Late (16-30 days)'], dtype=object)

# %%
def loan_st(string):
  if (string.strip() == 'Current') or (string.strip() == 'Fully Paid'):
    return 1
  else:
    return 0

# %%
df['loan_status_is_great'] = df['loan_status'].apply(loan_st)

# %%
df['loan_status_is_great'].dtype
# Out:
# dtype('int64')

# %%
df[['loan_status','loan_status_is_great']]
# Out:
#                loan_status  loan_status_is_great
# 0                  Current                     1
# 1                  Current                     1
# 2                  Current                     1
# 3                  Current                     1
# 4                  Current                     1
# 5                  Current                     1
# 6                  Current                     1
# 7                  Current                     1
# 8                  Current                     1
# 9                  Current                     1
# 10                 Current                     1
# 11                 Current                     1
# 12                 Current                     1
# 13                 Current                     1
# 14                 Current                     1
# 15                 Current                     1
# 16                 Current                     1
# 17                 Current                     1
# ...

# %% [markdown]
# #### Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
df['last_pymnt_d'].head()
# Out:
# 0    Feb-2019
# 1    Feb-2019
# 2    Feb-2019
# 3    Feb-2019
# 4    Feb-2019
# Name: last_pymnt_d, dtype: object

# %%
df['last_pymnt_d'].isnull().sum()
# Out:
# 163

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

# %%
df['last_pymnt_d'].head()
# Out:
# 0   2019-02-01
# 1   2019-02-01
# 2   2019-02-01
# 3   2019-02-01
# 4   2019-02-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
df['last_pymnt_d'].isnull().sum()
# Out:
# 163

# %%
df['last_pymnt_d'].unique()
# Out:
# array(['2019-02-01T00:00:00.000000000', '2019-03-01T00:00:00.000000000',
#        '2019-01-01T00:00:00.000000000',                           'NaT',
#        '2018-12-01T00:00:00.000000000', '2018-11-01T00:00:00.000000000',
#        '2018-10-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
import numpy as np
import datetime as dt
import calendar

# %%
def new_column_month(date):
  if str(date) == 'NaT':
    return np.NaN
  else:
    return date.month
  
def new_column_year(date):
  if str(date) == 'NaT':
    return np.NaN
  else:
    return date.year

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d'].apply(new_column_year)

df['last_pymnt_d_month'].head()
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: last_pymnt_d_month, dtype: float64

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d_month'].astype(pd.Int64Dtype())

# %%
df['last_pymnt_d_month'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: last_pymnt_d_month, dtype: Int64

# %%
df['last_pymnt_d_month'].isnull().sum()
# Out:
# 163

# %%
df['last_pymnt_d_year'] = df['last_pymnt_d'].apply(new_column_year).astype(pd.Int64Dtype())

df['last_pymnt_d_year'].head()
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# Name: last_pymnt_d_year, dtype: Int64

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
