","","","","","","","","","","","N","","","","","","","","","","","","","","","Cash","N","","","","","",""
# "","","10000","10000","9750"," 36 months"," 11.06%","327.68","B","B3","","n/a","RENT","44400","Source Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","980xx","WA","11.78","0","Oct-2008","2","40","","15","0","6269","13.1%","25","f","8800.53","8580.51","1623.04","1582.46","1199.47","423.57","0.0","0.0","0.0","Mar-2019","327.68","Apr-2019","Mar-2019","0","53","1","Individual","","","","0","520","16440","3","1","1","1","2","10171","100","2","5","404","28","47700","0","3","5","6","1265","20037","2.3","0","0","61","119","1","1","0","1","","1","40","1","2","4","6","8","3","14","22","4","15","0","0","0","3","92","0","0","0","57871","16440","20500","10171","","","","","","","","","","","","N","","","","","","","","","","","","","","","Cash","N","","","","","",""
# "","","10000","10000","10000"," 36 months"," 16.91%","356.08","C","C5","Key Accounts Manager","2 years","RENT","80000","Not Verified","Oct-2018","Current","n","","","other","Other","021xx","MA","17.72","1","Sep-2006","0","14","","17","0","1942","30.8%","31","w","8893.43","8893.43","1771.01","1771.01","1106.57","664.44","0.0","0.0","0.0","Mar-2019","356.08","Apr-2019","Mar-2019","0","25","1","Individual","","","","0","0","59194","0","15","1","1","12","57252","85","0","0","1942","80","6300","0","5","0","1","3482","2058","48.5","0","0","144","142","40","12","0","131","30","","30","3","1","1","1","5","22","2","9","1","17","0","0","0","1","74.2","0","0","0","73669","59194","4000","67369","","","","","","","","","","","","N","","","","","","","","","","","","","","","Cash","N","","","","","",""
#
#
# Total amount funded in policy code 1: 2050909275
# Total amount funded in policy code 2: 820109297

# %% [markdown]
# ## Load LendingClub data
#
# pandas documentation
# - [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# - [`options.display`](https://pandas.pydata.org/pandas-docs/stable/options.html#available-options)

# %%
import pandas as pd
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
loan_stats = pd.read_csv("LoanStats_2018Q4.csv", header=1, skipfooter=2, engine='python')
loan_stats.shape
# Out:
# (128412, 145)

# %%
loan_stats.isna().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# member_id                                     128412
# url                                           128412
# desc                                          128412
# hardship_loan_status                          128411
# hardship_amount                               128411
# hardship_start_date                           128411
# hardship_end_date                             128411
# payment_plan_start_date                       128411
# hardship_length                               128411
# hardship_dpd                                  128411
# hardship_payoff_balance_amount                128411
# orig_projected_additional_accrued_interest    128411
# hardship_status                               128411
# hardship_last_payment_amount                  128411
# hardship_reason                               128411
# hardship_type                                 128411
# deferral_term                                 128411
# settlement_percentage                         128407
# settlement_term                               128407
# settlement_status                             128407
# debt_settlement_flag_date                     128407
# settlement_amount                             128407
# settlement_date                               128407
# sec_app_mths_since_last_major_derog           123258
# verification_status_joint                     113564
# mths_since_last_record                        112962
# sec_app_revol_util                            111888
# sec_app_num_rev_accts                         111630
# annual_inc_joint                              111630
# sec_app_chargeoff_within_12_mths              111630
# sec_app_open_act_il                           111630
# sec_app_collections_12_mths_ex_med            111630
# dti_joint                                     111630
# revol_bal_joint                               111630
# sec_app_earliest_cr_line                      111630
# sec_app_inq_last_6mths                        111630
# sec_app_mort_acc                              111630
# sec_app_open_acc                              111630
# mths_since_recent_bc_dlq                      103243
# mths_since_last_major_derog                    99232
# mths_since_recent_revol_delinq                 91630
# mths_since_last_delinq                         72196
# emp_title                                      20947
# il_util                                        20274
# mths_since_recent_inq                          16047
# emp_length                                     11704
# next_pymnt_d                                    5030
# mo_sin_old_il_acct                              4478
# mths_since_rcnt_il                              4478
# num_tl_120dpd_2m                                2859
# bc_util                                         1754
# percent_bc_gt_75                                1692
# bc_open_to_buy                                  1691
# mths_since_recent_bc                            1591
# dti                                              237
# last_pymnt_d                                     163
# revol_util                                       156
# all_util                                          37
# avg_cur_bal                                       13
# last_credit_pull_d                                 1
# total_rec_prncp                                    0
# initial_list_status                                0
# int_rate                                           0
# out_prncp                                          0
# out_prncp_inv                                      0
# total_pymnt                                        0
# total_pymnt_inv                                    0
# title                                              0
# total_rec_int                                      0
# installment                                        0
# term                                               0
# funded_amnt_inv                                    0
# funded_amnt                                        0
# recoveries                                         0
# collection_recovery_fee                            0
# loan_amnt                                          0
# total_rec_late_fee                                 0
# revol_bal                                          0
# total_acc                                          0
# earliest_cr_line                                   0
# pymnt_plan                                         0
# loan_status                                        0
# last_pymnt_amnt                                    0
# zip_code                                           0
# addr_state                                         0
# delinq_2yrs                                        0
# issue_d                                            0
# inq_last_6mths                                     0
# purpose                                            0
# verification_status                                0
# annual_inc                                         0
# home_ownership                                     0
# sub_grade                                          0
# grade                                              0
# open_acc                                           0
# pub_rec                                            0
# disbursement_method                                0
# open_il_24m                                        0
# collections_12_mths_ex_med                         0
# num_tl_30dpd                                       0
# num_actv_bc_tl                                     0
# num_actv_rev_tl                                    0
# num_bc_sats                                        0
# num_bc_tl                                          0
# num_il_tl                                          0
# num_op_rev_tl                                      0
# num_rev_accts                                      0
# num_rev_tl_bal_gt_0                                0
# num_sats                                           0
# num_tl_90g_dpd_24m                                 0
# policy_code                                        0
# num_tl_op_past_12m                                 0
# pct_tl_nvr_dlq                                     0
# pub_rec_bankruptcies                               0
# tax_liens                                          0
# tot_hi_cred_lim                                    0
# total_bal_ex_mort                                  0
# total_bc_limit                                     0
# total_il_high_credit_limit                         0
# hardship_flag                                      0
# num_accts_ever_120_pd                              0
# mort_acc                                           0
# mo_sin_rcnt_tl                                     0
# mo_sin_rcnt_rev_tl_op                              0
# application_type                                   0
# acc_now_delinq                                     0
# tot_coll_amt                                       0
# tot_cur_bal                                        0
# open_acc_6m                                        0
# open_act_il                                        0
# open_il_12m                                        0
# debt_settlement_flag                               0
# total_bal_il                                       0
# open_rv_12m                                        0
# open_rv_24m                                        0
# max_bal_bc                                         0
# total_rev_hi_lim                                   0
# inq_fi                                             0
# inq_last_12m                                       0
# acc_open_past_24mths                               0
# chargeoff_within_12_mths                           0
# delinq_amnt                                        0
# mo_sin_old_rev_tl_op                               0
# total_cu_tl                                        0
# dtype: int64

# %% [markdown]
# ## Work with strings

# %% [markdown]
# For machine learning, we usually want to replace strings with numbers.
#
# We can get info about which columns have a datatype of "object" (strings)

# %%
loan_stats.dtypes
# Out:
# id                                            float64
# member_id                                     float64
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# url                                           float64
# desc                                          float64
# purpose                                        object
# title                                          object
# zip_code                                       object
# addr_state                                     object
# dti                                           float64
# delinq_2yrs                                     int64
# earliest_cr_line                               object
# inq_last_6mths                                  int64
# mths_since_last_delinq                        float64
# mths_since_last_record                        float64
# open_acc                                        int64
# pub_rec                                         int64
# revol_bal                                       int64
# revol_util                                     object
# total_acc                                       int64
# initial_list_status                            object
# out_prncp                                     float64
# out_prncp_inv                                 float64
# total_pymnt                                   float64
# total_pymnt_inv                               float64
# total_rec_prncp                               float64
# total_rec_int                                 float64
# total_rec_late_fee                            float64
# recoveries                                    float64
# collection_recovery_fee                       float64
# last_pymnt_d                                   object
# last_pymnt_amnt                               float64
# next_pymnt_d                                   object
# last_credit_pull_d                             object
# collections_12_mths_ex_med                      int64
# mths_since_last_major_derog                   float64
# policy_code                                     int64
# application_type                               object
# annual_inc_joint                              float64
# dti_joint                                     float64
# verification_status_joint                      object
# acc_now_delinq                                  int64
# tot_coll_amt                                    int64
# tot_cur_bal                                     int64
# open_acc_6m                                     int64
# open_act_il                                     int64
# open_il_12m                                     int64
# open_il_24m                                     int64
# mths_since_rcnt_il                            float64
# total_bal_il                                    int64
# il_util                                       float64
# open_rv_12m                                     int64
# open_rv_24m                                     int64
# max_bal_bc                                      int64
# all_util                                      float64
# total_rev_hi_lim                                int64
# inq_fi                                          int64
# total_cu_tl                                     int64
# inq_last_12m                                    int64
# acc_open_past_24mths                            int64
# avg_cur_bal                                   float64
# bc_open_to_buy                                float64
# bc_util                                       float64
# chargeoff_within_12_mths                        int64
# delinq_amnt                                     int64
# mo_sin_old_il_acct                            float64
# mo_sin_old_rev_tl_op                            int64
# mo_sin_rcnt_rev_tl_op                           int64
# mo_sin_rcnt_tl                                  int64
# mort_acc                                        int64
# mths_since_recent_bc                          float64
# mths_since_recent_bc_dlq                      float64
# mths_since_recent_inq                         float64
# mths_since_recent_revol_delinq                float64
# num_accts_ever_120_pd                           int64
# num_actv_bc_tl                                  int64
# num_actv_rev_tl                                 int64
# num_bc_sats                                     int64
# num_bc_tl                                       int64
# num_il_tl                                       int64
# num_op_rev_tl                                   int64
# num_rev_accts                                   int64
# num_rev_tl_bal_gt_0                             int64
# num_sats                                        int64
# num_tl_120dpd_2m                              float64
# num_tl_30dpd                                    int64
# num_tl_90g_dpd_24m                              int64
# num_tl_op_past_12m                              int64
# pct_tl_nvr_dlq                                float64
# percent_bc_gt_75                              float64
# pub_rec_bankruptcies                            int64
# tax_liens                                       int64
# tot_hi_cred_lim                                 int64
# total_bal_ex_mort                               int64
# total_bc_limit                                  int64
# total_il_high_credit_limit                      int64
# revol_bal_joint                               float64
# sec_app_earliest_cr_line                       object
# sec_app_inq_last_6mths                        float64
# sec_app_mort_acc                              float64
# sec_app_open_acc                              float64
# sec_app_revol_util                            float64
# sec_app_open_act_il                           float64
# sec_app_num_rev_accts                         float64
# sec_app_chargeoff_within_12_mths              float64
# sec_app_collections_12_mths_ex_med            float64
# sec_app_mths_since_last_major_derog           float64
# hardship_flag                                  object
# hardship_type                                  object
# hardship_reason                                object
# hardship_status                                object
# deferral_term                                 float64
# hardship_amount                               float64
# hardship_start_date                            object
# hardship_end_date                              object
# payment_plan_start_date                        object
# hardship_length                               float64
# hardship_dpd                                  float64
# hardship_loan_status                           object
# orig_projected_additional_accrued_interest    float64
# hardship_payoff_balance_amount                float64
# hardship_last_payment_amount                  float64
# disbursement_method                            object
# debt_settlement_flag                           object
# debt_settlement_flag_date                      object
# settlement_status                              object
# settlement_date                                object
# settlement_amount                             float64
# settlement_percentage                         float64
# settlement_term                               float64
# dtype: object

# %% [markdown]
# ### Convert `int_rate`
#
# Define a function to remove percent signs from strings and convert to floats

# %%
def strip_percent(string):
  return float(string.strip('%'))/100

# %% [markdown]
# Apply the function to the `int_rate` column

# %%
loan_stats['int_rate'] = loan_stats['int_rate'].apply(strip_percent)
loan_stats.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       2500         2500           2500.0   36 months
# 2 NaN        NaN      12000        12000          12000.0   60 months
# 3 NaN        NaN      15000        15000          14975.0   60 months
# 4 NaN        NaN      16000        16000          16000.0   60 months
#
#    int_rate  installment grade sub_grade                  emp_title  \
# 0    0.1033       324.23     B        B1                        NaN
# 1    0.1356        84.92     C        C1                       Chef
# 2    0.1356       276.49     C        C1                        NaN
# 3    0.1447       352.69     C        C2                        NaN
# 4    0.1797       406.04     D        D1  Instructional Coordinator
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0   < 1 year       MORTGAGE    280000.0        Not Verified  Dec-2018
# 1  10+ years           RENT     55000.0        Not Verified  Dec-2018
# 2   < 1 year       MORTGAGE     40000.0        Not Verified  Dec-2018
# 3        NaN       MORTGAGE     30000.0     Source Verified  Dec-2018
# 4    5 years       MORTGAGE     51000.0        Not Verified  Dec-2018
#
#   loan_status pymnt_plan  url  desc             purpose               title  \
# 0     Current          n  NaN   NaN  debt_consolidation  Debt consolidation
# 1     Current          n  NaN   NaN  debt_consolidation  Debt consolidation
# 2     Current          n  NaN   NaN  debt_consolidation  Debt consolidation
# 3     Current          n  NaN   NaN  debt_consolidation  Debt consolidation
# 4     Current          n  NaN   NaN  debt_consolidation  Debt consolidation
#
#   zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 
0
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                   11.0                             NaN
# 1                    2.0                             NaN
# 2                    4.0                             NaN
# 3                    NaN                             NaN
# 4                    4.0                            52.0
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                      0               3                4            7
# 1                      0               2                5            3
# 2                      0               5                6            5
# 3                      0               4               13            4
# 4                      6               2                2            3
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0          7         10              9             11                    4
# 1          3         16              7             18                    5
# 2          5          1              7              7                    6
# 3          5          8             18             21                   13
# 4          6         21              3              6                    2
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0        14               0.0             0                   0
# 1         9               0.0             0                   0
# 2         8               0.0             0                   0
# 3        20               0.0             0                   0
# 4        11               0.0             0                   0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                   4            91.3              28.6                     0
# 1                   3           100.0               0.0                     1
# 2                   3           100.0              60.0                     0
# 3                   1           100.0              50.0                     0
# 4                   3            77.8               0.0                     0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          0           367828              61364           20900
# 1          0            60124              16901           36500
# 2          0            50800              32462           36800
# 3          0           118790              24507            9900
# 4          0            67924              39339           29500
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                       54912              NaN                      NaN
# 1                       18124              NaN                      NaN
# 2                        9000              NaN                      NaN
# 3                       14490          29704.0                 Oct-1999
# 4                       38424              NaN                      NaN
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     0.0               0.0              16.0
# 4                     NaN               NaN               NaN
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                 NaN                  NaN                    NaN
# 2                 NaN                  NaN                    NaN
# 3                48.8                  0.0                   15.0
# 4                 NaN                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               0.0                                 0.0
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N           NaN
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                  NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN           DirectPay                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %% [markdown]
# ### Clean `emp_title`
#
# Look at top 20 titles

# %%
loan_stats['emp_title'].head(20)
# Out:
# 0                                  NaN
# 1                                 Chef
# 2                                  NaN
# 3                                  NaN
# 4            Instructional Coordinator
# 5                  driver coordinator
# 6                             Security
# 7                        gas attendant
# 8                                  NaN
# 9                              Manager
# 10    Financial Relationship Associate
# 11                         Postmaster
# 12                    Material Handler
# 13                      Administrative
# 14                            Operator
# 15                  Nursing Supervisor
# 16                 Sale Representative
# 17                    Sr Sales Manager
# 18                                 NaN
# 19                            Optician
# Name: emp_title, dtype: object

# %% [markdown]
# How often is `emp_title` null?

# %%
loan_stats['emp_title'].isna().sum()
# Out:
# 20947

# %% [markdown]
# Clean the title and handle missing values

# %%
# Out:
# 0                   Unemployed
# 1                         Chef
# 2                   Unemployed
# 3                   Unemployed
# 4    Instructional Coordinator
# Name: emp_title, dtype: object

# %% [markdown]
# ### Create `emp_title_manager`
#
# > Indented block
#
#
#
# pandas documentation: [`str.contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html)

# %%
import numpy as np
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"
loan_stats['emp_title'] = loan_stats['emp_title'].apply(clean_title)
loan_stats.head(20)
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN      10000        10000          10000.0   36 months
# 1  NaN        NaN       2500         2500           2500.0   36 months
# 2  NaN        NaN      12000        12000          12000.0   60 months
# 3  NaN        NaN      15000        15000          14975.0   60 months
# 4  NaN        NaN      16000        16000          16000.0   60 months
# 5  NaN        NaN       9600         9600           9600.0   36 months
# 6  NaN        NaN       4000         4000           4000.0   36 months
# 7  NaN        NaN       3500         3500           3500.0   36 months
# 8  NaN        NaN       9600         9600           9600.0   36 months
# 9  NaN        NaN       8000         8000           8000.0   36 months
# 10 NaN        NaN      16000        16000          16000.0   60 months
# 11 NaN        NaN      30000        30000          30000.0   60 months
# 12 NaN        NaN      10000        10000          10000.0   60 months
# 13 NaN        NaN       5000         5000           5000.0   36 months
# 14 NaN        NaN      23000        23000          23000.0   60 months
# 15 NaN        NaN      32075        32075          32075.0   60 months
# 16 NaN        NaN      13000        13000          13000.0   36 months
# 17 NaN        NaN      35000        35000          35000.0   60 months
# 18 NaN        NaN      40000        40000          40000.0   60 months
# 19 NaN        NaN       8000         8000           8000.0   36 months
#
#     int_rate  installment grade sub_grade                         emp_title  \
# 0     0.1033       324.23     B        B1                           Unknown
# 1     0.1356        84.92     C        C1                              Chef
# 2     0.1356       276.49     C        C1                           Unknown
# 3     0.1447       352.69     C        C2                           Unknown
# 4     0.1797       406.04     D        D1         Instructional Coordinator
# 5     0.2340       373.62     E        E1                Driver Coordinator
# 6     0.2340       155.68     E        E1                          Security
# 7     0.2089       131.67     D        D4                     Gas Attendant
# 8     0.1298       323.37     B        B5                           Unknown
# 9     0.2340       311.35     E        E1                           Manager
# 10    0.2631       481.99     E        E4  Financial Relationship Associate
# 11    0.1894       777.23     D        D2                        Postmaster
# 12    0.1992       264.50     D        D3                  Material Handler
# 13    0.1797       180.69     D        D1                    Administrative
# 14    0.2089       620.81     D        D4                          Operator
# 15    0.1180       710.26     B        B4                Nursing Supervisor
# 16    0.2340       505.95     E        E1               Sale Representative
# 17    0.1502       833.02     C        C3                  Sr Sales Manager
# 18    0.1131       875.90     B        B3                           Unknown
# 19    0.1033       259.38     B        B1                          Optician
#
#    emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0    < 1 year       MORTGAGE    280000.0        Not Verified  Dec-2018
# 1   10+ years           RENT     55000.0        Not Verified  Dec-2018
# 2    < 1 year       MORTGAGE     40000.0        Not Verified  Dec-2018
# 3         NaN       MORTGAGE     30000.0     Source Verified  Dec-2018
# 4     5 years       MORTGAGE     51000.0        Not Verified  Dec-2018
# 5     9 years           RENT     65000.0        Not Verified  Dec-2018
# 6     3 years           RENT     90000.0     Source Verified  Dec-2018
# 7   10+ years       MORTGAGE     40000.0     Source Verified  Dec-2018
# 8         NaN       MORTGAGE     35704.0        Not Verified  Dec-2018
# 9   10+ years            OWN     43000.0     Source Verified  Dec-2018
# 10   < 1 year           RENT     33000.0     Source Verified  Dec-2018
# 11  10+ years       MORTGAGE     90000.0     Source Verified  Dec-2018
# 12  10+ years       MORTGAGE     80000.0        Not Verified  Dec-2018
# 13    6 years       MORTGAGE     59280.0     Source Verified  Dec-2018
# 14    5 years           RENT     68107.0     Source Verified  Dec-2018
# 15  10+ years       MORTGAGE    150000.0        Not Verified  Dec-2018
# 16    2 years       MORTGAGE     90000.0            Verified  Dec-2018
# 17  10+ years       MORTGAGE    290000.0     Source Verified  Dec-2018
# 18   < 1 year       MORTGAGE    136000.0        Not Verified  Dec-2018
# 19    6 years       MORTGAGE     38000.0     Source Verified  Dec-2018
#
#    loan_status pymnt_plan  url  desc             purpose  \
# 0      Current          n  NaN   NaN  debt_consolidation
# 1      Current          n  NaN   NaN  debt_consolidation
# 2      Current          n  NaN   NaN  debt_consolidation
# 3      Current          n  NaN   NaN  debt_consolidation
# 4      Current          n  NaN   NaN  debt_consolidation
# 5      Current          n  NaN   NaN         credit_card
# 6      Current          n  NaN   NaN  debt_consolidation
# 7      Current          n  NaN   NaN                 car
# 8      Current          n  NaN   NaN    home_improvement
# 9      Current          n  NaN   NaN  debt_consolidation
# 10     Current          n  NaN   NaN         credit_card
# 11     Current          n  NaN   NaN  debt_consolidation
# 12     Current          n  NaN   NaN  debt_consolidation
# 13     Current          n  NaN   NaN  debt_consolidation
# 14     Current          n  NaN   NaN  debt_consolidation
# 15     Current          n  NaN   NaN         credit_card
# 16     Current          n  NaN   NaN               other
# 17     Current          n  NaN   NaN  debt_consolidation
# 18     Current          n  NaN   NaN  debt_consolidation
# 19     Current          n  NaN   NaN         credit_card
#
#                       title zip_code addr_state    dti  delinq_2yrs  \
# 0        Debt consolidation    974xx         OR   6.15            2
# 1        Debt consolidation    109xx         NY  18.24            0
# 2        Debt consolidation    180xx         PA  19.23            0
# 3        Debt consolidation    756xx         TX  41.60            0
# 4        Debt consolidation    284xx         NC  21.91            0
# 5   Credit card refinancing    265xx         WV  23.01            1
# 6        Debt consolidation    070xx         NJ  26.33            0
# 7             Car financing    078xx         NJ   9.09            0
# 8          Home improvement    401xx         KY   0.84            0
# 9        Debt consolidation    357xx         AL  33.24            0
# 10  Credit card refinancing    290xx         SC  33.62            0
# 11       Debt consolidation    713xx         LA  26.52            0
# 12       Debt consolidation    648xx         MO  20.67            0
# 13       Debt consolidation    490xx         MI  10.51            0
# 14       Debt consolidation    672xx         KS   0.52            0
# 15  Credit card refinancing    231xx         VA  22.21            0
# 16                    Other    191xx         PA  39.73            0
# 17       Debt consolidation    656xx         MO   7.60            0
# 18       Debt consolidation    480xx         MI  15.41            0
# 19  Credit card refinancing    159xx         PA  19.84            0
#
#    earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0          Jan-1996               0                    18.0
# 1          Apr-2001               1                     NaN
# 2          Aug-2005               2                     NaN
# 3          Oct-1999               0                     NaN
# 4          Oct-2005               1                    52.0
# 5          Sep-2003               0                    16.0
# 6          Sep-2006               4                    59.0
# 7          Oct-2004               1                    24.0
# 8          Nov-2003               0                    69.0
# 9          Jan-1995               0                     NaN
# 10         Sep-2010               1                     NaN
# 11         Jun-1987               0                    71.0
# 12         Apr-2005               0                    37.0
# 13         Apr-2011               0                     NaN
# 14         Feb-1997               0                     NaN
# 15         Aug-2005               0                     NaN
# 16         May-2007               0                     NaN
# 17         Dec-2004               0                    29.0
# 18         Apr-2006               0                    72.0
# 19         Feb-2003               1                    49.0
#
#     mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  \
#
_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0      Apr-2019           Mar-2019                           0
# 1      Apr-2019           Mar-2019                           0
# 2      Apr-2019           Mar-2019                           0
# 3      Apr-2019           Mar-2019                           0
# 4      Apr-2019           Mar-2019                           0
# 5      Apr-2019           Mar-2019                           0
# 6      Apr-2019           Mar-2019                           0
# 7      Apr-2019           Mar-2019                           0
# 8      Apr-2019           Mar-2019                           0
# 9      Apr-2019           Mar-2019                           0
# 10     Apr-2019           Mar-2019                           0
# 11     Apr-2019           Mar-2019                           0
# 12     Apr-2019           Mar-2019                           0
# 13     Apr-2019           Mar-2019                           0
# 14     Apr-2019           Mar-2019                           1
# 15     Apr-2019           Mar-2019                           0
# 16     Apr-2019           Mar-2019                           0
# 17     Apr-2019           Mar-2019                           1
# 18     Apr-2019           Mar-2019                           0
# 19     Apr-2019           Mar-2019                           0
#
#     mths_since_last_major_derog  policy_code application_type  \
# 0                           NaN            1       Individual
# 1                           NaN            1       Individual
# 2                           NaN            1       Individual
# 3                           NaN            1        Joint App
# 4                          52.0            1       Individual
# 5                           NaN            1       Individual
# 6                           NaN            1       Individual
# 7                          48.0            1        Joint App
# 8                           NaN            1       Individual
# 9                           NaN            1       Individual
# 10                          NaN            1       Individual
# 11                          NaN            1       Individual
# 12                         37.0            1       Individual
# 13                          NaN            1       Individual
# 14                          NaN            1       Individual
# 15                          NaN            1       Individual
# 16                          NaN            1       Individual
# 17                         42.0            1       Individual
# 18                          NaN            1       Individual
# 19                         52.0            1       Individual
#
#     annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0                NaN        NaN                       NaN               0
# 1                NaN        NaN                       NaN               0
# 2                NaN        NaN                       NaN               0
# 3            55000.0      34.95           Source Verified               0
# 4                NaN        NaN                       NaN               0
# 5                NaN        NaN                       NaN               0
# 6                NaN        NaN                       NaN               0
# 7            59500.0      10.59           Source Verified               0
# 8                NaN        NaN                       NaN               0
# 9                NaN        NaN                       NaN               0
# 10               NaN        NaN                       NaN               0
# 11               NaN        NaN                       NaN               0
# 12               NaN        NaN                       NaN               0
# 13               NaN        NaN                       NaN               0
# 14               NaN        NaN                       NaN               0
# 15               NaN        NaN                       NaN               0
# 16               NaN        NaN                       NaN               0
# 17               NaN        NaN                       NaN               0
# 18               NaN        NaN                       NaN               0
# 19               NaN        NaN                       NaN               0
#
#     tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0            671       246828            1            3            2
# 1              0        16901            2            2            1
# 2              0        32462            1            1            1
# 3              0        65496            1            1            0
# 4              0        39339            3            8            2
# 5             66        24165            0            2            0
# 6              0        66926            5            4            3
# 7              0       189794            1            1            1
# 8              0          748            0            0            0
# 9              0       169223            0            3            2
# 10             0        29869            1            1            0
# 11          1208       321915            4            4            2
# 12           116       110120            0            2            0
# 13             0       110299            0            1            0
# 14          2693          976            0            0            0
# 15             0       272667            1            4            1
# 16             0        87876            1            7            1
# 17           149       479986            1            8            0
# 18             0       149597            1            2            0
# 19             0        83139            4            1            2
#
#     open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 
o_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                    275                     11               1         1
# 1                    212                      1               1         0
# 2                    149                      9               4         1
# 3                    230                      6               6         1
# 4                    158                      6               2         0
# 5                     92                     12              12         0
# 6                    118                      2               2         0
# 7                    170                      1               1         4
# 8                    100                     13              13         0
# 9                    287                     44               7         1
# 10                    99                      2               2         0
# 11                   378                      4               3         3
# 12                   164                     11              11         1
# 13                    92                     15              14         2
# 14                   262                     10              10         0
# 15                    70                      4               4         2
# 16                   139                     16               1         0
# 17                   167                     22               6         3
# 18                   132                      1               1         3
# 19                   133                      1               1         3
#
#     mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   11.0                       NaN                   11.0
# 1                    1.0                       NaN                    2.0
# 2                   10.0                       NaN                    4.0
# 3                   31.0                       NaN                    NaN
# 4                    6.0                      52.0                    4.0
# 5                   27.0                       NaN                   15.0
# 6                    2.0                       NaN                    0.0
# 7                    8.0                      48.0                    1.0
# 8                   16.0                       NaN                    3.0
# 9                   51.0                       NaN                    7.0
# 10                   2.0                       NaN                    3.0
# 11                   4.0                       NaN                    4.0
# 12                 149.0                      37.0                   11.0
# 13                  77.0                       NaN                   14.0
# 14                  10.0                       NaN                    9.0
# 15                  27.0                       NaN                   14.0
# 16                  16.0                       NaN                   10.0
# 17                  22.0                      42.0                    8.0
# 18                  40.0                       NaN                   15.0
# 19                   2.0                       NaN                    1.0
#
#     mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                              NaN                      0               3
# 1                              NaN                      0               2
# 2                              NaN                      0               5
# 3                              NaN                      0               4
# 4                             52.0                      6               2
# 5                             30.0                      0               7
# 6                              NaN                      0               5
# 7                             48.0                      2               1
# 8                              NaN                      0               1
# 9                              NaN                      0               1
# 10                             NaN                      0               6
# 11                             NaN                      0               2
# 12                            37.0                      0               2
# 13                             NaN                      0               0
# 14                             NaN                      0               0
# 15                             NaN                      0               4
# 16                             NaN                      0               6
# 17                            29.0                      0               3
# 18                             NaN                      0               3
# 19                             NaN                      1               4
#
#     num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                 4            7          7         10              9
# 1                 5            3          3         16              7
# 2                 6            5          5          1              7
# 3                13            4          5          8             18
# 4                 2            3          6         21              3
# 5                 9            7          8          8             10
# 6                 7            9          9          8             11
# 7                 2            1          8          3              2
# 8                 1            2          2         16              5
# 9                 4            1          2          8              4
# 10               11            9         13          2             16
# 11                4            4          9         27              8
# 12                8            2          4          6              8
# 13                3            3          3          4              6
# 14                1            3          4          3              5
# 15               10            4          4          8             12
# 16                7            6          7         11              7
# 17                4            3          8         17              6
# 18                8            4          8          5              9
# 19                8            4          6          6             12
#
#     num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0              11                    4        14               0.0
# 1              18                    5         9               0.0
# 2               7                    6         8               0.0
# 3              21                   13        20               0.0
# 4               6                    2        11               0.0
# 5              12                    9        12               0.0
# 6              12                    7        15               0.0
# 7              11                    2         4               0.0
# 8               7                    1         5               0.0
# 9               7                    4         8               0.0
# 10             20                   11        17               0.0
# 11             14                    4        13               0.0
# 12             12                    8        11               0.0
# 13              7                    3         8               0.0
# 14              7                    1         5               0.0
# 15             14                   10        17               0.0
# 16              9                    7        14               0.0
# 17             13                    4        15               0.0
# 18             14                    8        12               0.0
# 19             16                    8        14               0.0
#
#     num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0              0                   0                   4            91.3
# 1              0                   0                   3           100.0
# 2              0                   0                   3           100.0
# 3              0                   0                   1           100.0
# 4              0                   0                   3            77.8
# 5              0                   0                   1            90.0
# 6              0                   0                   9            95.0
# 7              0                   0                   3            38.9
# 8              0                   0                   0            95.5
# 9              0                   0                   2           100.0
# 10             0                   0                   1           100.0
# 11             0                   0                   6            95.0
# 12             0                   0                   1            84.2
# 13             0                   0                   0           100.0
# 14             0                   0                   3           100.0
# 15             0                   0                   2           100.0
# 16             0                   0                   1           100.0
# 17             0                   0                   1            87.9
# 18             0                   0                   2            86.4
# 19             0                   0                   7            95.7
#
#     percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               28.6                     0          0           367828
# 1                0.0                     1          0            60124
# 2               60.0                     0          0            50800
# 3               50.0                     0          0           118790
# 4                0.0                     0          0            67924
# 5               85.7                     0          0            68902
# 6                0.0                     0          0            98655
# 7                0.0                     0          0           217000
# 8                0.0                     0          0             6500
# 9              100.0                     1          0           199744
# 10              55.6                     0          0            45709
# 11               0.0                     1          0           372872
# 12              50.0                     0          0           170230
# 13               0.0                     0          0           136927
# 14               0.0                     0          0             7500
# 15              50.0                     0          0           360433
# 16              66.7                     0          0           137276
# 17             100.0                     0          0           513173
# 18              75.0                     0          0           179159
# 19              25.0                     0          0           100250
#
#     total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0               61364           20900                       54912
# 1               16901           36500                       18124
# 2               32462           36800                        9000
# 3               24507            9900                       14490
# 4               39339           29500                       38424
# 5               24165            7600                       40402
# 6               66926           21900                       71555
# 7               26902            5000                       25000
# 8                 748            4200                           0
# 9               31078            2300                       32206
# 10              29869           13900                       10809
# 11              99468           15000                       94072
# 12              37606            8000                       55030
# 13              11749           13800                       10000
# 14                976            3300                           0
# 15              56635           20000                       80125
# 16              87876           58600                       74676
# 17              87439           21600                       82773
# 18              62143           25000                       42409
# 19              31634           14600                       23358
#
#     revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0               NaN                      NaN                     NaN
# 1               NaN                      NaN                     NaN
# 2               NaN                      NaN                     NaN
# 3           29704.0                 Oct-1999                     0.0
# 4               NaN                      NaN                     NaN
# 5               NaN                      NaN                     NaN
# 6               NaN                      NaN                     NaN
# 7            6902.0                 May-2003                     0.0
# 8               NaN                      NaN                     NaN
# 9               NaN                      NaN                     NaN
# 10              NaN                      NaN                     NaN
# 11              NaN                      NaN                     NaN
# 12              NaN                      NaN                     NaN
# 13              NaN                      NaN                     NaN
# 14              NaN                      NaN                     NaN
# 15              NaN                      NaN                     NaN
# 16              NaN                      NaN                     NaN
# 17              NaN                      NaN                     NaN
# 18              NaN                      NaN                     NaN
# 19              NaN                      NaN                     NaN
#
#     sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0                NaN               NaN                 NaN
# 1                NaN               NaN                 NaN
# 2                NaN               NaN                 NaN
# 3                0.0              16.0                48.8
# 4                NaN               NaN                 NaN
# 5                NaN               NaN                 NaN
# 6                NaN               NaN                 NaN
# 7                3.0               6.0                47.9
# 8                NaN               NaN                 NaN
# 9                NaN               NaN                 NaN
# 10               NaN               NaN                 NaN
# 11               NaN               NaN                 NaN
# 12               NaN               NaN                 NaN
# 13               NaN               NaN                 NaN
# 14               NaN               NaN                 NaN
# 15               NaN               NaN                 NaN
# 16               NaN               NaN                 NaN
# 17               NaN               NaN                 NaN
# 18               NaN               NaN                 NaN
# 19               NaN               NaN                 NaN
#
#     sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   0.0                   15.0
# 4                   NaN                    NaN
# 5                   NaN                    NaN
# 6                   NaN                    NaN
# 7                   0.0                   21.0
# 8                   NaN                    NaN
# 9                   NaN                    NaN
# 10                  NaN                    NaN
# 11                  NaN                    NaN
# 12                  NaN                    NaN
# 13                  NaN                    NaN
# 14                  NaN                    NaN
# 15                  NaN                    NaN
# 16                  NaN                    NaN
# 17                  NaN                    NaN
# 18                  NaN                    NaN
# 19                  NaN                    NaN
#
#     sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                0.0                                 0.0
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
# 6                                NaN                                 NaN
# 7                                0.0                                 0.0
# 8                                NaN                                 NaN
# 9                                NaN                                 NaN
# 10                               NaN                                 NaN
# 11                               NaN                                 NaN
# 12                               NaN                                 NaN
# 13                               NaN                                 NaN
# 14                               NaN                                 NaN
# 15                               NaN                                 NaN
# 16                               NaN                                 NaN
# 17                               NaN                                 NaN
# 18                               NaN                                 NaN
# 19                               NaN                                 NaN
#
#     sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                   NaN             N           NaN
# 1                                   NaN             N           NaN
# 2                                   NaN             N           NaN
# 3                                   NaN             N           NaN
# 4                                   NaN             N           NaN
# 5                                   NaN             N           NaN
# 6                                   NaN             N           NaN
# 7                                  46.0             N           NaN
# 8                                   NaN             N           NaN
# 9                                   NaN             N           NaN
# 10                                  NaN             N           NaN
# 11                                  NaN             N           NaN
# 12                                  NaN             N           NaN
# 13                                  NaN             N           NaN
# 14                                  NaN             N           NaN
# 15                                  NaN             N           NaN
# 16                                  NaN             N           NaN
# 17                                  NaN             N           NaN
# 18                                  NaN             N           NaN
# 19                                  NaN             N           NaN
#
#    hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0              NaN             NaN            NaN              NaN
# 1              NaN             NaN            NaN              NaN
# 2              NaN             NaN            NaN              NaN
# 3              NaN             NaN            NaN              NaN
# 4              NaN             NaN            NaN              NaN
# 5              NaN             NaN            NaN              NaN
# 6              NaN             NaN            NaN              NaN
# 7              NaN             NaN            NaN              NaN
# 8              NaN             NaN            NaN              NaN
# 9              NaN             NaN            NaN              NaN
# 10             NaN             NaN            NaN              NaN
# 11             NaN             NaN            NaN              NaN
# 12             NaN             NaN            NaN              NaN
# 13             NaN             NaN            NaN              NaN
# 14             NaN             NaN            NaN              NaN
# 15             NaN             NaN            NaN              NaN
# 16             NaN             NaN            NaN              NaN
# 17             NaN             NaN            NaN              NaN
# 18             NaN             NaN            NaN              NaN
# 19             NaN             NaN            NaN              NaN
#
#    hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                  NaN               NaN                     NaN
# 1                  NaN               NaN                     NaN
# 2                  NaN               NaN                     NaN
# 3                  NaN               NaN                     NaN
# 4                  NaN               NaN                     NaN
# 5                  NaN               NaN                     NaN
# 6                  NaN               NaN                     NaN
# 7                  NaN               NaN                     NaN
# 8                  NaN               NaN                     NaN
# 9                  NaN               NaN                     NaN
# 10                 NaN               NaN                     NaN
# 11                 NaN               NaN                     NaN
# 12                 NaN               NaN                     NaN
# 13                 NaN               NaN                     NaN
# 14                 NaN               NaN                     NaN
# 15                 NaN               NaN                     NaN
# 16                 NaN               NaN                     NaN
# 17                 NaN               NaN                     NaN
# 18                 NaN               NaN                     NaN
# 19                 NaN               NaN                     NaN
#
#     hardship_length  hardship_dpd hardship_loan_status  \
# 0               NaN           NaN                  NaN
# 1               NaN           NaN                  NaN
# 2               NaN           NaN                  NaN
# 3               NaN           NaN                  NaN
# 4               NaN           NaN                  NaN
# 5               NaN           NaN                  NaN
# 6               NaN           NaN                  NaN
# 7               NaN           NaN                  NaN
# 8               NaN           NaN                  NaN
# 9               NaN           NaN                  NaN
# 10              NaN           NaN                  NaN
# 11              NaN           NaN                  NaN
# 12              NaN           NaN                  NaN
# 13              NaN           NaN                  NaN
# 14              NaN           NaN                  NaN
# 15              NaN           NaN                  NaN
# 16              NaN           NaN                  NaN
# 17              NaN           NaN                  NaN
# 18              NaN           NaN                  NaN
# 19              NaN           NaN                  NaN
#
#     orig_projected_additional_accrued_interest  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
#
#     hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# 5                              NaN                           NaN
# 6                              NaN                           NaN
# 7                              NaN                           NaN
# 8                              NaN                           NaN
# 9                              NaN                           NaN
# 10                             NaN                           NaN
# 11                             NaN                           NaN
# 12                             NaN                           NaN
# 13                             NaN                           NaN
# 14                             NaN                           NaN
# 15                             NaN                           NaN
# 16                             NaN                           NaN
# 17                             NaN                           NaN
# 18                             NaN                           NaN
# 19                             NaN                           NaN
#
#    disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0            DirectPay                    N                       NaN
# 1                 Cash                    N                       NaN
# 2                 Cash                    N                       NaN
# 3                 Cash                    N                       NaN
# 4                 Cash                    N                       NaN
# 5                 Cash                    N                       NaN
# 6                 Cash                    N                       NaN
# 7                 Cash                    N                       NaN
# 8                 Cash                    N                       NaN
# 9                 Cash                    N                       NaN
# 10                Cash                    N                       NaN
# 11                Cash                    N                       NaN
# 12                Cash                    N                       NaN
# 13                Cash                    N                       NaN
# 14                Cash                    N                       NaN
# 15                Cash                    N                       NaN
# 16                Cash                    N                       NaN
# 17           DirectPay                    N                       NaN
# 18           DirectPay                    N                       NaN
# 19           DirectPay                    N                       NaN
#
#    settlement_status settlement_date  settlement_amount  \
# 0                NaN             NaN                NaN
# 1                NaN             NaN                NaN
# 2                NaN             NaN                NaN
# 3                NaN             NaN                NaN
# 4                NaN             NaN                NaN
# 5                NaN             NaN                NaN
# 6                NaN             NaN                NaN
# 7                NaN             NaN                NaN
# 8                NaN             NaN                NaN
# 9                NaN             NaN                NaN
# 10               NaN             NaN                NaN
# 11               NaN             NaN                NaN
# 12               NaN             NaN                NaN
# 13               NaN             NaN                NaN
# 14               NaN             NaN                NaN
# 15               NaN             NaN                NaN
# 16               NaN             NaN                NaN
# 17               NaN             NaN                NaN
# 18               NaN             NaN                NaN
# 19               NaN             NaN                NaN
#
#     settlement_percentage  settlement_term
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3                     NaN              NaN
# 4                     NaN              NaN
# 5                     NaN              NaN
# 6                     NaN              NaN
# 7                     NaN              NaN
# 8                     NaN              NaN
# 9                     NaN              NaN
# 10                    NaN              NaN
# 11                    NaN              NaN
# 12                    NaN              NaN
# 13                    NaN              NaN
# 14                    NaN              NaN
# 15                    NaN              NaN
# 16                    NaN              NaN
# 17                    NaN              NaN
# 18                    NaN              NaN
# 19                    NaN              NaN

# %%
loan_stats['emp_title_manager'] = loan_stats['emp_title'] == 'Manager'
loan_stats['emp_title_manager'].head(100)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85     True
# 86    False
# 87    False
# 88    False
# 89    False
# 90    False
# 91     True
# 92    False
# 93    False
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: emp_title_manager, dtype: bool

# %% [markdown]
# ## Work with dates

# %% [markdown]
# pandas documentation
# - [to_datetime](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)
# - [Time/Date Components](https://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components) "You can access these properties via the `.dt` accessor"

# %%
loan_stats['issue_d'] = loan_stats['issue_d'].apply(pd.to_datetime)

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
# - Convert the `term` column from string to integer.
#
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
loan_stats['term'] = loan_stats['term'].apply(lambda term: int(term.strip(' months')))
loan_stats['term'].head()
# Out:
# 0    36
# 1    36
# 2    60
# 3    60
# 4    60
# Name: term, dtype: int64

# %%
loan_stats['loan_status_is_great'] = loan_stats['loan_status'].apply(lambda status: status == 'Current' or status == 'Fully Paid')
loan_stats['loan_status_is_great'].value_counts()
# Out:
# True     126584
# False      1828
# Name: loan_status_is_great, dtype: int64

# %%
loan_stats['last_pymnt_d'] = pd.to_datetime(loan_stats['last_pymnt_d'])
loan_stats['last_pymnt_d'].head()
# Out:
# 0   2019-02-01
# 1   2019-02-01
# 2   2019-02-01
# 3   2019-02-01
# 4   2019-02-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
loan_stats['last_pymnt_d_month'] = loan_stats['last_pymnt_d'].dt.month
loan_stats['last_pymnt_d_year'] = loan_stats['last_pymnt_d'].dt.year
loan_stats['last_pymnt_d_month'].head()
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: last_pymnt_d_month, dtype: float64

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
loan_stats['revol_util'] = loan_stats['revol_util'].apply(strip_percent)
loan_stats['revol_util'].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-37a3ca550edb> in <module>()
# ----> 1 loan_stats['revol_util'] = loan_stats['revol_util'].apply(strip_percent)
#       2 loan_stats['revol_util'].head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-57-3089261dc390> in strip_percent(string)
#       1 def strip_percent(string):
# ----> 2   return float(string.strip('%'))/100
#
# AttributeError: 'float' object has no attribute 'strip'

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
