# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

landslide_data = pd.read_csv('https://query.data.world/s/h63v5sypgtnhkpevtqbdf3v472ppic')

# %%
landslide_data.head()
# Out:
#    id        date time         country                        nearest_places  \
# 0   1  01/02/2007  NaN  United Kingdom                   Whitehaven, Cumbria
# 1   2  01/03/2007  NaN            Peru  Alto Mesapata, in the Pasco province
# 2   3  01/05/2007  NaN          Brazil         Nova Friburgo, Rio de Janeiro
# 3   4  01/05/2007  NaN          Brazil             Sumidouro, Rio de Janeiro
# 4   5  01/05/2007  NaN          Brazil                    Jundiai, Sao Paulo
#
#   hazard_type landslide_type trigger storm_name  fatalities  \
# 0   landslide      Landslide    Rain        NaN         1.0
# 1   landslide        Complex    Rain        NaN         NaN
# 2   landslide      Landslide    Rain        NaN         7.0
# 3   landslide      Landslide    Rain        NaN         2.0
# 4   landslide      Landslide    Rain        NaN         1.0
#
#                       ...                      population countrycode  \
# ...

# %%
mean_pop = np.mean(landslide_data.population)
print(mean_pop)
# Out:
# 156874.91406086044

# %%
shape = landslide_data.shape
print(shape)
# Out:
# (9564, 34)

# %%
pop_variance = landslide_data.population.var()
print(pop_variance)

variance = landslide_data.var()
print(variance)
# Out:
# 684330486997.975
# id              7.834626e+06
# fatalities      4.182178e+03
# injuries        6.857145e+01
# cat_id          7.798149e+06
# distance        2.439280e+02
# population      6.843305e+11
# version         1.065165e-01
# changeset_id    1.755940e+18
# latitude        4.168206e+02
# longitude       1.004779e+04
# dtype: float64
