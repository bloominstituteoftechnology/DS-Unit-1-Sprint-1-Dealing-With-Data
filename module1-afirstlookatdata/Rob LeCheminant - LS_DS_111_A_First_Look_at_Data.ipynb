# %% [markdown]
# <a href="https://colab.research.google.com/github/lechemrc/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/module1-afirstlookatdata/LS_DS_111_A_First_Look_at_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lambda School Data Science - A First Look at Data

# %% [markdown]
# ## Lecture - let's explore Python DS libraries and examples!
#
# The Python Data Science ecosystem is huge. You've seen some of the big pieces - pandas, scikit-learn, matplotlib. What parts do you want to see more of?

# %%
# TODO - we'll be doing this live, taking requests
# and reproducing what it is to look up and learn things

# %% [markdown]
# ### Loading Data via linux codes

# %%
# another way to import data.... this is a bash command

# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !wget https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv
# Out:
# --2019-07-10 02:49:32--  https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4384 (4.3K) [text/plain]
# Saving to: ‘drinks.csv.1’
#
# drinks.csv.1        100%[===================>]   4.28K  --.-KB/s    in 0s
#
# 2019-07-10 02:49:32 (49.9 MB/s) - ‘drinks.csv.1’ saved [4384/4384]

# %%
drinks2 = pd.read_csv('drinks.csv')
print(drinks2.shape)
# Out:
# (193, 5)

# %% [markdown]
# ### Loading Data

# %%
import pandas as pd 

drinks = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv')
print(drinks.shape)
drinks.head()
# Out:
# (193, 5)
#        country  beer_servings  ...  wine_servings  total_litres_of_pure_alcohol
# 0  Afghanistan              0  ...              0                           0.0
# 1      Albania             89  ...             54                           4.9
# 2      Algeria             25  ...             14                           0.7
# 3      Andorra            245  ...            312                          12.4
# 4       Angola            217  ...             45                           5.9
#
# [5 rows x 5 columns]

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %% [markdown]
# ### Manipulating Data

# %%
drinks.sort_values('beer_servings', ascending=False)[:10]
# Out:
#             country  beer_servings  ...  wine_servings  total_litres_of_pure_alcohol
# 117         Namibia            376  ...              1                           6.8
# 45   Czech Republic            361  ...            134                          11.8
# 62            Gabon            347  ...             59                           8.9
# 65          Germany            346  ...            175                          11.3
# 98        Lithuania            343  ...             56                          12.9
# 135          Poland            343  ...             56                          10.9
# 188       Venezuela            333  ...              3                           7.7
# 81          Ireland            313  ...            165                          11.4
# 129           Palau            306  ...             23                           6.9
# 140         Romania            297  ...            167                          10.4
#
# [10 rows x 5 columns]

# %%
drinks.nlargest(10, 'beer_servings')
# Out:
#             country  beer_servings  ...  wine_servings  total_litres_of_pure_alcohol
# 117         Namibia            376  ...              1                           6.8
# 45   Czech Republic            361  ...            134                          11.8
# 62            Gabon            347  ...             59                           8.9
# 65          Germany            346  ...            175                          11.3
# 98        Lithuania            343  ...             56                          12.9
# 135          Poland            343  ...             56                          10.9
# 188       Venezuela            333  ...              3                           7.7
# 81          Ireland            313  ...            165                          11.4
# 129           Palau            306  ...             23                           6.9
# 140         Romania            297  ...            167                          10.4
#
# [10 rows x 5 columns]

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

drinks.total_litres_of_pure_alcohol.hist()
plt.show()

# %%
drinks['drinks_alcohol'] = np.where(drinks['total_litres_of_pure_alcohol'] > 9, 'high',
                          np.where(drinks['total_litres_of_pure_alcohol'] >= 6, 'medium',
                          np.where(drinks['total_litres_of_pure_alcohol'] == 0, 'none', 'low',)))
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  drinks_alcohol
# 0  Afghanistan              0  ...                           0.0            none
# 1      Albania             89  ...                           4.9             low
# 2      Algeria             25  ...                           0.7             low
# 3      Andorra            245  ...                          12.4            high
# 4       Angola            217  ...                           5.9             low
#
# [5 rows x 6 columns]

# %%
drinks.drinks_alcohol.value_counts()
# Out:
# low       105
# medium     41
# high       34
# none       13
# Name: drinks_alcohol, dtype: int64

# %%
countries = pd.read_csv('https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv')
print(countries.shape)
countries.head()
# Out:
# (249, 11)
#              name alpha-2  ... sub-region-code  intermediate-region-code
# 0     Afghanistan      AF  ...            34.0                       NaN
# 1   Åland Islands      AX  ...           154.0                       NaN
# 2         Albania      AL  ...            39.0                       NaN
# 3         Algeria      DZ  ...            15.0                       NaN
# 4  American Samoa      AS  ...            61.0                       NaN
#
# [5 rows x 11 columns]

# %%
# joining dataframes -- be careful and double check that the data is joining the way you want it

df = drinks.join(countries[['name', 'region', 'sub-region']], how='left')
df.head()

# this joins on the index instead of the country name that we wanted.
# Out:
#        country  beer_servings  ...   region       sub-region
# 0  Afghanistan              0  ...     Asia    Southern Asia
# 1      Albania             89  ...   Europe  Northern Europe
# 2      Algeria             25  ...   Europe  Southern Europe
# 3      Andorra            245  ...   Africa  Northern Africa
# 4       Angola            217  ...  Oceania        Polynesia
#
# [5 rows x 9 columns]

# %%
df = pd.merge(drinks, countries[['name', 'region', 'sub-region']], how='left', left_on='country', right_on='name')
print(df.shape)
df.head(10)
# Out:
# (193, 9)
#              country  beer_servings  ...    region                       sub-region
# 0        Afghanistan              0  ...      Asia                    Southern Asia
# 1            Albania             89  ...    Europe                  Southern Europe
# 2            Algeria             25  ...    Africa                  Northern Africa
# 3            Andorra            245  ...    Europe                  Southern Europe
# 4             Angola            217  ...    Africa               Sub-Saharan Africa
# 5  Antigua & Barbuda            102  ...       NaN                              NaN
# 6          Argentina            193  ...  Americas  Latin America and the Caribbean
# 7            Armenia             21  ...      Asia                     Western Asia
# 8          Australia            261  ...   Oceania        Australia and New Zealand
# 9            Austria            279  ...    Europe                   Western Europe
#
# [10 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 192
# Data columns (total 9 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# drinks_alcohol                  193 non-null object
# name                            167 non-null object
# region                          167 non-null object
# sub-region                      167 non-null object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 15.1+ KB

# %%
df.isna().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# drinks_alcohol                   0
# name                            26
# region                          26
# sub-region                      26
# dtype: int64

# %%
df[df.total_litres_of_pure_alcohol > 5]
# Out:
#                           country  ...                       sub-region
# 3                         Andorra  ...                  Southern Europe
# 4                          Angola  ...               Sub-Saharan Africa
# 6                       Argentina  ...  Latin America and the Caribbean
# 8                       Australia  ...        Australia and New Zealand
# 9                         Austria  ...                   Western Europe
# 11                        Bahamas  ...  Latin America and the Caribbean
# 14                       Barbados  ...  Latin America and the Caribbean
# 15                        Belarus  ...                   Eastern Europe
# 16                        Belgium  ...                   Western Europe
# 17                         Belize  ...  Latin America and the Caribbean
# 22                       Botswana  ...               Sub-Saharan Africa
# 23                         Brazil  ...  Latin America and the Caribbean
# ...

# %%
df[df.region.isna()]
# Out:
#                           country  beer_servings  ...  region  sub-region
# 5               Antigua & Barbuda            102  ...     NaN         NaN
# 20                        Bolivia            167  ...     NaN         NaN
# 21             Bosnia-Herzegovina             76  ...     NaN         NaN
# 24                         Brunei             31  ...     NaN         NaN
# 28                  Cote d'Ivoire             37  ...     NaN         NaN
# 45                 Czech Republic            361  ...     NaN         NaN
# 46                    North Korea              0  ...     NaN         NaN
# 47                       DR Congo             32  ...     NaN         NaN
# 79                           Iran              0  ...     NaN         NaN
# 92                           Laos             62  ...     NaN         NaN
# 110                    Micronesia             62  ...     NaN         NaN
# 138                   South Korea            140  ...     NaN         NaN
# ...

# %%
drinks.iloc[184]
# Out:
# country                            USA
# beer_servings                      249
# spirit_servings                    158
# wine_servings                       84
# total_litres_of_pure_alcohol       8.7
# drinks_alcohol                  medium
# Name: 184, dtype: object

# %%
drinks.at[184, 'country'] = 'United States of America'
df.at[184, 'country'] = 'United States of America'

# %%
print(drinks.iloc[184])
df.iloc[184]
# Out:
# country                         United States of America
# beer_servings                                        249
# spirit_servings                                      158
# wine_servings                                         84
# total_litres_of_pure_alcohol                         8.7
# drinks_alcohol                                    medium
# Name: 184, dtype: object
# country                         United States of America
# beer_servings                                        249
# spirit_servings                                      158
# wine_servings                                         84
# total_litres_of_pure_alcohol                         8.7
# drinks_alcohol                                    medium
# name                                                 NaN
# region                                               NaN
# sub-region                                           NaN
# Name: 184, dtype: object

# %%
df['region'].value_counts()
# Out:
# Africa      48
# Asia        40
# Europe      37
# Americas    27
# Oceania     15
# Name: region, dtype: int64

# %%
df['sub-region'].value_counts()

# %%
df.groupby('sub-region').beer_servings.mean().plot(kind='bar', figsize=(20, 6))
plt.title('Average Beer Servings by Region')
plt.ylabel('Beer Servings')
plt.show()

# %%
df.boxplot(column='beer_servings', by='region', figsize=(10,6))
plt.show()

# %%
import seaborn as sns

# %%
# sns.pairplot(x_vars=['beer_servings'], y_vars=['wine_servings'])

# %%
df = df.dropna(subset=["region"])
df.shape
# Out:
# (167, 9)

# %%
from bokeh.io import output_file, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool, CategoricalColorMapper
from bokeh.palettes import d3
from bokeh.plotting import figure
from bokeh.transform import transform
output_notebook()
x = df.beer_servings.values
y = df.wine_servings.values
country = df.country
region = df.region
source = ColumnDataSource(data=dict(x=x, y=y, country=country, region=region))
hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("(x,y)", "(@x, @y)"),
    ('country', '@country'),
])
palette = d3['Category10'][len(df['region'].unique())]
mapper = CategoricalColorMapper(factors = df['region'].unique(), palette = palette)
# create figure and plot
p = figure(plot_width=600, plot_height=600, 
           tools=[hover, "wheel_zoom", "box_zoom", "reset"], 
           title="Beer and Wine Servings per Year by Country")
# create plot
p.scatter(x='x', y='y', size=10, alpha=0.8,
          color={'field': 'region', 'transform': mapper},
          legend='region', 
          source=source)
# add axis labels
p.xaxis.axis_label = "Beer Servings"
p.yaxis.axis_label = "Wine Servings"
output_file('interactive_bokeh_plot.html')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1170">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="20abc864-fff1-4ed0-9dab-50bae90e974b" data-root-id="1175"></div>

# %% [markdown]
# ## Assignment - now it's your turn
#
# Pick at least one Python DS library, and using documentation/examples reproduce in this notebook something cool. It's OK if you don't fully understand it or get it 100% working, but do put in effort and look things up.

# %% [markdown]
# ### Music Genre Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
genre = pd.read_csv('https://raw.githubusercontent.com/Insiyaa/Music-Tagging/master/data.csv')
print(genre.shape)
print(genre.head())
genre.tail()
# Out:
# (1000, 30)
#          filename       tempo  beats  ...     mfcc19     mfcc20  label
# 0  blues.00081.au  103.359375     50  ...  -7.570825   2.918987  blues
# 1  blues.00022.au   95.703125     44  ...   3.316913  -0.608485  blues
# 2  blues.00031.au  151.999081     75  ... -11.025216 -13.387260  blues
# 3  blues.00012.au  184.570312     91  ...  -1.418707  -5.932607  blues
# 4  blues.00056.au  161.499023     74  ...   0.024832  -2.005315  blues
#
# [5 rows x 30 columns]
#           filename       tempo  beats  ...    mfcc19    mfcc20  label
# 995  rock.00017.au  123.046875     59  ... -3.673562 -0.163201   rock
# 996  rock.00081.au  117.453835     56  ... -1.654875  7.544224   rock
# 997  rock.00004.au  103.359375     45  ... -4.665996 -4.787677   rock
# 998  rock.00006.au  112.347147     45  ... -2.196753 -3.395148   rock
# 999  rock.00066.au   75.999540     36  ... -4.349921 -4.220998   rock
#
# [5 rows x 30 columns]

# %%
genre.describe()
# Out:
#              tempo        beats  ...       mfcc19       mfcc20
# count  1000.000000  1000.000000  ...  1000.000000  1000.000000
# mean    119.601702    57.138000  ...    -2.328779    -1.094875
# std      28.297367    14.225728  ...     3.755574     3.837561
# min      54.978391    18.000000  ...   -18.504188   -19.935203
# 25%      99.384014    47.000000  ...    -4.670281    -3.368000
# 50%     117.453835    56.000000  ...    -2.391261    -1.155198
# 75%     135.999178    65.250000  ...     0.149070     1.303739
# max     234.907670   117.000000  ...    14.686910    15.368966
#
# [8 rows x 28 columns]

# %%
print(min(genre['tempo']))
print(max(genre['tempo']))
print(genre['tempo'].value_counts())
print(np.mean(genre['tempo'].value_counts() <=45))
# Out:
# 54.97839095744681
# 234.90767045454547
# 123.046875    94
# 117.453835    79
# 129.199219    79
# 99.384014     66
# 107.666016    66
# 112.347147    62
# 151.999081    62
# 135.999178    61
# 103.359375    56
# 95.703125     54
# 143.554688    48
# 161.499023    45
# 92.285156     37
# 89.102909     29
# 172.265625    26
# 184.570312    23
# 83.354335     19
# 86.132812     14
# 80.749512     12
# 73.828125     10
# 78.302557      9
# 75.999540      8
# 198.768029     7
# 71.777344      6
# 215.332031     5
# 69.837416      4
# 67.999589      3
# 66.256010      3
# 61.523438      3
# 64.599609      3
# 58.726918      2
# 63.024009      2
# 54.978391      1
# 234.907670     1
# 60.092660      1
# Name: tempo, dtype: int64
# 0.6857142857142857

# %%
genre.isna().sum()
# Out:
# filename              0
# tempo                 0
# beats                 0
# chroma_stft           0
# rmse                  0
# spectral_centroid     0
# spectral_bandwidth    0
# rolloff               0
# zero_crossing_rate    0
# mfcc1                 0
# mfcc2                 0
# mfcc3                 0
# mfcc4                 0
# mfcc5                 0
# mfcc6                 0
# mfcc7                 0
# mfcc8                 0
# mfcc9                 0
# mfcc10                0
# mfcc11                0
# mfcc12                0
# mfcc13                0
# mfcc14                0
# mfcc15                0
# mfcc16                0
# mfcc17                0
# mfcc18                0
# mfcc19                0
# mfcc20                0
# label                 0
# dtype: int64

# %%
genre2 = pd.read_csv('https://raw.githubusercontent.com/Insiyaa/Music-Tagging/master/data_2genre.csv')
print(genre2.shape)
print(genre2.head())
genre.tail()
# Out:
# (200, 30)
#        filename       tempo  beats  ...    mfcc19    mfcc20  label
# 0  pop.00024.au  117.453835     57  ...  1.493700  0.949931      1
# 1  pop.00099.au   78.302557     38  ...  1.609469  7.580263      1
# 2  pop.00009.au  107.666016     50  ...  1.569434 -1.724873      1
# 3  pop.00078.au  103.359375     52  ... -0.729631 -0.987611      1
# 4  pop.00037.au  103.359375     51  ... -0.612146 -4.050126      1
#
# [5 rows x 30 columns]
#           filename       tempo  beats  ...    mfcc19    mfcc20  label
# 995  rock.00017.au  123.046875     59  ... -3.673562 -0.163201   rock
# 996  rock.00081.au  117.453835     56  ... -1.654875  7.544224   rock
# 997  rock.00004.au  103.359375     45  ... -4.665996 -4.787677   rock
# 998  rock.00006.au  112.347147     45  ... -2.196753 -3.395148   rock
# 999  rock.00066.au   75.999540     36  ... -4.349921 -4.220998   rock
#
# [5 rows x 30 columns]

# %%
genre.describe()
# Out:
#              tempo        beats  ...       mfcc19       mfcc20
# count  1000.000000  1000.000000  ...  1000.000000  1000.000000
# mean    119.601702    57.138000  ...    -2.328779    -1.094875
# std      28.297367    14.225728  ...     3.755574     3.837561
# min      54.978391    18.000000  ...   -18.504188   -19.935203
# 25%      99.384014    47.000000  ...    -4.670281    -3.368000
# 50%     117.453835    56.000000  ...    -2.391261    -1.155198
# 75%     135.999178    65.250000  ...     0.149070     1.303739
# max     234.907670   117.000000  ...    14.686910    15.368966
#
# [8 rows x 28 columns]

# %%
genres = genre.append(genre2)
print(genres.head())
genres.tail()
# Out:
#          filename       tempo  beats  ...     mfcc19     mfcc20  label
# 0  blues.00081.au  103.359375     50  ...  -7.570825   2.918987  blues
# 1  blues.00022.au   95.703125     44  ...   3.316913  -0.608485  blues
# 2  blues.00031.au  151.999081     75  ... -11.025216 -13.387260  blues
# 3  blues.00012.au  184.570312     91  ...  -1.418707  -5.932607  blues
# 4  blues.00056.au  161.499023     74  ...   0.024832  -2.005315  blues
#
# [5 rows x 30 columns]
#                filename       tempo  beats  ...    mfcc19    mfcc20  label
# 195  classical.00020.au  143.554688     69  ... -1.292084 -7.100527      2
# 196  classical.00072.au  117.453835     57  ... -3.253521  3.998950      2
# 197  classical.00061.au  151.999081     76  ... -5.246985 -5.270150      2
# 198  classical.00008.au  135.999178     67  ... -2.105312  0.755132      2
# 199  classical.00084.au  112.347147     25  ... -1.273307 -0.441167      2
#
# [5 rows x 30 columns]

# %%
print(genres.shape)
print(genres['label'].value_counts())
# Out:
# (1200, 30)
# pop          100
# rock         100
# disco        100
# country      100
# reggae       100
# blues        100
# jazz         100
# classical    100
# metal        100
# hiphop       100
# 2            100
# 1            100
# Name: label, dtype: int64

# %%
# genres.drop([genres['label'] == 'hiphop'], axis=0, inplace=True)

# %%
# genres = genres[genres['label'] != ]

# %% [markdown]
# ### Genre graphing

# %%
print(genres.shape)
print(genres['label'].value_counts())
# Out:
# (1200, 30)
# pop          100
# rock         100
# disco        100
# country      100
# reggae       100
# blues        100
# jazz         100
# classical    100
# metal        100
# hiphop       100
# 2            100
# 1            100
# Name: label, dtype: int64

# %%
genres['tempo'][genre['label'] == 'blues'].hist(bins=20, color='b', alpha=0.2, figsize=(10,6))
genres['tempo'][genre['label'] == 'pop'].hist(bins=20, color='purple', alpha=0.4)
genres['tempo'][genre['label'] == 'rock'].hist(bins=20, color='r', alpha=0.5)
genres['tempo'][genre['label'] == 'hiphop'].hist(bins=20, color='y', alpha=0.4)
genres['tempo'][genre['label'] == 'classical'].hist(bins=20, color='g', alpha=0.2)
genres['tempo'][genre['label'] == 'jazz'].hist(bins=20, color='k', alpha=0.2)
plt.title('tempo distribution of genres overlayed')
plt.show()

# I wanted to show all the different tempos overlayed first and then separated
# in order to see if there was a patterh to where tempos generally fall
# it sure seemed to show such

# %%
genres['tempo'].hist(bins=20, color='gray')
plt.title('tempo distribution of all tempos')
plt.show(block=False)
genres['tempo'][genre['label'] == 'blues'].hist(bins=20, color='b')
plt.title('tempo distribution of blues')
plt.show(block=False)
genres['tempo'][genre['label'] == 'pop'].hist(bins=20, color='purple')
plt.title('tempo distribution of pop')
plt.show(block=False)
genres['tempo'][genre['label'] == 'rock'].hist(bins=20, color='r')
plt.title('tempo distribution of rock')
plt.show(block=False)
genres['tempo'][genre['label'] == 'hiphop'].hist(bins=20, color='y')
plt.title('tempo distribution of hiphop')
plt.show(block=False)
genres['tempo'][genre['label'] == 'classical'].hist(bins=20, color='g')
plt.title('tempo distribution of classical')
plt.show(block=False)
genres['tempo'][genre['label'] == 'jazz'].hist(bins=20, color='k')
plt.title('tempo distribution of jazz')
plt.show(block=False)
plt.show()

# %%
# plt.scatter(genres['label'][genres['label'] != 1,2], genres['tempo'][genres['label'] != 1,2])
# plt.show()

# %% [markdown]
# ### Assignment questions
#
# After you've worked on some code, answer the following questions in this text block:
#
# 1.  Describe in a paragraph of text what you did and why, as if you were writing an email to somebody interested but nontechnical.
#
# 2.  What was the most challenging part of what you did?
#
# 3.  What was the most interesting thing you learned?
#
# 4.  What area would you like to explore with more time?

# %% [markdown]
# 1. Honestly, it doesn't seem like I got a lot done today, but I got stuck at several points and it turns out I was working with a dataset with some quirks. I needed to use masking to get tempos for specific labels of music and it took a while to get to understand that. What that means is I need to figure out how to search in the dataset for tempos but specifically tempos for rows containing the label 'blues', for instance. I wanted to plot the distribution of those tempos and do it per genre, while also creating an overaly of all the graphs to see if the tempos tend to fall into a specific range more often, which is something I could also do with a simple histogram of all the tempos combined as well.
#
# 2. The most challenging part was trying to figure out the quirks of columns and the values that fall in them, especially when they contain strings and numbers. It certainly didn't make it easy. Also, I couldn't figure out why, when there were 1200 values in the dataset, when I tried to find specific numbers in the thousands, it was saying they were indexed as zeros and 100s. Very confusing.
#
# 3. Merging data sets was extremely useful and it made my work at lot easier early on. I thought I was going to have to do the same things twice with two different data sets, but since the columns aligned nicely, a simple line merged them together quite well.
#
# 4. I would like to explore column and row manipulation a bit more, especially when you're dealing with larger datasets and what the datatypes mean and what parameters they entail overall.

# %% [markdown]
# ## Stretch goals and resources
#
# Following are *optional* things for you to take a look at. Focus on the above assignment first, and make sure to commit and push your changes to GitHub (and since this is the first assignment of the sprint, open a PR as well).
#
# - [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/)
# - [scikit-learn documentation](http://scikit-learn.org/stable/documentation.html)
# - [matplotlib documentation](https://matplotlib.org/contents.html)
# - [Awesome Data Science](https://github.com/bulutyazilim/awesome-datascience) - a list of many types of DS resources
#
# Stretch goals:
#
# - Find and read blogs, walkthroughs, and other examples of people working through cool things with data science - and share with your classmates!
# - Write a blog post (Medium is a popular place to publish) introducing yourself as somebody learning data science, and talking about what you've learned already and what you're excited to learn more about.
