# %% [markdown]
# <a href="https://colab.research.google.com/github/SamH3pn3r/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/Sam's_Copy_of_LS_DS_124_Make_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Make features
#
# Objectives
# -  understand the purpose of feature engineering
# -  work with strings in pandas
# - work with dates and times in pandas
# - work with dataframe filtering, list comprehensions, and .apply function.
#
# Links
# - [Feature Engineering](https://en.wikipedia.org/wiki/Feature_engineering)
# - Python Data Science Handbook
#   - [Chapter 3.10](https://jakevdp.github.io/PythonDataScienceHandbook/03.10-working-with-strings.html), Vectorized String Operations
#   - [Chapter 3.11](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html), Working with Time Series

# %% [markdown]
# ## Get LendingClub data
#
# [Source](https://www.lendingclub.com/info/download-data.action)

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-07-11 16:29:52--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [                <=> ]  21.51M   902KB/s    in 25s
#
# 2019-07-11 16:30:17 (893 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22559146]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4543.48","4543.48","1511.13","1511.13","1056.52","454.61","0.0","0.0","0.0","Jun-2019","190.21","Jul-2019","Jun-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %% [markdown]
# ## Load LendingClub data
#
# pandas documentation
# - [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# - [`options.display`](https://pandas.pydata.org/pandas-docs/stable/options.html#available-options)

# %%
import pandas as pd
df = pd.read_csv('LoanStats_2018Q4.csv')
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,123,124,125,126,127,128,129,130,131,132,133,134,135,136,138,139,140,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv',skiprows = 1)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,123,124,125,128,129,130,133,138,139,140) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 1  NaN        NaN    25000.0      25000.0          25000.0   60 months
# 2  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 3  NaN        NaN     4000.0       4000.0           4000.0   36 months
# 4  NaN        NaN    31450.0      31450.0          31450.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0   17.97%       180.69     D        D1        Administrative    6 years
# 1   14.47%       587.82     C        C2               teacher  10+ years
# ...

# %%
df.isnull().sum()
# Out:
# id                                            128412
# member_id                                     128414
# loan_amnt                                          2
# funded_amnt                                        2
# funded_amnt_inv                                    2
# term                                               2
# int_rate                                           2
# installment                                        2
# grade                                              2
# sub_grade                                          2
# emp_title                                      20949
# emp_length                                     11706
# home_ownership                                     2
# annual_inc                                         2
# verification_status                                2
# issue_d                                            2
# loan_status                                        2
# pymnt_plan                                         2
# ...

# %%
df.tail()
# Out:
#                                                       id  member_id  \
# 128409                                               NaN        NaN
# 128410                                               NaN        NaN
# 128411                                               NaN        NaN
# 128412  Total amount funded in policy code 1: 2050909275        NaN
# 128413   Total amount funded in policy code 2: 820109297        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128409     5000.0       5000.0           5000.0   36 months   13.56%
# 128410    10000.0      10000.0           9750.0   36 months   11.06%
# 128411    10000.0      10000.0          10000.0   36 months   16.91%
# 128412        NaN          NaN              NaN         NaN      NaN
# 128413        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade             emp_title emp_length  \
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv',skiprows = 1,skipfooter=2, engine = 'python')
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128407   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128408   15.02%       346.76     C        C3        security guard    5 years
# 128409   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128410   11.06%       327.68     B        B3                   NaN        NaN
# 128411   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
print(df.shape)
df.isnull().sum().sort_values(ascending=False)
# Out:
# (128412, 144)
# id                                            128412
# member_id                                     128412
# url                                           128412
# desc                                          128412
# hardship_dpd                                  128411
# deferral_term                                 128411
# hardship_amount                               128411
# hardship_start_date                           128411
# hardship_end_date                             128411
# payment_plan_start_date                       128411
# hardship_length                               128411
# orig_projected_additional_accrued_interest    128411
# hardship_loan_status                          128411
# hardship_reason                               128411
# hardship_payoff_balance_amount                128411
# hardship_last_payment_amount                  128411
# hardship_type                                 128411
# ...

# %%
df_copy_1 = df.drop(['id','url','desc','member_id'],axis='columns')
df_copy = df_copy_1.copy()
df_copy.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   17.97%       180.69
# 1      25000        25000          25000.0   60 months   14.47%       587.82
# 2      10000        10000          10000.0   36 months   10.33%       324.23
# 3       4000         4000           4000.0   36 months   23.40%       155.68
# 4      31450        31450          31450.0   36 months    7.56%       979.16
#
#   grade sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0     D        D1        Administrative    6 years       MORTGAGE     59280.0
# 1     C        C2               teacher  10+ years            OWN    110000.0
# 2     B        B1                   NaN   < 1 year       MORTGAGE    280000.0
# 3     E        E1              Security    3 years           RENT     90000.0
# 4     A        A3  Construction Manager    7 years       MORTGAGE    130000.0
#
# ...

# %% [markdown]
# ## Work with strings

# %% [markdown]
# For machine learning, we usually want to replace strings with numbers.
#
# We can get info about which columns have a datatype of "object" (strings)

# %%
df_copy.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %% [markdown]
# ### Convert `int_rate`
#
# Define a function to remove percent signs from strings and convert to floats

# %%
def remove_percent(string):
  return float(string.strip('%'))

# %% [markdown]
# Apply the function to the `int_rate` column

# %%
df_copy['int_rate'] = df_copy['int_rate'].apply(remove_percent)

# %%
df_copy.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       5000         5000           5000.0   36 months     17.97       180.69
# 1      25000        25000          25000.0   60 months     14.47       587.82
# 2      10000        10000          10000.0   36 months     10.33       324.23
# 3       4000         4000           4000.0   36 months     23.40       155.68
# 4      31450        31450          31450.0   36 months      7.56       979.16
#
#   grade sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0     D        D1        Administrative    6 years       MORTGAGE     59280.0
# 1     C        C2               teacher  10+ years            OWN    110000.0
# 2     B        B1                   NaN   < 1 year       MORTGAGE    280000.0
# 3     E        E1              Security    3 years           RENT     90000.0
# 4     A        A3  Construction Manager    7 years       MORTGAGE    130000.0
#
# ...

# %%
df_copy.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %% [markdown]
# # **List Comprehension Example**

# %%
example_list = ['13.56%','13.56%','13.23']
[remove_percent(string) for string in example_list]
# Out:
# [13.56, 13.56, 13.23]

# %% [markdown]
# ### Clean `emp_title`
#
# Look at top 20 titles

# %%
df_copy['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %% [markdown]
# How often is `emp_title` null?

# %%
df_copy['emp_title'].isnull().sum()
# Out:
# 20947

# %% [markdown]
# Clean the title and handle missing values

# %%
import numpy as np
examples = ['owner','Supervisor',' Project Manager', np.NaN]

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"
  return title.strip()

[clean_title(x) for x in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df_copy['emp_title'] = df_copy['emp_title'].apply(clean_title)
print(df_copy['emp_title'].value_counts(dropna=False).head(20))
df_copy['emp_title'].value_counts(dropna=False).head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# ...

# %%
#[{"Nurse": ['Registered Nurse', 'Rn', 'Nurse']},{"Manager": ['Sales Manager', 'General Manager']}]

# %% [markdown]
# ### Create `emp_title_manager`
#
# pandas documentation: [`str.contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html)

# %%
#df_copy = df_copy.apply(lambda x: x.strip().title() if isinstance(x,str))
df_copy = df_copy.apply(lambda x: x.str.strip().str.title() if x.dtype == "object" else x)
df_copy.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0       5000         5000           5000.0    36     17.97       180.69     D
# 1      25000        25000          25000.0    60     14.47       587.82     C
# 2      10000        10000          10000.0    36     10.33       324.23     B
# 3       4000         4000           4000.0    36     23.40       155.68     E
# 4      31450        31450          31450.0    36      7.56       979.16     A
#
#   sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0        D1        Administrative    6 Years       Mortgage     59280.0
# 1        C2               Teacher  10+ Years            Own    110000.0
# 2        B1               Unknown   < 1 Year       Mortgage    280000.0
# 3        E1              Security    3 Years           Rent     90000.0
# 4        A3  Construction Manager    7 Years       Mortgage    130000.0
#
# ...

# %%
df_copy['emp_title_manager'] = df_copy['emp_title'].str.contains('Manager')

# %%
df_copy.head(6)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       5000         5000           5000.0   36 months     17.97       180.69
# 1      25000        25000          25000.0   60 months     14.47       587.82
# 2      10000        10000          10000.0   36 months     10.33       324.23
# 3       4000         4000           4000.0   36 months     23.40       155.68
# 4      31450        31450          31450.0   36 months      7.56       979.16
# 5      15500        15500          15500.0   36 months     10.72       505.40
#
#   grade sub_grade                 emp_title emp_length home_ownership  \
# 0     D        D1            Administrative    6 years       MORTGAGE
# 1     C        C2                   Teacher  10+ years            OWN
# 2     B        B1                   Unknown   < 1 year       MORTGAGE
# 3     E        E1                  Security    3 years           RENT
# 4     A        A3      Construction Manager    7 years       MORTGAGE
# ...

# %% [markdown]
# ## **Dataframe Filtering**

# %%
#rows where managers are
managers = df_copy[df_copy['emp_title_manager']==True]
#rows where non-managers are
plebians = df_copy[df_copy['emp_title_manager']==False]

# %%
print(managers['int_rate'].mean())
print(plebians['int_rate'].mean())
# Out:
# 12.760582149647126
# 12.957349045509492

# %%
import seaborn as sns 
sns.distplot(managers['int_rate']);
sns.distplot(plebians['int_rate']);

# %% [markdown]
# ## Work with dates

# %% [markdown]
# pandas documentation
# - [to_datetime](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)
# - [Time/Date Components](https://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components) "You can access these properties via the `.dt` accessor"

# %%
df_copy['issue_d'].head().values
# Out:
# array(['Dec-2018', 'Dec-2018', 'Dec-2018', 'Dec-2018', 'Dec-2018'],
#       dtype=object)

# %%
df_copy['issue_d'].describe()
# Out:
# count       128412
# unique           3
# top       Oct-2018
# freq         46305
# Name: issue_d, dtype: object

# %%
df_copy['issue_d'] = pd.to_datetime(df_copy['issue_d'],infer_datetime_format=True)

# %%
df_copy['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df_copy.dtypes

# %%
df_copy['issue_d'].describe()
# Out:
# count                  128412
# unique                      3
# top       2018-10-01 00:00:00
# freq                    46305
# first     2018-10-01 00:00:00
# last      2018-12-01 00:00:00
# Name: issue_d, dtype: object

# %%
df_copy['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# 5         2018
# 6         2018
# 7         2018
# 8         2018
# 9         2018
# 10        2018
# 11        2018
# 12        2018
# 13        2018
# 14        2018
# 15        2018
# 16        2018
# 17        2018
# 18        2018
# 19        2018
# 20        2018
# 21        2018
# 22        2018
# 23        2018
# 24        2018
# 25        2018
# 26        2018
# 27        2018
# 28        2018
# 29        2018
# 30        2018
# 31        2018
# 32        2018
# 33        2018
# 34        2018
# 35        2018
# 36        2018
# 37        2018
# 38        2018
# 39        2018
# 40        2018
# 41        2018
# 42        2018
# 43        2018
# 44        2018
# 45        2018
# 46        2018
# 47        2018
# 48        2018
# 49        2018
# 50        2018
# 51        2018
# 52        2018
# 53        2018
# 54        2018
# 55        2018
# 56        2018
# 57        2018
# ...

# %%
df_copy['issue_year'] = df_copy['issue_d'].dt.year

# %%
df_copy['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
# 5         12
# 6         12
# 7         12
# 8         12
# 9         12
# 10        12
# 11        12
# 12        12
# 13        12
# 14        12
# 15        12
# 16        12
# 17        12
# 18        12
# 19        12
# 20        12
# 21        12
# 22        12
# 23        12
# 24        12
# 25        12
# 26        12
# 27        12
# 28        12
# 29        12
# 30        12
# 31        12
# 32        12
# 33        12
# 34        12
# 35        12
# 36        12
# 37        12
# 38        12
# 39        12
# 40        12
# 41        12
# 42        12
# 43        12
# 44        12
# 45        12
# 46        12
# 47        12
# 48        12
# 49        12
# 50        12
# 51        12
# 52        12
# 53        12
# 54        12
# 55        12
# 56        12
# 57        12
# 58        12
# 59        12
# 60        12
# 61        12
# 62        12
# 63        12
# 64        12
# 65        12
# ...

# %%
df_copy['issue_month'] = df_copy['issue_d'].dt.month

# %%
df_copy['issue_month'].value_counts()
# Out:
# 10    46305
# 11    41973
# 12    40134
# Name: issue_month, dtype: int64

# %%
[col for col in df_copy if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df_copy['earliest_cr_line'].head()
# Out:
# 0    Apr-2011
# 1    Jan-1997
# 2    Jan-1996
# 3    Sep-2006
# 4    Jul-1997
# Name: earliest_cr_line, dtype: object

# %%
df_copy['earliest_cr_line'] = pd.to_datetime(df_copy['earliest_cr_line'],
                                            infer_datetime_format=True)

# %%
(df_copy['issue_d'] - df_copy['earliest_cr_line']).dt.days
# Out:
# 0          2801
# 1          8004
# 2          8370
# 3          4474
# 4          7823
# 5          4079
# 6          6088
# 7          3713
# 8          5479
# 9          7093
# 10         6331
# 11         6635
# 12         1705
# 13        14428
# 14         3562
# 15         6453
# 16         4232
# 17         1736
# 18         5479
# 19         9192
# 20         4079
# 21         3743
# 22        11048
# 23         2648
# 24         4901
# 25         1979
# 26        10380
# 27         1764
# 28         5174
# 29         8339
# 30         5723
# 31         4201
# 32         5693
# 33         2983
# 34         4901
# 35         4079
# 36         5935
# 37         3075
# 38         4962
# 39         5782
# 40         5174
# 41         5023
# 42         4686
# 43         2435
# 44         1522
# 45         2679
# 46         3987
# 47         4201
# 48         4383
# 49         4474
# 50         4444
# 51         9953
# 52         5143
# 53         8645
# 54         3013
# ...

# %%
df_copy['days_from_earliest_credit_to_issue'] = (
    df_copy['issue_d'] - df_copy['earliest_cr_line']).dt.days

df_copy.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       5000         5000           5000.0   36 months     17.97       180.69
# 1      25000        25000          25000.0   60 months     14.47       587.82
# 2      10000        10000          10000.0   36 months     10.33       324.23
# 3       4000         4000           4000.0   36 months     23.40       155.68
# 4      31450        31450          31450.0   36 months      7.56       979.16
#
#   grade sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0     D        D1        Administrative    6 years       MORTGAGE     59280.0
# 1     C        C2               Teacher  10+ years            OWN    110000.0
# 2     B        B1               Unknown   < 1 year       MORTGAGE    280000.0
# 3     E        E1              Security    3 years           RENT     90000.0
# 4     A        A3  Construction Manager    7 years       MORTGAGE    130000.0
#
# ...

# %%
df_copy['years_from_earliest_credit_to_issue'] = (df_copy['days_from_earliest_credit_to_issue'] / 365)
df_copy.tail()
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 128407      23000        23000          23000.0    36     15.02       797.53
# 128408      10000        10000          10000.0    36     15.02       346.76
# 128409       5000         5000           5000.0    36     13.56       169.83
# 128410      10000        10000           9750.0    36     11.06       327.68
# 128411      10000        10000          10000.0    36     16.91       356.08
#
#        grade sub_grade             emp_title emp_length home_ownership  \
# 128407     C        C3        Tax Consultant  10+ years       MORTGAGE
# 128408     C        C3        Security Guard    5 years       MORTGAGE
# 128409     C        C1          Payoff Clerk  10+ years       MORTGAGE
# 128410     B        B3               Unknown        NaN           RENT
# 128411     C        C5  Key Accounts Manager    2 years           RENT
#
# ...

# %%
type(np.NaN)
# Out:
# float

# %%
df_copy['loan_status']

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
# - Convert the `term` column from string to integer.
#
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
#method for removing text in data and converting to int
def remove_months(string):
  return int(string.strip(' months'))

# %%
#Using the method to convert to int
df_copy['term'] = df_copy['term'].apply(remove_months)
df_copy.dtypes

# %%
new_loan_stat = { "Current":1, 
                 "Fully Paid":1,
                 "In Grace Period":0, 
                 "Charged Off":0,
                 "Late (31-120 Days)":0,
                "Late (16-30 Days)":0,
                "Default":0}

df_copy['loan_status_is_great'] = df_copy['loan_status'].map(new_loan_stat)

# %%
df_copy.isnull().sum()

# %%
df_copy['loan_status'].value_counts()

# %%
#spliting into two columns
df_copy['last_pymnt_d'] = pd.to_datetime(df_copy['last_pymnt_d'],
                                            infer_datetime_format=True)
df_copy['last_pymnt_d_month'] = df_copy['last_pymnt_d'].dt.month
df_copy['last_pymnt_d_year'] = df_copy['last_pymnt_d'].dt.year

# %%
df_copy.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0       5000         5000           5000.0    36     17.97       180.69     D
# 1      25000        25000          25000.0    60     14.47       587.82     C
# 2      10000        10000          10000.0    36     10.33       324.23     B
# 3       4000         4000           4000.0    36     23.40       155.68     E
# 4      31450        31450          31450.0    36      7.56       979.16     A
#
#   sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0        D1        Administrative    6 Years       Mortgage     59280.0
# 1        C2               Teacher  10+ Years            Own    110000.0
# 2        B1               Unknown   < 1 Year       Mortgage    280000.0
# 3        E1              Security    3 Years           Rent     90000.0
# 4        A3  Construction Manager    7 Years       Mortgage    130000.0
#
# ...

# %%
#Checking to make sure I didn't create any more null values
print(df_copy['last_pymnt_d'].isnull().sum())
print(df_copy['last_pymnt_d_month'].isnull().sum())
print(df_copy['last_pymnt_d_year'].isnull().sum())
# Out:
# 159
# 159
# 159

# %% [markdown]
# # STRETCH OPTIONS
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
